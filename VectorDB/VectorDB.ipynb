# %% [markdown]
# ## Import Relevant Files

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torcheval.metrics import R2Score

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import math

import sys
sys.path.insert(1, '../CDeeS/utils')
from paths import *

import chromadb

# %% [markdown]
# ## Load Neural Network

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size):
        super(NeuralNetwork, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), 2)
        )

    def forward(self, x):
        return self.layers(x)

# %%
model = NeuralNetwork(66)
model.load_state_dict(torch.load('deam_feedforward_nn_essentia_best_valence_mean_normalised.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Load Music Metadata

# %%
df_music = pd.read_csv("./music_info_withname.csv")
df_music.rename(columns={"i_id_c": "song_id"}, inplace=True)
df_music = df_music.astype({'song_id': 'int32'})

cols = ["song_id", "general_genre", "music", "singer"]
df_music = df_music[cols]
display(df_music)
# Out:
#      song_id general_genre                  music  \
# 0        874         indie         The Privateers
# 1        566         other            Never Stops
# 2        812          jazz    Night Of The Iguana
# 3        941          rock             You And Me
# 4        802        reggae        Saber Su Nombre
# ..       ...           ...                    ...
# 931      438          rock            Uptown Girl
# 932      690         other              Oblivious
# 933      163   alternative  America's Suitehearts
# 934      946         metal     Ride The Lightning
# 935      717          rock        I'm Not In Love
#
#                             singer
# 0                      Andrew Bird
# 1                       Deerhunter
# 2          The Cinematic Orchestra
# 3                  Plain White T's
# 4                     Daddy Yankee
# ..                             ...
# 931  Me First And The Gimme Gimmes
# 932                   Aztec Camera
# 933                   Fall Out Boy
# 934                      Metallica
# 935                 Charly García
#
# [936 rows x 4 columns]

# %% [markdown]
# ## Load Essentia Features

# %%
df_features = pd.read_csv("./essentia_features_clipped.csv", index_col=0)
display(df_features)
# Out:
#      song_id  lowlevel.average_loudness  lowlevel.barkbands_crest.dmean  \
# 0        275                   0.973211                        2.734494
# 1        507                   0.914995                        1.779870
# 2        936                   0.980768                        2.198826
# 3        739                   0.957888                        2.358258
# 4        659                   0.985889                        2.725301
# ..       ...                        ...                             ...
# 291      126                   0.981803                        3.347317
# 292      898                   0.968436                        2.509090
# 293      873                   0.944901                        3.191716
# 294      697                   0.979438                        2.086719
# 295      720                   0.975688                        3.843237
#
#      lowlevel.barkbands_crest.dmean2  lowlevel.barkbands_crest.dvar  \
# 0                           4.519869                       6.629131
# 1                           2.783498                       2.342016
# 2                           3.604454                       6.320270
# 3                           3.890606                       5.011153
# 4                           4.472162                       7.312916
# ..                               ...                            ...
# 291                         5.755877                       9.081094
# 292                         4.032299                       6.231036
# 293                         5.233109                       9.425733
# 294                         3.368903                       5.024929
# 295                         6.323866                      11.846233
#
#      lowlevel.barkbands_crest.dvar2  lowlevel.barkbands_crest.max  \
# 0                         17.751158                     22.156931
# 1                          5.451638                     24.106762
# 2                         16.075104                     21.427538
# 3                         12.956815                     24.700670
# 4                         17.942963                     19.204697
# ..                              ...                           ...
# 291                       23.494911                     24.453768
# 292                       16.421440                     23.289955
# 293                       24.588820                     26.887018
# 294                       12.668143                     23.188427
# 295                       27.269871                     25.299095
#
#      lowlevel.barkbands_crest.mean  lowlevel.barkbands_crest.median  \
# 0                         9.782679                         9.064570
# 1                        11.063436                        10.109395
# 2                         7.163894                         6.297218
# 3                        15.441179                        15.776317
# 4                         7.446805                         6.570291
# ..                             ...                              ...
# 291                       9.621816                         8.968574
# 292                      12.805885                        12.573533
# 293                       9.700563                         8.773985
# 294                       7.980445                         7.247404
# 295                      11.475137                        10.367895
#
#      lowlevel.barkbands_crest.min  ...  metadata.version.essentia_git_sha  \
# 0                        2.926671  ...    v2.1_beta5-1110-g77a6a954-dirty
# 1                        3.955993  ...    v2.1_beta5-1110-g77a6a954-dirty
# 2                        2.519053  ...    v2.1_beta5-1110-g77a6a954-dirty
# 3                        4.622088  ...    v2.1_beta5-1110-g77a6a954-dirty
# 4                        2.597616  ...    v2.1_beta5-1110-g77a6a954-dirty
# ..                            ...  ...                                ...
# 291                      2.641244  ...    v2.1_beta5-1110-g77a6a954-dirty
# 292                      3.175924  ...    v2.1_beta5-1110-g77a6a954-dirty
# 293                      2.415689  ...    v2.1_beta5-1110-g77a6a954-dirty
# 294                      2.558759  ...    v2.1_beta5-1110-g77a6a954-dirty
# 295                      2.974041  ...    v2.1_beta5-1110-g77a6a954-dirty
#
#      metadata.version.extractor  tonal.chords_key  tonal.chords_scale  \
# 0                     music 2.0                Bb               major
# 1                     music 2.0                F#               major
# 2                     music 2.0                Ab               major
# 3                     music 2.0                 A               major
# 4                     music 2.0                 E               major
# ..                          ...               ...                 ...
# 291                   music 2.0                 B               major
# 292                   music 2.0                 G               major
# 293                   music 2.0                 E               minor
# 294                   music 2.0                F#               minor
# 295                   music 2.0                 E               minor
#
#      tonal.key_edma.key  tonal.key_edma.scale  tonal.key_krumhansl.key  \
# 0                    Eb                 major                       Eb
# 1                    F#                 major                       F#
# 2                    C#                 major                       C#
# 3                     D                 minor                        D
# 4                     E                 major                        E
# ..                  ...                   ...                      ...
# 291                   C                 major                        C
# 292                   D                 major                        D
# 293                   E                 minor                        E
# 294                   D                 major                        D
# 295                   A                 major                        A
#
#      tonal.key_krumhansl.scale  tonal.key_temperley.key  \
# 0                        major                       Eb
# 1                        major                       F#
# 2                        major                       C#
# 3                        minor                        D
# 4                        major                        E
# ..                         ...                      ...
# 291                      major                        C
# 292                      major                        D
# 293                      minor                        E
# 294                      major                        D
# 295                      major                        A
#
#      tonal.key_temperley.scale
# 0                        major
# 1                        major
# 2                        major
# 3                        minor
# 4                        major
# ..                         ...
# 291                      major
# 292                      major
# 293                      minor
# 294                      major
# 295                      major
#
# [296 rows x 578 columns]

# %%
df_combined = df_music.merge(df_features, how="inner", on="song_id")
display(df_combined)
# Out:
#      song_id general_genre                music                   singer  \
# 0        874         indie       The Privateers              Andrew Bird
# 1        812          jazz  Night Of The Iguana  The Cinematic Orchestra
# 2        941          rock           You And Me          Plain White T's
# 3        739         metal       Planet Caravan            Black Sabbath
# 4         70        reggae  No Creo En El Jamas                   Juanes
# ..       ...           ...                  ...                      ...
# 291       47          rock            The Stomp                The Hives
# 292      529       hip-hop    Where The Hood At                      DMX
# 293      875   alternative          Sullen Girl              Fiona Apple
# 294      946         metal   Ride The Lightning                Metallica
# 295      717          rock      I'm Not In Love           Charly García
#
#      lowlevel.average_loudness  lowlevel.barkbands_crest.dmean  \
# 0                     0.392642                        2.495658
# 1                     0.933627                        2.397552
# 2                     0.973347                        2.531084
# 3                     0.957888                        2.358258
# 4                     0.954137                        2.347313
# ..                         ...                             ...
# 291                   0.971516                        2.380748
# 292                   0.971770                        3.323876
# 293                   0.975494                        1.793537
# 294                   0.967736                        2.375322
# 295                   0.981945                        2.705758
#
#      lowlevel.barkbands_crest.dmean2  lowlevel.barkbands_crest.dvar  \
# 0                           4.118659                       5.243636
# 1                           3.892377                       4.056502
# 2                           4.147055                       5.669414
# 3                           3.890606                       5.011153
# 4                           3.715736                       4.513411
# ..                               ...                            ...
# 291                         3.945108                       5.812252
# 292                         5.149584                       8.319780
# 293                         2.983498                       2.826975
# 294                         3.969078                       5.563212
# 295                         4.492238                       5.359109
#
#      lowlevel.barkbands_crest.dvar2  lowlevel.barkbands_crest.max  ...  \
# 0                         14.063597                     26.688347  ...
# 1                         10.908409                     25.141388  ...
# 2                         14.551494                     26.319483  ...
# 3                         12.956815                     24.700670  ...
# 4                         11.102341                     23.834007  ...
# ..                              ...                           ...  ...
# 291                       14.684026                     24.004417  ...
# 292                       20.000862                     24.849039  ...
# 293                        8.117479                     21.265247  ...
# 294                       15.381688                     21.387815  ...
# 295                       15.545798                     19.885136  ...
#
#      metadata.version.essentia_git_sha  metadata.version.extractor  \
# 0      v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# 1      v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# 2      v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# 3      v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# 4      v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# ..                                 ...                         ...
# 291    v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# 292    v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# 293    v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# 294    v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
# 295    v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
#
#      tonal.chords_key  tonal.chords_scale  tonal.key_edma.key  \
# 0                   D               major                   D
# 1                   C               minor                   C
# 2                   G               major                   G
# 3                   A               major                   D
# 4                   E               major                   E
# ..                ...                 ...                 ...
# 291                 A               major                   A
# 292                 G               major                   G
# 293                 D               minor                   D
# 294                 C               major                   C
# 295                Eb               minor                   A
#
#      tonal.key_edma.scale  tonal.key_krumhansl.key  tonal.key_krumhansl.scale  \
# 0                   major                        D                      major
# 1                   minor                        C                      minor
# 2                   major                        G                      major
# 3                   minor                        D                      minor
# 4                   major                        E                      major
# ..                    ...                      ...                        ...
# 291                 minor                        A                      minor
# 292                 minor                        G                      minor
# 293                 minor                        D                      minor
# 294                 major                        C                      major
# 295                 minor                        A                      minor
#
#      tonal.key_temperley.key  tonal.key_temperley.scale
# 0                          D                      major
# 1                          C                      minor
# 2                          G                      major
# 3                          D                      minor
# 4                          E                      major
# ..                       ...                        ...
# 291                        A                      minor
# 292                        G                      minor
# 293                        D                      minor
# 294                        C                      major
# 295                        A                      minor
#
# [296 rows x 581 columns]

# %%
# Pretend to keep only VA values - Used dummy variables instead
df_combined["valence_pred"] = np.random.randn(df_combined.shape[0])
df_combined["arousal_pred"] = np.random.randn(df_combined.shape[0])
display(df_combined)
# Out:
#      song_id general_genre                music                   singer  \
# 0        874         indie       The Privateers              Andrew Bird
# 1        812          jazz  Night Of The Iguana  The Cinematic Orchestra
# 2        941          rock           You And Me          Plain White T's
# 3        739         metal       Planet Caravan            Black Sabbath
# 4         70        reggae  No Creo En El Jamas                   Juanes
# ..       ...           ...                  ...                      ...
# 291       47          rock            The Stomp                The Hives
# 292      529       hip-hop    Where The Hood At                      DMX
# 293      875   alternative          Sullen Girl              Fiona Apple
# 294      946         metal   Ride The Lightning                Metallica
# 295      717          rock      I'm Not In Love           Charly García
#
#      lowlevel.average_loudness  lowlevel.barkbands_crest.dmean  \
# 0                     0.392642                        2.495658
# 1                     0.933627                        2.397552
# 2                     0.973347                        2.531084
# 3                     0.957888                        2.358258
# 4                     0.954137                        2.347313
# ..                         ...                             ...
# 291                   0.971516                        2.380748
# 292                   0.971770                        3.323876
# 293                   0.975494                        1.793537
# 294                   0.967736                        2.375322
# 295                   0.981945                        2.705758
#
#      lowlevel.barkbands_crest.dmean2  lowlevel.barkbands_crest.dvar  \
# 0                           4.118659                       5.243636
# 1                           3.892377                       4.056502
# 2                           4.147055                       5.669414
# 3                           3.890606                       5.011153
# 4                           3.715736                       4.513411
# ..                               ...                            ...
# 291                         3.945108                       5.812252
# 292                         5.149584                       8.319780
# 293                         2.983498                       2.826975
# 294                         3.969078                       5.563212
# 295                         4.492238                       5.359109
#
#      lowlevel.barkbands_crest.dvar2  lowlevel.barkbands_crest.max  ...  \
# 0                         14.063597                     26.688347  ...
# 1                         10.908409                     25.141388  ...
# 2                         14.551494                     26.319483  ...
# 3                         12.956815                     24.700670  ...
# 4                         11.102341                     23.834007  ...
# ..                              ...                           ...  ...
# 291                       14.684026                     24.004417  ...
# 292                       20.000862                     24.849039  ...
# 293                        8.117479                     21.265247  ...
# 294                       15.381688                     21.387815  ...
# 295                       15.545798                     19.885136  ...
#
#      tonal.chords_key  tonal.chords_scale  tonal.key_edma.key  \
# 0                   D               major                   D
# 1                   C               minor                   C
# 2                   G               major                   G
# 3                   A               major                   D
# 4                   E               major                   E
# ..                ...                 ...                 ...
# 291                 A               major                   A
# 292                 G               major                   G
# 293                 D               minor                   D
# 294                 C               major                   C
# 295                Eb               minor                   A
#
#      tonal.key_edma.scale  tonal.key_krumhansl.key  tonal.key_krumhansl.scale  \
# 0                   major                        D                      major
# 1                   minor                        C                      minor
# 2                   major                        G                      major
# 3                   minor                        D                      minor
# 4                   major                        E                      major
# ..                    ...                      ...                        ...
# 291                 minor                        A                      minor
# 292                 minor                        G                      minor
# 293                 minor                        D                      minor
# 294                 major                        C                      major
# 295                 minor                        A                      minor
#
#      tonal.key_temperley.key  tonal.key_temperley.scale  valence_pred  \
# 0                          D                      major      1.561614
# 1                          C                      minor     -1.613583
# 2                          G                      major     -0.800255
# 3                          D                      minor      1.466953
# 4                          E                      major     -0.714615
# ..                       ...                        ...           ...
# 291                        A                      minor     -0.160364
# 292                        G                      minor     -1.738442
# 293                        D                      minor      0.604298
# 294                        C                      major      1.105372
# 295                        A                      minor      2.213341
#
#      arousal_pred
# 0        0.431368
# 1       -1.390048
# 2       -0.237850
# 3       -0.044559
# 4        0.913900
# ..            ...
# 291      1.405267
# 292      0.767901
# 293      1.930051
# 294      0.389298
# 295     -0.356204
#
# [296 rows x 583 columns]

# %%
df_va = df_combined[["valence_pred", "arousal_pred"]].copy()
display(df_va.values.tolist())
# Out:
# [[1.5616135311733512, 0.4313682079314598],
#  [-1.6135830616948528, -1.3900484057095837],
#  [-0.8002553704286894, -0.23784962244836902],
#  [1.466953448566375, -0.0445590506253277],
#  [-0.7146154332107751, 0.9139002180695679],
#  [0.5929799682835929, 0.26953936685876295],
#  [-0.41663276636171026, 0.30324128650361726],
#  [0.9006214634948152, -0.4512937972844698],
#  [-0.3324584972053156, 0.45088099534712117],
#  [0.9588675968943076, 1.6620741583214076],
#  [-1.9407469205313612, 1.6927267306144376],
#  [-1.9104231105553842, 1.179672467338831],
#  [0.4002395457434478, -1.744934694609595],
#  [-0.3654172616836193, -0.48480787416137217],
#  [1.3271271934766782, 0.9275375486017436],
#  [-0.2631866597456472, -0.3840371530133859],
#  [0.7530082064758642, 1.1385014508791926],
#  [-1.3160351085119684, 0.6605815305281982],
#  [-0.4153399832702466, -0.35609413383115557],
#  [-0.005020792561050923, -0.3847882506989781],
#  [0.7114305595178242, -0.007361435431717674],
#  [0.10800926794939848, 0.27372727033959343],
#  [0.4238391803691664, -0.8014592272394752],
#  [-0.2378811386161967, -1.2348803934535526],
#  [-0.27197682347205576, 0.013358308441338238],
#  [1.1071931862920985, 1.1100881054405844],
#  [-1.7624686366235602, 0.14502831484057313],
#  [0.8984119660577767, 0.4937954368564535],
#  [1.1866012150096221, 0.4441214434204448],
#  [-0.6671626022957857, -0.5158252912918542],
#  [-0.16319883275588482, -1.1031899835046297],
#  [0.6118238852742751, 1.1912262662448443],
#  [-0.6741518333721297, 1.0285806593800042],
#  [-0.6963999443513902, -0.04905802970192447],
#  [1.0734185296062477, 0.6451040182599556],
#  [0.47641573093697864, -0.6325408571487624],
#  [0.3349866761734418, -0.8822896755723336],
#  [0.2135116739108471, 1.351772502971793],
#  [0.1916908721408286, 0.023428351998583268],
#  [-0.11344965361306812, 0.841502892602418],
#  [-0.8773784905238536, 0.45263372070670005],
#  [-0.6829344928434927, 0.452234882999452],
#  [-1.4171210750573016, -0.5133296605581429],
#  [0.1864453795334613, 0.37815339652256375],
#  [-1.4531600018372202, 1.378039188801043],
#  [-0.28445272822005985, 0.505157040258467],
#  [1.3475675881230231, 0.8501373335293573],
#  [1.2212892086406282, 0.31632027179943595],
#  [2.3080069684920845, -1.7286379482281855],
#  [0.18299163184023975, 0.8249840046126492],
#  [1.009655717242356, -0.6813860811401027],
#  [1.0504748153815469, 0.020842373310811752],
#  [-0.47721001993962486, -0.21212918001277184],
#  [1.6964689058063926, 0.953023500334707],
#  [0.24330983350564392, -1.0127280401834549],
#  [-0.7899436825483721, 0.10339474139472511],
#  [-0.767229451676781, 0.5582778966263442],
#  [-0.06188667839495355, -1.0246069499217705],
#  [1.5154463141455383, 0.877924310828167],
#  [1.3055260541347498, 0.23602535189074925],
#  [-0.41721288303711085, 0.15385426265422006],
#  [0.07360906516247791, 1.1206292670352707],
#  [0.7656948890252555, -0.1775949320019881],
#  [0.10936355779129427, 1.111106756083399],
#  [-1.7449411533753716, -0.506732322053381],
#  [0.044296162776742504, -0.283580413112154],
#  [-0.6372610494282294, -2.248037668952455],
#  [0.9944268651711557, 0.8851439827402632],
#  [1.0657006553268504, 0.7405082243716719],
#  [-0.32365459785168416, 1.1049049213098745],
#  [-1.4391863758695984, -0.5644879281292922],
#  [0.0008888714982831982, 1.6202587026368627],
#  [-1.4214154188615233, -0.7596657730291911],
#  [0.46229041110907626, 1.0977993416143776],
#  [2.2512068996089685, -0.5463635767671674],
#  [-0.39863362079935877, 1.5357466866637113],
#  [-1.3275890126823584, 0.6830631801568884],
#  [-0.12979430418645685, -1.2718132392591628],
#  [-0.8669757758916327, 0.3723046187997173],
#  [-0.4437322409850923, 0.08576062132641439],
#  [-0.527192178543592, -0.9140517524787566],
#  [0.6509437861948603, 1.7803236921014811],
#  [-0.5735381259279348, 0.6579416220813833],
#  [-0.6200358798790572, 0.862327016419934],
#  [1.378889322512825, 1.1292384742543653],
#  [0.36986495283508, 0.6547330843172545],
#  [-0.013279869073513048, 0.3808639853629884],
#  [-0.02189362538633206, 0.9988754581895232],
#  [1.1214764817011147, -1.0473816785611119],
#  [1.828734662428456, -0.46899318824374764],
#  [-0.40317716432736594, -0.40957457731332264],
#  [-0.35773405515684437, -1.0607047981713162],
#  [1.0609048075292964, -0.28249672669186005],
#  [0.260958141654606, -1.2374805156839428],
#  [-0.5059796737698153, -1.365117582736568],
#  [1.608184325788101, -1.689950582659561],
#  [0.9440701109866964, 0.33090676577630246],
#  [-1.6184357280712514, 1.1893732235133303],
#  [0.08342169085824347, -0.4252951614801871],
#  [0.08175676314861634, 1.4350730593053875],
#  [0.2161708765282691, 2.318829212407116],
#  [0.7145384623986099, -0.41306862921515547],
#  [0.6098977456895041, -1.4919943511451979],
#  [-0.6582888243524542, -1.4404393531331225],
#  [-0.08705998253882044, 0.855789472544588],
#  [-1.7557295154564088, 0.10537803116440222],
#  [-0.16869337784681898, -1.8672049104155903],
#  [-0.5708155403036537, -1.3586916792952553],
#  [-0.5918363848695214, 0.051057186545578344],
#  [0.49012251706833526, 0.8480556515404618],
#  [1.0608157999995218, -0.4901601861147478],
#  [-0.8612003207976465, 0.6659059865211804],
#  [-1.541145666815725, 0.14140389715357612],
#  [-1.5364406220524576, 1.2961515669590504],
#  [-0.7104392054037483, 0.589195242880857],
#  [-0.16975117225401898, -1.149726298815852],
#  [-0.6686737157262662, -0.18534651269014973],
#  [-1.685189937710705, 0.9797181698891413],
#  [-0.023610756729441063, 0.35773085546533157],
#  [-0.900792583406969, -0.37075990037784856],
#  [-1.2036244545477421, 0.22663494231651932],
#  [-1.0157302427218073, -1.8196853958218067],
#  [0.054163636370845744, 1.5084969236017034],
#  [-0.5466577820121844, 0.0735253900122653],
#  [-1.1219258974696598, 0.44416049819276104],
#  [0.3579974178262423, -1.1474351497954505],
#  [-0.5232020322189558, 0.4919155897636823],
#  [0.060875960499082095, -0.8719329209414096],
#  [0.9830250408183039, 1.8218836187612137],
#  [1.8351960622876307, -0.7486190534716615],
#  [1.1520906029903606, 1.1011296354378453],
#  [1.1952330308442018, -0.6611675625975915],
#  [-1.8845890527775548, -0.23724040812282804],
#  [0.2895918862803308, -0.965519569413587],
#  [0.2854833910461482, -1.4446670506443318],
#  [-1.6680089444041628, -0.7358746917546996],
#  [0.5847779846434082, 2.0393138051503166],
#  [0.18550917446015933, 0.028419362539744027],
#  [-1.6605897994589278, -0.3056339566895262],
#  [1.0184506919068008, -1.3516322757912203],
#  [0.7798823834516387, 0.09291209956549669],
#  [-0.7009399241909124, 1.6582284947058417],
#  [-0.17656844173627168, -1.2957045122115403],
#  [1.2659901648090295, 1.3356218509283442],
#  [0.48269053640248455, 0.24551510286342765],
#  [1.2935127426492454, -0.9756301084205258],
#  [1.1603567767783811, 0.06826590160502999],
#  [-0.9355376058179505, 0.2905576636775877],
#  [1.5740771663932107, -1.416343626995089],
#  [1.9803500075082396, -0.12326249058177452],
#  [-0.7731225587357077, -0.20760979252323356],
#  [0.9396255946615736, 0.21531186715596962],
#  [1.3473843551101796, -0.5447375656460518],
#  [0.09898257095146977, -1.0938748019818803],
#  [0.7854230991799878, 0.7961446587372226],
#  [-0.6316276461538235, -0.1280611585893583],
#  [2.494818518300504, 0.12724008323692707],
#  [-0.7204402190116421, -1.6452975379616352],
#  [-0.4771580847174048, -0.6662153439194639],
#  [-1.3092649263403497, 0.06869471165183558],
#  [-0.7082997134421177, 0.7090700314877609],
#  [-1.4124473635660602, 2.4276527206309435],
#  [0.14351646503158977, 1.1420080391792047],
#  [-0.2994617464064643, -0.49729221289913256],
#  [-0.2623074985105312, -0.2875138226788227],
#  [-0.33771635894585766, -2.6038215006646945],
#  [0.6158079503413574, -3.22297465690811],
#  [0.9153396925924424, -1.8831788750920058],
#  [0.7632213240426472, -1.5099289711722734],
#  [1.345544122564608, 1.4121660555148143],
#  [-0.6990953740375231, 1.3746561293713944],
#  [0.3740207735747314, -1.0426800379115189],
#  [-1.11095768050171, 0.47874323045052686],
#  [-0.4814088059809708, 0.8268069639445155],
#  [0.7630519675097956, -0.5953014995632128],
#  [0.009113323863361233, 1.8229011643876942],
#  [-0.8961189762816323, -0.39672839954021877],
#  [0.18879972225791816, 1.201773181184825],
#  [-0.3321040837129157, -1.0267134714611732],
#  [0.2717538483267084, 0.0185337229163684],
#  [0.7486292228130432, -0.09996893486400485],
#  [0.04130945196316797, 1.1276961794562659],
#  [0.2338378784463987, -1.1097995899178925],
#  [0.07688865162760712, -1.0690714818056881],
#  [0.7704952005739251, -0.1940142224039442],
#  [0.2606595618145052, -0.5743377778656283],
#  [-1.3259496796563222, -0.9685266961257669],
#  [-1.2393932976743522, 0.7139032583870747],
#  [-0.15583004854998217, 0.5711786329917677],
#  [-1.7769260712988648, -0.25426411868809157],
#  [0.15775100034682082, 0.5832919457769355],
#  [-0.7049138094788222, 0.03049979350503866],
#  [-1.190075669315599, 1.5815013296297926],
#  [-0.012612667642621332, 0.9471933642959339],
#  [0.32349142663684477, 1.0366239159258803],
#  [1.744999076669236, -0.9282194119599563],
#  [0.16800220900529952, -1.417269921660995],
#  [-0.6814240326105636, -0.7939800163647732],
#  [0.6029409157806596, -0.50513363917456],
#  [-0.07953735369064369, 0.7894366050870781],
#  [0.2542652444191489, -0.5639960373556286],
#  [-0.2748623758094298, -0.2612845250629839],
#  [-1.4229086319371016, 1.6637524942811082],
#  [0.30568357262396467, -2.6889324280431404],
#  [-0.09336465453358699, -1.4384725964555904],
#  [-0.9035225947365877, -0.9274013398250444],
#  [1.0152774554566393, -1.120881826407003],
#  [-0.9515442089521988, 0.7339807356209319],
#  [-1.219979793242899, -1.0797492680626661],
#  [1.189338416540625, -2.407817550465507],
#  [0.3536957574753268, 0.2827991249803811],
#  [0.9217772793443942, -1.1338766392523902],
#  [-0.5246087094886283, -0.13734189679570596],
#  [-0.38219265854733553, -0.5349489280973718],
#  [-1.1487641065549186, -0.5965073555590216],
#  [-1.2075421522018241, 1.7660613880678542],
#  [0.3967360651254477, -0.37497284008193],
#  [-1.5761695128906819, 0.8668645232045423],
#  [-0.4911887323002782, 2.6030013041728135],
#  [-0.24153663871486372, 2.1553149762621358],
#  [-0.7113418720593104, 1.4780443060858424],
#  [1.7164145730198022, -1.1304025189466076],
#  [-1.5510185417219937, -1.5166340653344383],
#  [-0.7525495068700747, -0.32272986904849754],
#  [0.7157471168083426, 0.22915693224772068],
#  [0.608865761803516, -0.37325203151613656],
#  [-0.47954395865501054, 1.0609623370392134],
#  [-0.7787544327639021, 0.30479155151939613],
#  [0.2056666676812912, 0.6410898826969229],
#  [-0.8354940875489358, 0.43130932881694495],
#  [1.0629734004832339, -0.4475897889154831],
#  [-0.6476305899886153, -0.9390222251695312],
#  [-1.5769244755161238, 0.6151538377970651],
#  [-0.35826642788415547, 0.8898034031209981],
#  [-1.205179878836694, 1.452176678365991],
#  [-0.11554419820726924, -0.0649307657280125],
#  [1.9792840367843243, 0.5830000166177651],
#  [0.06072245181507436, 1.9909802764354743],
#  [0.27214943932443697, -0.5521819570916346],
#  [0.22910956150176015, 0.6730276158622753],
#  [-1.153857825850868, -1.035820188346634],
#  [-0.9132011055198825, 0.5382817246623516],
#  [-1.1817461923327297, 1.0846986824506681],
#  [0.927506347476463, 0.3169244478867348],
#  [0.5597727924761275, 0.06643985716492172],
#  [0.9398729729307924, -0.032201695569976437],
#  [1.6569212702899716, -1.447084989102765],
#  [-0.8774383123443602, 1.300830294029674],
#  [-0.668371269711935, -3.271345376529711],
#  [0.20758020100032526, 0.49898485831776707],
#  [-0.17824290208210666, 0.8555509538800146],
#  [1.0570845739486303, 0.7258036957564764],
#  [-0.91180472996727, -1.9855849949830118],
#  [-0.5486209201462671, 0.15408259263429644],
#  [-1.762973898873263, -0.5398787768502221],
#  [-0.022873621840887905, -1.4774392205376283],
#  [-0.5530488302782601, -0.9530050576033777],
#  [0.5475724108963714, 1.2089782912960965],
#  [0.27166739342270424, -0.9154408288181813],
#  [-0.0328230273340177, 0.4582755334486219],
#  [-1.2218662622176604, 1.3618611175262065],
#  [0.9942255223587579, 0.10887127248749479],
#  [0.5458817928463756, -1.2332226082130713],
#  [0.5841334350584385, 0.7238715586328645],
#  [0.12424780543303834, 0.8573141023302806],
#  [0.599130553973656, -0.4393066031792074],
#  [-0.3224539949243607, 0.7431910839432719],
#  [-0.42112787765564613, -0.06406276259738285],
#  [-1.2095434740848625, -0.8782612168377758],
#  [-0.20146832883750065, 0.778598980484165],
#  [0.04094293390538975, -1.5524345116087657],
#  [-0.11227006322459679, 0.9946736278776257],
#  [-1.1323484653721405, -0.8911949210303618],
#  [0.3199133571840623, 0.18894391394205962],
#  [0.641779569921594, -0.07719918654265223],
#  [-0.018224088039702362, -0.8041788246749194],
#  [0.9073657665238256, 0.42954112171397224],
#  [-0.14181206470174035, -0.4294814136385634],
#  [-0.03404799062186525, 0.8717442519049793],
#  [-0.37917215305597674, -0.7256399164609209],
#  [0.3081632228647942, 0.21106356932903567],
#  [0.18026858983849467, 0.9493591847424292],
#  [-0.3585843177796989, 1.8591336337329083],
#  [0.8786786995549901, 1.4582202551938335],
#  [-0.07036087428204318, -1.7148356875400819],
#  [-1.5462741363321095, 0.435081127984185],
#  [-0.9816401252599345, -1.2552162454849878],
#  [-1.4372595062664197, 2.174531962874052],
#  [-2.778589184244746, 0.11957502678767506],
#  [0.907779993156938, -0.04080643283403878],
#  [1.3225272577424074, -1.250188427147826],
#  [-0.1603640544188065, 1.4052671061699757],
#  [-1.738441943028353, 0.7679007754438605],
#  [0.6042981162580482, 1.930051064415533],
#  [1.1053722172127263, 0.38929810375817275],
#  [2.213340796396382, -0.35620409555180355]]

# %%
metadata = df_combined.columns.tolist()[1:4]
# print(metadata)
metadata_dicts = df_combined[metadata].to_dict('records')
# print(metadata_dicts)

# %%
song_ids = df_combined["song_id"].values.tolist()
print(song_ids)
# Out:
# [874, 812, 941, 739, 70, 987, 5, 300, 720, 266, 576, 6, 876, 360, 912, 74, 158, 239, 965, 276, 373, 550, 984, 905, 578, 170, 604, 204, 325, 361, 818, 268, 490, 258, 680, 506, 600, 26, 923, 699, 627, 558, 205, 17, 629, 594, 327, 13, 136, 673, 914, 175, 223, 532, 520, 14, 182, 480, 397, 634, 754, 120, 707, 23, 962, 514, 863, 422, 868, 790, 409, 995, 289, 544, 439, 414, 972, 297, 264, 826, 428, 727, 603, 649, 706, 126, 795, 192, 169, 591, 202, 372, 282, 822, 911, 24, 499, 947, 209, 228, 283, 329, 208, 977, 168, 796, 20, 333, 149, 934, 97, 341, 174, 975, 111, 759, 269, 723, 144, 384, 994, 429, 954, 222, 835, 843, 390, 621, 104, 672, 19, 117, 786, 418, 440, 886, 925, 320, 652, 936, 411, 90, 207, 897, 807, 216, 736, 731, 57, 780, 793, 924, 465, 46, 719, 565, 709, 752, 937, 516, 375, 951, 142, 883, 67, 469, 388, 619, 555, 356, 609, 635, 548, 996, 878, 518, 442, 367, 726, 957, 741, 76, 100, 784, 659, 43, 872, 206, 676, 363, 22, 974, 285, 81, 743, 816, 916, 523, 9, 677, 132, 233, 364, 862, 491, 493, 434, 279, 915, 588, 58, 920, 602, 156, 87, 471, 848, 757, 598, 955, 839, 109, 768, 243, 8, 945, 148, 37, 908, 667, 85, 508, 171, 108, 873, 541, 52, 917, 312, 153, 820, 195, 349, 789, 89, 517, 510, 742, 638, 319, 257, 613, 689, 427, 791, 451, 315, 303, 712, 332, 900, 275, 309, 716, 344, 99, 744, 28, 468, 956, 571, 910, 524, 697, 639, 461, 507, 114, 504, 273, 776, 62, 898, 172, 761, 562, 342, 395, 245, 597, 814, 47, 529, 875, 946, 717]

# %%
song_ids_str = [str(x) for x in song_ids]
print(song_ids_str)
# Out:
# ['874', '812', '941', '739', '70', '987', '5', '300', '720', '266', '576', '6', '876', '360', '912', '74', '158', '239', '965', '276', '373', '550', '984', '905', '578', '170', '604', '204', '325', '361', '818', '268', '490', '258', '680', '506', '600', '26', '923', '699', '627', '558', '205', '17', '629', '594', '327', '13', '136', '673', '914', '175', '223', '532', '520', '14', '182', '480', '397', '634', '754', '120', '707', '23', '962', '514', '863', '422', '868', '790', '409', '995', '289', '544', '439', '414', '972', '297', '264', '826', '428', '727', '603', '649', '706', '126', '795', '192', '169', '591', '202', '372', '282', '822', '911', '24', '499', '947', '209', '228', '283', '329', '208', '977', '168', '796', '20', '333', '149', '934', '97', '341', '174', '975', '111', '759', '269', '723', '144', '384', '994', '429', '954', '222', '835', '843', '390', '621', '104', '672', '19', '117', '786', '418', '440', '886', '925', '320', '652', '936', '411', '90', '207', '897', '807', '216', '736', '731', '57', '780', '793', '924', '465', '46', '719', '565', '709', '752', '937', '516', '375', '951', '142', '883', '67', '469', '388', '619', '555', '356', '609', '635', '548', '996', '878', '518', '442', '367', '726', '957', '741', '76', '100', '784', '659', '43', '872', '206', '676', '363', '22', '974', '285', '81', '743', '816', '916', '523', '9', '677', '132', '233', '364', '862', '491', '493', '434', '279', '915', '588', '58', '920', '602', '156', '87', '471', '848', '757', '598', '955', '839', '109', '768', '243', '8', '945', '148', '37', '908', '667', '85', '508', '171', '108', '873', '541', '52', '917', '312', '153', '820', '195', '349', '789', '89', '517', '510', '742', '638', '319', '257', '613', '689', '427', '791', '451', '315', '303', '712', '332', '900', '275', '309', '716', '344', '99', '744', '28', '468', '956', '571', '910', '524', '697', '639', '461', '507', '114', '504', '273', '776', '62', '898', '172', '761', '562', '342', '395', '245', '597', '814', '47', '529', '875', '946', '717']

# %% [markdown]
# ## Chroma Vector Database

# %%
client = chromadb.Client()

## Persistent store
# client = chromadb.PersistentClient(path="./db/")

client.heartbeat()
# Out:
# 1712281638316949000

# %%
# https://docs.trychroma.com/usage-guide#changing-the-distance-function
collection = client.create_collection(
        name="SiTunes_datasetv2",
        metadata={"hnsw:space": "l2"} # "l2", "ip" or "cosine"
    )

# %%
collection.add(
    documents=[f"doc{i}" for i in range(df_combined.shape[0])], # file_path
    embeddings=df_va.values.tolist(), # VA embeddings
    metadatas=metadata_dicts, # song_names
    ids=song_ids_str # song_id from SiTunes dataset
)

# %%
collection.query(
    query_embeddings=[[1, 1]], # search by embeddings
    n_results=1, # number of results
    # where={"metadata_field": "is_equal_to_this"}, # filter on metadata, e.g. genre
    # where_document={"$contains":"search_string"} # filter on file path???
    include=["distances", "metadatas", "embeddings", "documents", "uris", "data"] # Need to include all relevant parameters to show
)
# Out:
# {'ids': [['170']],
#  'distances': [[8.344650268554688e-07]],
#  'metadatas': [[{'general_genre': 'rock',
#     'music': 'With Twilight As My Guide',
#     'singer': 'The Mars Volta'}]],
#  'embeddings': [[[1.1071932315826416, 1.1100881099700928]]],
#  'documents': [['doc25']],
#  'uris': [[None]],
#  'data': None}

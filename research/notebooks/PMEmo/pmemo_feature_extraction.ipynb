# %% [markdown]
# # PMEmo Dataset - Feature Extraction

# %% [markdown]
# # Done on local computer

# %% [markdown]
# ## openSMILE

# %% [markdown]
# Import relevant libraries

# %%
import pandas as pd

import sys
sys.path.insert(1, '../../utils')
from paths import *

# %%
import os
from joblib import Parallel, delayed

# %% [markdown]
# ### ComParE 2016 feature set

# %%
import opensmile
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.ComParE_2016,
    feature_level=opensmile.FeatureLevel.Functionals,
)

# %% [markdown]
# Prepare to extract features from all audio files

# %%
song_ids = []

# Iterate through all files in the directory
for filename in os.listdir(PMEMO_AUDIO_FOLDER):
    # Check if the path is a file (not a subdirectory)
    if os.path.isfile(os.path.join(PMEMO_AUDIO_FOLDER, filename)):
        song_ids.append(int(filename[:-4]))

song_ids.sort()

# Define a function to extract features for a single song ID
def extract_features(song_id):
    print(f'Extracting features from song_id: {song_id}')
    df_opensmile_temp = smile.process_file(f'{PMEMO_AUDIO_FOLDER}/{song_id}.mp3')
    return df_opensmile_temp

# %% [markdown]
# Extract openSMILE features using the ComParE_2016 feature set

# %%
# Parallelize the feature extraction process for all song IDs
# dfs = Parallel(n_jobs=-1)(delayed(extract_features)(song_id) for song_id in song_ids)
dfs = Parallel(n_jobs=-1)(delayed(extract_features)(song_id) for song_id in song_ids)

# Concatenate the extracted DataFrames
df_opensmile_compare_2016 = pd.concat(dfs)

# Add the 'song_id' column
df_opensmile_compare_2016.insert(0, column='song_id', value=song_ids)
df_opensmile_compare_2016.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
df_opensmile_compare_2016
# Out:
# Extracting features from song_id: 5
# Extracting features from song_id: 7
# Extracting features from song_id: 12
# Extracting features from song_id: 4
# Extracting features from song_id: 6
# Extracting features from song_id: 8
# Extracting features from song_id: 11
# Extracting features from song_id: 10
# Extracting features from song_id: 9
# Extracting features from song_id: 13
# Extracting features from song_id: 1
# Extracting features from song_id: 14
# Extracting features from song_id: 15
# Extracting features from song_id: 16
# Extracting features from song_id: 17
# Extracting features from song_id: 18
# Extracting features from song_id: 19
# Extracting features from song_id: 20
# Extracting features from song_id: 21
# Extracting features from song_id: 23
# Extracting features from song_id: 25
# Extracting features from song_id: 26
# Extracting features from song_id: 28
# Extracting features from song_id: 29
# Extracting features from song_id: 30
# Extracting features from song_id: 31
# Extracting features from song_id: 32
# Extracting features from song_id: 33
# Extracting features from song_id: 34
# Extracting features from song_id: 35
# Extracting features from song_id: 37
# Extracting features from song_id: 38
# Extracting features from song_id: 39
# Extracting features from song_id: 40
# Extracting features from song_id: 42
# Extracting features from song_id: 43
# Extracting features from song_id: 44
# Extracting features from song_id: 46
# Extracting features from song_id: 47
# Extracting features from song_id: 48
# Extracting features from song_id: 49
# Extracting features from song_id: 50
# Extracting features from song_id: 51
# Extracting features from song_id: 52
# Extracting features from song_id: 54
# Extracting features from song_id: 55
# Extracting features from song_id: 56
# Extracting features from song_id: 57
# Extracting features from song_id: 58
# Extracting features from song_id: 59
# Extracting features from song_id: 60
# Extracting features from song_id: 61
# Extracting features from song_id: 63
# Extracting features from song_id: 64
# Extracting features from song_id: 65
# Extracting features from song_id: 66
# Extracting features from song_id: 67
# Extracting features from song_id: 68
# Extracting features from song_id: 69
# Extracting features from song_id: 70
# Extracting features from song_id: 71
# Extracting features from song_id: 72
# Extracting features from song_id: 73
# Extracting features from song_id: 74
# Extracting features from song_id: 75
# Extracting features from song_id: 76
# Extracting features from song_id: 78
# Extracting features from song_id: 79
# Extracting features from song_id: 80
# Extracting features from song_id: 81
# Extracting features from song_id: 83
# Extracting features from song_id: 84
# Extracting features from song_id: 85
# Extracting features from song_id: 86
# Extracting features from song_id: 87
# Extracting features from song_id: 88
# Extracting features from song_id: 89
# Extracting features from song_id: 90
# Extracting features from song_id: 91
# Extracting features from song_id: 92
# Extracting features from song_id: 93
# Extracting features from song_id: 94
# Extracting features from song_id: 95
# Extracting features from song_id: 96
# Extracting features from song_id: 97
# Extracting features from song_id: 98
# Extracting features from song_id: 99
# Extracting features from song_id: 100
# Extracting features from song_id: 101
# Extracting features from song_id: 102
# Extracting features from song_id: 103
# Extracting features from song_id: 104
# Extracting features from song_id: 105
# Extracting features from song_id: 106
# Extracting features from song_id: 107
# Extracting features from song_id: 108
# Extracting features from song_id: 109
# Extracting features from song_id: 110
# Extracting features from song_id: 113
# Extracting features from song_id: 114
# Extracting features from song_id: 115
# Extracting features from song_id: 116
# Extracting features from song_id: 117
# Extracting features from song_id: 118
# Extracting features from song_id: 119
# Extracting features from song_id: 120
# Extracting features from song_id: 123
# Extracting features from song_id: 124
# Extracting features from song_id: 126
# Extracting features from song_id: 127
# Extracting features from song_id: 128
# Extracting features from song_id: 132
# Extracting features from song_id: 133
# Extracting features from song_id: 134
# Extracting features from song_id: 135
# Extracting features from song_id: 136
# Extracting features from song_id: 137
# Extracting features from song_id: 138
# Extracting features from song_id: 139
# Extracting features from song_id: 140
# Extracting features from song_id: 141
# Extracting features from song_id: 142
# Extracting features from song_id: 143
# Extracting features from song_id: 144
# Extracting features from song_id: 145
# Extracting features from song_id: 146
# Extracting features from song_id: 147
# Extracting features from song_id: 148
# Extracting features from song_id: 149
# Extracting features from song_id: 150
# Extracting features from song_id: 151
# Extracting features from song_id: 152
# Extracting features from song_id: 153
# Extracting features from song_id: 156
# Extracting features from song_id: 157
# Extracting features from song_id: 158
# Extracting features from song_id: 159
# Extracting features from song_id: 160
# Extracting features from song_id: 161
# Extracting features from song_id: 162
# Extracting features from song_id: 165
# Extracting features from song_id: 166
# Extracting features from song_id: 167
# Extracting features from song_id: 168
# Extracting features from song_id: 169
# Extracting features from song_id: 170
# Extracting features from song_id: 171
# Extracting features from song_id: 172
# Extracting features from song_id: 174
# Extracting features from song_id: 175
# Extracting features from song_id: 176
# Extracting features from song_id: 177
# Extracting features from song_id: 179
# Extracting features from song_id: 180
# Extracting features from song_id: 181
# Extracting features from song_id: 184
# Extracting features from song_id: 185
# Extracting features from song_id: 186
# Extracting features from song_id: 187
# Extracting features from song_id: 188
# Extracting features from song_id: 189
# Extracting features from song_id: 191
# Extracting features from song_id: 192
# Extracting features from song_id: 196
# Extracting features from song_id: 197
# Extracting features from song_id: 198
# Extracting features from song_id: 199
# Extracting features from song_id: 200
# Extracting features from song_id: 201
# Extracting features from song_id: 202
# Extracting features from song_id: 203
# Extracting features from song_id: 204
# Extracting features from song_id: 205
# Extracting features from song_id: 206
# Extracting features from song_id: 207
# Extracting features from song_id: 209
# Extracting features from song_id: 210
# Extracting features from song_id: 211
# Extracting features from song_id: 212
# Extracting features from song_id: 213
# Extracting features from song_id: 215
# Extracting features from song_id: 216
# Extracting features from song_id: 217
# Extracting features from song_id: 219
# Extracting features from song_id: 220
# Extracting features from song_id: 221
# Extracting features from song_id: 222
# Extracting features from song_id: 224
# Extracting features from song_id: 225
# Extracting features from song_id: 226
# Extracting features from song_id: 227
# Extracting features from song_id: 228
# Extracting features from song_id: 229
# Extracting features from song_id: 230
# Extracting features from song_id: 231
# Extracting features from song_id: 232
# Extracting features from song_id: 233
# Extracting features from song_id: 234
# Extracting features from song_id: 235
# Extracting features from song_id: 236
# Extracting features from song_id: 237
# Extracting features from song_id: 238
# Extracting features from song_id: 239
# Extracting features from song_id: 241
# Extracting features from song_id: 242
# Extracting features from song_id: 244
# Extracting features from song_id: 249
# Extracting features from song_id: 251
# Extracting features from song_id: 252
# Extracting features from song_id: 253
# Extracting features from song_id: 257
# Extracting features from song_id: 258
# Extracting features from song_id: 260
# Extracting features from song_id: 263
# Extracting features from song_id: 264
# Extracting features from song_id: 265
# Extracting features from song_id: 267
# Extracting features from song_id: 269
# Extracting features from song_id: 273
# Extracting features from song_id: 275
# Extracting features from song_id: 276
# Extracting features from song_id: 277
# Extracting features from song_id: 278
# Extracting features from song_id: 279
# Extracting features from song_id: 280
# Extracting features from song_id: 282
# Extracting features from song_id: 283
# Extracting features from song_id: 284
# Extracting features from song_id: 285
# Extracting features from song_id: 287
# Extracting features from song_id: 291
# Extracting features from song_id: 292
# Extracting features from song_id: 293
# Extracting features from song_id: 294
# Extracting features from song_id: 295
# Extracting features from song_id: 296
# Extracting features from song_id: 297
# Extracting features from song_id: 298
# Extracting features from song_id: 299
# Extracting features from song_id: 300
# Extracting features from song_id: 301
# Extracting features from song_id: 302
# Extracting features from song_id: 303
# Extracting features from song_id: 304
# Extracting features from song_id: 305
# Extracting features from song_id: 306
# Extracting features from song_id: 307
# Extracting features from song_id: 308
# Extracting features from song_id: 309
# Extracting features from song_id: 310
# Extracting features from song_id: 311
# Extracting features from song_id: 312
# Extracting features from song_id: 313
# Extracting features from song_id: 314
# Extracting features from song_id: 315
# Extracting features from song_id: 316
# Extracting features from song_id: 317
# Extracting features from song_id: 318
# Extracting features from song_id: 319
# Extracting features from song_id: 320
# Extracting features from song_id: 321
# Extracting features from song_id: 323
# Extracting features from song_id: 324
# Extracting features from song_id: 325
# Extracting features from song_id: 326
# Extracting features from song_id: 327
# Extracting features from song_id: 329
# Extracting features from song_id: 331
# Extracting features from song_id: 332
# Extracting features from song_id: 333
# Extracting features from song_id: 334
# Extracting features from song_id: 336
# Extracting features from song_id: 337
# Extracting features from song_id: 338
# Extracting features from song_id: 339
# Extracting features from song_id: 341
# Extracting features from song_id: 342
# Extracting features from song_id: 343
# Extracting features from song_id: 347
# Extracting features from song_id: 348
# Extracting features from song_id: 349
# Extracting features from song_id: 350
# Extracting features from song_id: 351
# Extracting features from song_id: 352
# Extracting features from song_id: 353
# Extracting features from song_id: 354
# Extracting features from song_id: 355
# Extracting features from song_id: 356
# Extracting features from song_id: 358
# Extracting features from song_id: 359
# Extracting features from song_id: 360
# Extracting features from song_id: 361
# Extracting features from song_id: 362
# Extracting features from song_id: 364
# Extracting features from song_id: 366
# Extracting features from song_id: 367
# Extracting features from song_id: 368
# Extracting features from song_id: 370
# Extracting features from song_id: 371
# Extracting features from song_id: 372
# Extracting features from song_id: 373
# Extracting features from song_id: 375
# Extracting features from song_id: 376
# Extracting features from song_id: 379
# Extracting features from song_id: 381
# Extracting features from song_id: 382
# Extracting features from song_id: 383
# Extracting features from song_id: 384
# Extracting features from song_id: 385
# Extracting features from song_id: 386
# Extracting features from song_id: 388
# Extracting features from song_id: 389
# Extracting features from song_id: 391
# Extracting features from song_id: 392
# Extracting features from song_id: 393
# Extracting features from song_id: 394
# Extracting features from song_id: 395
# Extracting features from song_id: 396
# Extracting features from song_id: 397
# Extracting features from song_id: 398
# Extracting features from song_id: 399
# Extracting features from song_id: 401
# Extracting features from song_id: 402
# Extracting features from song_id: 403
# Extracting features from song_id: 404
# Extracting features from song_id: 405
# Extracting features from song_id: 407
# Extracting features from song_id: 408
# Extracting features from song_id: 409
# Extracting features from song_id: 410
# Extracting features from song_id: 411
# Extracting features from song_id: 412
# Extracting features from song_id: 413
# Extracting features from song_id: 414
# Extracting features from song_id: 415
# Extracting features from song_id: 417
# Extracting features from song_id: 418
# Extracting features from song_id: 419
# Extracting features from song_id: 420
# Extracting features from song_id: 421
# Extracting features from song_id: 423
# Extracting features from song_id: 424
# Extracting features from song_id: 425
# Extracting features from song_id: 426
# Extracting features from song_id: 427
# Extracting features from song_id: 428
# Extracting features from song_id: 429
# Extracting features from song_id: 431
# Extracting features from song_id: 432
# Extracting features from song_id: 433
# Extracting features from song_id: 434
# Extracting features from song_id: 435
# Extracting features from song_id: 436
# Extracting features from song_id: 437
# Extracting features from song_id: 438
# Extracting features from song_id: 439
# Extracting features from song_id: 440
# Extracting features from song_id: 441
# Extracting features from song_id: 442
# Extracting features from song_id: 443
# Extracting features from song_id: 444
# Extracting features from song_id: 445
# Extracting features from song_id: 446
# Extracting features from song_id: 447
# Extracting features from song_id: 448
# Extracting features from song_id: 449
# Extracting features from song_id: 450
# Extracting features from song_id: 451
# Extracting features from song_id: 452
# Extracting features from song_id: 454
# Extracting features from song_id: 455
# Extracting features from song_id: 456
# Extracting features from song_id: 457
# Extracting features from song_id: 458
# Extracting features from song_id: 459
# Extracting features from song_id: 460
# Extracting features from song_id: 461
# Extracting features from song_id: 462
# Extracting features from song_id: 463
# Extracting features from song_id: 464
# Extracting features from song_id: 465
# Extracting features from song_id: 466
# Extracting features from song_id: 468
# Extracting features from song_id: 469
# Extracting features from song_id: 470
# Extracting features from song_id: 471
# Extracting features from song_id: 472
# Extracting features from song_id: 476
# Extracting features from song_id: 477
# Extracting features from song_id: 478
# Extracting features from song_id: 479
# Extracting features from song_id: 480
# Extracting features from song_id: 481
# Extracting features from song_id: 482
# Extracting features from song_id: 483
# Extracting features from song_id: 484
# Extracting features from song_id: 485
# Extracting features from song_id: 486
# Extracting features from song_id: 487
# Extracting features from song_id: 488
# Extracting features from song_id: 489
# Extracting features from song_id: 490
# Extracting features from song_id: 491
# Extracting features from song_id: 492
# Extracting features from song_id: 493
# Extracting features from song_id: 494
# Extracting features from song_id: 495
# Extracting features from song_id: 496
# Extracting features from song_id: 499
# Extracting features from song_id: 500
# Extracting features from song_id: 501
# Extracting features from song_id: 503
# Extracting features from song_id: 504
# Extracting features from song_id: 505
# Extracting features from song_id: 506
# Extracting features from song_id: 507
# Extracting features from song_id: 508
# Extracting features from song_id: 510
# Extracting features from song_id: 511
# Extracting features from song_id: 512
# Extracting features from song_id: 514
# Extracting features from song_id: 515
# Extracting features from song_id: 516
# Extracting features from song_id: 517
# Extracting features from song_id: 518
# Extracting features from song_id: 519
# Extracting features from song_id: 520
# Extracting features from song_id: 521
# Extracting features from song_id: 522
# Extracting features from song_id: 523
# Extracting features from song_id: 524
# Extracting features from song_id: 525
# Extracting features from song_id: 526
# Extracting features from song_id: 530
# Extracting features from song_id: 531
# Extracting features from song_id: 532
# Extracting features from song_id: 534
# Extracting features from song_id: 535
# Extracting features from song_id: 536
# Extracting features from song_id: 537
# Extracting features from song_id: 539
# Extracting features from song_id: 540
# Extracting features from song_id: 541
# Extracting features from song_id: 542
# Extracting features from song_id: 544
# Extracting features from song_id: 546
# Extracting features from song_id: 548
# Extracting features from song_id: 549
# Extracting features from song_id: 550
# Extracting features from song_id: 551
# Extracting features from song_id: 552
# Extracting features from song_id: 554
# Extracting features from song_id: 555
# Extracting features from song_id: 558
# Extracting features from song_id: 560
# Extracting features from song_id: 561
# Extracting features from song_id: 562
# Extracting features from song_id: 563
# Extracting features from song_id: 564
# Extracting features from song_id: 565
# Extracting features from song_id: 566
# Extracting features from song_id: 567
# Extracting features from song_id: 568
# Extracting features from song_id: 569
# Extracting features from song_id: 570
# Extracting features from song_id: 571
# Extracting features from song_id: 572
# Extracting features from song_id: 573
# Extracting features from song_id: 574
# Extracting features from song_id: 575
# Extracting features from song_id: 576
# Extracting features from song_id: 577
# Extracting features from song_id: 578
# Extracting features from song_id: 579
# Extracting features from song_id: 580
# Extracting features from song_id: 582
# Extracting features from song_id: 583
# Extracting features from song_id: 584
# Extracting features from song_id: 585
# Extracting features from song_id: 587
# Extracting features from song_id: 588
# Extracting features from song_id: 589
# Extracting features from song_id: 590
# Extracting features from song_id: 591
# Extracting features from song_id: 592
# Extracting features from song_id: 594
# Extracting features from song_id: 595
# Extracting features from song_id: 596
# Extracting features from song_id: 597
# Extracting features from song_id: 598
# Extracting features from song_id: 599
# Extracting features from song_id: 600
# Extracting features from song_id: 601
# Extracting features from song_id: 602
# Extracting features from song_id: 603
# Extracting features from song_id: 605
# Extracting features from song_id: 606
# Extracting features from song_id: 607
# Extracting features from song_id: 608
# Extracting features from song_id: 609
# Extracting features from song_id: 610
# Extracting features from song_id: 611
# Extracting features from song_id: 612
# Extracting features from song_id: 613
# Extracting features from song_id: 614
# Extracting features from song_id: 615
# Extracting features from song_id: 616
# Extracting features from song_id: 617
# Extracting features from song_id: 621
# Extracting features from song_id: 622
# Extracting features from song_id: 623
# Extracting features from song_id: 624
# Extracting features from song_id: 625
# Extracting features from song_id: 626
# Extracting features from song_id: 627
# Extracting features from song_id: 628
# Extracting features from song_id: 629
# Extracting features from song_id: 630
# Extracting features from song_id: 631
# Extracting features from song_id: 632
# Extracting features from song_id: 634
# Extracting features from song_id: 635
# Extracting features from song_id: 636
# Extracting features from song_id: 637
# Extracting features from song_id: 638
# Extracting features from song_id: 639
# Extracting features from song_id: 643
# Extracting features from song_id: 644
# Extracting features from song_id: 645
# Extracting features from song_id: 646
# Extracting features from song_id: 647
# Extracting features from song_id: 648
# Extracting features from song_id: 649
# Extracting features from song_id: 650
# Extracting features from song_id: 651
# Extracting features from song_id: 652
# Extracting features from song_id: 653
# Extracting features from song_id: 654
# Extracting features from song_id: 656
# Extracting features from song_id: 657
# Extracting features from song_id: 659
# Extracting features from song_id: 660
# Extracting features from song_id: 661
# Extracting features from song_id: 662
# Extracting features from song_id: 665
# Extracting features from song_id: 666
# Extracting features from song_id: 668
# Extracting features from song_id: 670
# Extracting features from song_id: 671
# Extracting features from song_id: 672
# Extracting features from song_id: 673
# Extracting features from song_id: 674
# Extracting features from song_id: 675
# Extracting features from song_id: 676
# Extracting features from song_id: 677
# Extracting features from song_id: 678
# Extracting features from song_id: 679
# Extracting features from song_id: 681
# Extracting features from song_id: 682
# Extracting features from song_id: 683
# Extracting features from song_id: 684
# Extracting features from song_id: 685
# Extracting features from song_id: 686
# Extracting features from song_id: 687
# Extracting features from song_id: 688
# Extracting features from song_id: 689
# Extracting features from song_id: 692
# Extracting features from song_id: 693
# Extracting features from song_id: 694
# Extracting features from song_id: 697
# Extracting features from song_id: 698
# Extracting features from song_id: 699
# Extracting features from song_id: 700
# Extracting features from song_id: 703
# Extracting features from song_id: 704
# Extracting features from song_id: 705
# Extracting features from song_id: 706
# Extracting features from song_id: 707
# Extracting features from song_id: 708
# Extracting features from song_id: 710
# Extracting features from song_id: 711
# Extracting features from song_id: 713
# Extracting features from song_id: 715
# Extracting features from song_id: 716
# Extracting features from song_id: 717
# Extracting features from song_id: 718
# Extracting features from song_id: 719
# Extracting features from song_id: 720
# Extracting features from song_id: 722
# Extracting features from song_id: 726
# Extracting features from song_id: 727
# Extracting features from song_id: 728
# Extracting features from song_id: 729
# Extracting features from song_id: 730
# Extracting features from song_id: 731
# Extracting features from song_id: 732
# Extracting features from song_id: 733
# Extracting features from song_id: 734
# Extracting features from song_id: 736
# Extracting features from song_id: 738
# Extracting features from song_id: 739
# Extracting features from song_id: 740
# Extracting features from song_id: 741
# Extracting features from song_id: 742
# Extracting features from song_id: 743
# Extracting features from song_id: 744
# Extracting features from song_id: 745
# Extracting features from song_id: 746
# Extracting features from song_id: 747
# Extracting features from song_id: 748
# Extracting features from song_id: 749
# Extracting features from song_id: 750
# Extracting features from song_id: 751
# Extracting features from song_id: 752
# Extracting features from song_id: 753
# Extracting features from song_id: 754
# Extracting features from song_id: 755
# Extracting features from song_id: 757
# Extracting features from song_id: 758
# Extracting features from song_id: 759
# Extracting features from song_id: 760
# Extracting features from song_id: 761
# Extracting features from song_id: 763
# Extracting features from song_id: 765
# Extracting features from song_id: 767
# Extracting features from song_id: 769
# Extracting features from song_id: 770
# Extracting features from song_id: 771
# Extracting features from song_id: 772
# Extracting features from song_id: 773
# Extracting features from song_id: 774
# Extracting features from song_id: 775
# Extracting features from song_id: 776
# Extracting features from song_id: 777
# Extracting features from song_id: 778
# Extracting features from song_id: 779
# Extracting features from song_id: 780
# Extracting features from song_id: 783
# Extracting features from song_id: 784
# Extracting features from song_id: 786
# Extracting features from song_id: 788
# Extracting features from song_id: 789
# Extracting features from song_id: 790
# Extracting features from song_id: 791
# Extracting features from song_id: 792
# Extracting features from song_id: 793
# Extracting features from song_id: 794
# Extracting features from song_id: 796
# Extracting features from song_id: 797
# Extracting features from song_id: 798
# Extracting features from song_id: 799
# Extracting features from song_id: 801
# Extracting features from song_id: 803
# Extracting features from song_id: 804
# Extracting features from song_id: 806
# Extracting features from song_id: 807
# Extracting features from song_id: 808
# Extracting features from song_id: 809
# Extracting features from song_id: 810
# Extracting features from song_id: 812
# Extracting features from song_id: 813
# Extracting features from song_id: 814
# Extracting features from song_id: 815
# Extracting features from song_id: 816
# Extracting features from song_id: 818
# Extracting features from song_id: 820
# Extracting features from song_id: 821
# Extracting features from song_id: 823
# Extracting features from song_id: 824
# Extracting features from song_id: 825
# Extracting features from song_id: 827
# Extracting features from song_id: 828
# Extracting features from song_id: 829
# Extracting features from song_id: 830
# Extracting features from song_id: 831
# Extracting features from song_id: 832
# Extracting features from song_id: 833
# Extracting features from song_id: 834
# Extracting features from song_id: 835
# Extracting features from song_id: 836
# Extracting features from song_id: 837
# Extracting features from song_id: 839
# Extracting features from song_id: 842
# Extracting features from song_id: 844
# Extracting features from song_id: 846
# Extracting features from song_id: 847
# Extracting features from song_id: 848
# Extracting features from song_id: 850
# Extracting features from song_id: 851
# Extracting features from song_id: 852
# Extracting features from song_id: 853
# Extracting features from song_id: 854
# Extracting features from song_id: 855
# Extracting features from song_id: 857
# Extracting features from song_id: 858
# Extracting features from song_id: 859
# Extracting features from song_id: 860
# Extracting features from song_id: 861
# Extracting features from song_id: 862
# Extracting features from song_id: 863
# Extracting features from song_id: 864
# Extracting features from song_id: 865
# Extracting features from song_id: 866
# Extracting features from song_id: 868
# Extracting features from song_id: 869
# Extracting features from song_id: 870
# Extracting features from song_id: 871
# Extracting features from song_id: 876
# Extracting features from song_id: 879
# Extracting features from song_id: 880
# Extracting features from song_id: 881
# Extracting features from song_id: 882
# Extracting features from song_id: 883
# Extracting features from song_id: 884
# Extracting features from song_id: 885
# Extracting features from song_id: 886
# Extracting features from song_id: 888
# Extracting features from song_id: 889
# Extracting features from song_id: 890
# Extracting features from song_id: 892
# Extracting features from song_id: 894
# Extracting features from song_id: 895
# Extracting features from song_id: 896
# Extracting features from song_id: 897
# Extracting features from song_id: 900
# Extracting features from song_id: 903
# Extracting features from song_id: 904
# Extracting features from song_id: 905
# Extracting features from song_id: 906
# Extracting features from song_id: 907
# Extracting features from song_id: 908
# Extracting features from song_id: 909
# Extracting features from song_id: 911
# Extracting features from song_id: 913
# Extracting features from song_id: 915
# Extracting features from song_id: 916
# Extracting features from song_id: 917
# Extracting features from song_id: 918
# Extracting features from song_id: 919
# Extracting features from song_id: 921
# Extracting features from song_id: 922
# Extracting features from song_id: 924
# Extracting features from song_id: 925
# Extracting features from song_id: 926
# Extracting features from song_id: 927
# Extracting features from song_id: 928
# Extracting features from song_id: 929
# Extracting features from song_id: 931
# Extracting features from song_id: 932
# Extracting features from song_id: 933
# Extracting features from song_id: 934
# Extracting features from song_id: 935
# Extracting features from song_id: 936
# Extracting features from song_id: 937
# Extracting features from song_id: 938
# Extracting features from song_id: 939
# Extracting features from song_id: 940
# Extracting features from song_id: 941
# Extracting features from song_id: 943
# Extracting features from song_id: 945
# Extracting features from song_id: 946
# Extracting features from song_id: 948
# Extracting features from song_id: 950
# Extracting features from song_id: 951
# Extracting features from song_id: 952
# Extracting features from song_id: 953
# Extracting features from song_id: 957
# Extracting features from song_id: 958
# Extracting features from song_id: 959
# Extracting features from song_id: 962
# Extracting features from song_id: 964
# Extracting features from song_id: 965
# Extracting features from song_id: 966
# Extracting features from song_id: 967
# Extracting features from song_id: 968
# Extracting features from song_id: 969
# Extracting features from song_id: 970
# Extracting features from song_id: 971
# Extracting features from song_id: 973
# Extracting features from song_id: 974
# Extracting features from song_id: 978
# Extracting features from song_id: 979
# Extracting features from song_id: 980
# Extracting features from song_id: 981
# Extracting features from song_id: 983
# Extracting features from song_id: 984
# Extracting features from song_id: 985
# Extracting features from song_id: 989
# Extracting features from song_id: 992
# Extracting features from song_id: 993
# Extracting features from song_id: 996
# Extracting features from song_id: 997
# Extracting features from song_id: 999
# Extracting features from song_id: 1000
#      song_id  audspec_lengthL1norm_sma_range  audspec_lengthL1norm_sma_maxPos  \
# 0          1                        7.322202                         0.160250
# 1          4                        6.582460                         0.703399
# 2          5                        8.124249                         0.368032
# 3          6                        9.011615                         0.281728
# 4          7                        8.349627                         0.942354
# ..       ...                             ...                              ...
# 789      993                        8.483475                         0.763250
# 790      996                        8.911368                         0.202281
# 791      997                        8.573480                         0.461791
# 792      999                        8.656339                         0.792811
# 793     1000                        8.824550                         0.244802
#
#      audspec_lengthL1norm_sma_minPos  audspec_lengthL1norm_sma_quartile1  \
# 0                                0.0                            2.621674
# 1                                0.0                            1.656607
# 2                                0.0                            1.477557
# 3                                0.0                            2.313058
# 4                                0.0                            4.132349
# ..                               ...                                 ...
# 789                              0.0                            3.067161
# 790                              0.0                            4.574404
# 791                              0.0                            2.674773
# 792                              0.0                            4.998912
# 793                              0.0                            5.542526
#
#      audspec_lengthL1norm_sma_quartile2  audspec_lengthL1norm_sma_quartile3  \
# 0                              3.417233                            4.200210
# 1                              2.151616                            2.964223
# 2                              2.042911                            2.738106
# 3                              3.485445                            4.404951
# 4                              5.013152                            5.750350
# ..                                  ...                                 ...
# 789                            4.405553                            5.770013
# 790                            6.361631                            7.147145
# 791                            5.131298                            6.267901
# 792                            6.388689                            7.008387
# 793                            6.469470                            7.050390
#
#      audspec_lengthL1norm_sma_iqr1-2  audspec_lengthL1norm_sma_iqr2-3  \
# 0                           0.795559                         0.782976
# 1                           0.495009                         0.812608
# 2                           0.565354                         0.695195
# 3                           1.172387                         0.919506
# 4                           0.880803                         0.737199
# ..                               ...                              ...
# 789                         1.338392                         1.364460
# 790                         1.787228                         0.785513
# 791                         2.456525                         1.136603
# 792                         1.389777                         0.619698
# 793                         0.926944                         0.580920
#
#      audspec_lengthL1norm_sma_iqr1-3  ...  mfcc_sma_de[14]_peakRangeAbs  \
# 0                           1.578536  ...                      9.387893
# 1                           1.307617  ...                      7.649520
# 2                           1.260550  ...                      9.301864
# 3                           2.091893  ...                      9.001396
# 4                           1.618002  ...                      8.049467
# ..                               ...  ...                           ...
# 789                         2.702852  ...                      9.415093
# 790                         2.572741  ...                      9.883374
# 791                         3.593128  ...                      9.722556
# 792                         2.009475  ...                      8.010264
# 793                         1.507864  ...                      7.769637
#
#      mfcc_sma_de[14]_peakRangeRel  mfcc_sma_de[14]_peakMeanAbs  \
# 0                        0.527035                     2.584944
# 1                        0.493504                     2.592234
# 2                        0.578882                     2.421329
# 3                        0.577419                     2.309364
# 4                        0.513050                     2.204685
# ..                            ...                          ...
# 789                      0.519761                     2.557367
# 790                      0.546208                     2.423050
# 791                      0.604539                     2.208963
# 792                      0.556838                     2.027305
# 793                      0.510933                     2.139556
#
#      mfcc_sma_de[14]_peakMeanMeanDist  mfcc_sma_de[14]_peakMeanRel  \
# 0                            2.586223                   -20.000000
# 1                            2.594137                   -19.999989
# 2                            2.420420                    20.000000
# 3                            2.310359                   -20.000000
# 4                            2.211791                   -19.971230
# ..                                ...                          ...
# 789                          2.557284                    20.000000
# 790                          2.423151                   -20.000000
# 791                          2.208760                    20.000000
# 792                          2.026831                    20.000000
# 793                          2.138716                    20.000000
#
#      mfcc_sma_de[14]_minRangeRel  mfcc_sma_de[14]_meanRisingSlope  \
# 0                       0.636703                       108.890144
# 1                       0.637455                       104.337410
# 2                       0.547071                       104.202469
# 3                       0.491508                        97.956543
# 4                       0.553398                        94.180351
# ..                           ...                              ...
# 789                     0.653659                       103.939529
# 790                     0.616050                       112.232628
# 791                     0.511724                       104.249886
# 792                     0.565515                        98.668121
# 793                     0.571413                        93.072823
#
#      mfcc_sma_de[14]_stddevRisingSlope  mfcc_sma_de[14]_meanFallingSlope  \
# 0                            50.417366                        107.016617
# 1                            59.133785                        104.376335
# 2                            53.521988                        107.850937
# 3                            49.070080                         99.153725
# 4                            49.567486                         91.844627
# ..                                 ...                               ...
# 789                          59.248730                        107.771057
# 790                          57.986271                        107.318695
# 791                          53.459106                        100.819817
# 792                          51.425926                         96.999367
# 793                          48.014465                         91.802078
#
#      mfcc_sma_de[14]_stddevFallingSlope
# 0                             58.077972
# 1                             56.402073
# 2                             53.353096
# 3                             51.411999
# 4                             46.409393
# ..                                  ...
# 789                           58.497486
# 790                           52.195194
# 791                           54.904305
# 792                           52.407906
# 793                           48.417427
#
# [794 rows x 6374 columns]

# %% [markdown]
# Save the openSmile-extracted features to .csv for ComParE 2016 feature set

# %%
df_opensmile_compare_2016.to_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{OPENSMILE_COMPARE2016_FEATURES_CSV}', index=False)

# %% [markdown]
# ### emobase feature set

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.emobase,
    feature_level=opensmile.FeatureLevel.Functionals,
)

# %%
# Parallelize the feature extraction process for all song IDs
dfs = Parallel(n_jobs=-1)(delayed(extract_features)(song_id) for song_id in song_ids)

# Concatenate the extracted DataFrames
df_opensmile_emobase = pd.concat(dfs)

# Add the 'song_id' column
df_opensmile_emobase.insert(0, column='song_id', value=song_ids)
df_opensmile_emobase.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
df_opensmile_emobase
# Out:
# Extracting features from song_id: 1
# Extracting features from song_id: 4
# Extracting features from song_id: 5
# Extracting features from song_id: 6
# Extracting features from song_id: 7
# Extracting features from song_id: 8
# Extracting features from song_id: 9
# Extracting features from song_id: 10
# Extracting features from song_id: 11
# Extracting features from song_id: 13
# Extracting features from song_id: 12
# Extracting features from song_id: 14
# Extracting features from song_id: 15
# Extracting features from song_id: 16
# Extracting features from song_id: 17
# Extracting features from song_id: 18
# Extracting features from song_id: 19
# Extracting features from song_id: 20
# Extracting features from song_id: 21
# Extracting features from song_id: 23
# Extracting features from song_id: 25
# Extracting features from song_id: 26
# Extracting features from song_id: 28
# Extracting features from song_id: 29
# Extracting features from song_id: 30
# Extracting features from song_id: 31
# Extracting features from song_id: 32
# Extracting features from song_id: 33
# Extracting features from song_id: 34
# Extracting features from song_id: 35
# Extracting features from song_id: 37
# Extracting features from song_id: 38
# Extracting features from song_id: 39
# Extracting features from song_id: 40
# Extracting features from song_id: 42
# Extracting features from song_id: 43
# Extracting features from song_id: 44
# Extracting features from song_id: 46
# Extracting features from song_id: 47
# Extracting features from song_id: 48
# Extracting features from song_id: 49
# Extracting features from song_id: 50
# Extracting features from song_id: 51
# Extracting features from song_id: 52
# Extracting features from song_id: 54
# Extracting features from song_id: 55
# Extracting features from song_id: 56
# Extracting features from song_id: 57
# Extracting features from song_id: 58
# Extracting features from song_id: 59
# Extracting features from song_id: 60
# Extracting features from song_id: 61
# Extracting features from song_id: 63
# Extracting features from song_id: 64
# Extracting features from song_id: 65
# Extracting features from song_id: 66
# Extracting features from song_id: 67
# Extracting features from song_id: 68
# Extracting features from song_id: 69
# Extracting features from song_id: 70
# Extracting features from song_id: 71
# Extracting features from song_id: 72
# Extracting features from song_id: 73
# Extracting features from song_id: 74
# Extracting features from song_id: 75
# Extracting features from song_id: 76
# Extracting features from song_id: 78
# Extracting features from song_id: 79
# Extracting features from song_id: 80
# Extracting features from song_id: 81
# Extracting features from song_id: 83
# Extracting features from song_id: 84
# Extracting features from song_id: 85
# Extracting features from song_id: 86
# Extracting features from song_id: 87
# Extracting features from song_id: 88
# Extracting features from song_id: 89
# Extracting features from song_id: 90
# Extracting features from song_id: 91
# Extracting features from song_id: 92
# Extracting features from song_id: 93
# Extracting features from song_id: 94
# Extracting features from song_id: 95
# Extracting features from song_id: 96
# Extracting features from song_id: 97
# Extracting features from song_id: 98
# Extracting features from song_id: 99
# Extracting features from song_id: 100
# Extracting features from song_id: 101
# Extracting features from song_id: 102
# Extracting features from song_id: 103
# Extracting features from song_id: 104
# Extracting features from song_id: 105
# Extracting features from song_id: 106
# Extracting features from song_id: 107
# Extracting features from song_id: 108
# Extracting features from song_id: 109
# Extracting features from song_id: 110
# Extracting features from song_id: 113
# Extracting features from song_id: 114
# Extracting features from song_id: 115
# Extracting features from song_id: 116
# Extracting features from song_id: 117
# Extracting features from song_id: 118
# Extracting features from song_id: 119
# Extracting features from song_id: 120
# Extracting features from song_id: 123
# Extracting features from song_id: 124
# Extracting features from song_id: 126
# Extracting features from song_id: 127
# Extracting features from song_id: 128
# Extracting features from song_id: 132
# Extracting features from song_id: 133
# Extracting features from song_id: 134
# Extracting features from song_id: 135
# Extracting features from song_id: 136
# Extracting features from song_id: 137
# Extracting features from song_id: 138
# Extracting features from song_id: 139
# Extracting features from song_id: 140
# Extracting features from song_id: 141
# Extracting features from song_id: 142
# Extracting features from song_id: 143
# Extracting features from song_id: 144
# Extracting features from song_id: 145
# Extracting features from song_id: 146
# Extracting features from song_id: 147
# Extracting features from song_id: 148
# Extracting features from song_id: 149
# Extracting features from song_id: 150
# Extracting features from song_id: 151
# Extracting features from song_id: 152
# Extracting features from song_id: 153
# Extracting features from song_id: 156
# Extracting features from song_id: 157
# Extracting features from song_id: 158
# Extracting features from song_id: 159
# Extracting features from song_id: 160
# Extracting features from song_id: 161
# Extracting features from song_id: 162
# Extracting features from song_id: 165
# Extracting features from song_id: 166
# Extracting features from song_id: 167
# Extracting features from song_id: 168
# Extracting features from song_id: 169
# Extracting features from song_id: 170
# Extracting features from song_id: 171
# Extracting features from song_id: 172
# Extracting features from song_id: 174
# Extracting features from song_id: 175
# Extracting features from song_id: 176
# Extracting features from song_id: 177
# Extracting features from song_id: 179
# Extracting features from song_id: 180
# Extracting features from song_id: 181
# Extracting features from song_id: 184
# Extracting features from song_id: 185
# Extracting features from song_id: 186
# Extracting features from song_id: 187
# Extracting features from song_id: 188
# Extracting features from song_id: 189
# Extracting features from song_id: 191
# Extracting features from song_id: 192
# Extracting features from song_id: 196
# Extracting features from song_id: 197
# Extracting features from song_id: 198
# Extracting features from song_id: 199
# Extracting features from song_id: 200
# Extracting features from song_id: 201
# Extracting features from song_id: 202
# Extracting features from song_id: 203
# Extracting features from song_id: 204
# Extracting features from song_id: 205
# Extracting features from song_id: 206
# Extracting features from song_id: 207
# Extracting features from song_id: 209
# Extracting features from song_id: 210
# Extracting features from song_id: 212
# Extracting features from song_id: 211
# Extracting features from song_id: 213
# Extracting features from song_id: 215
# Extracting features from song_id: 216
# Extracting features from song_id: 217
# Extracting features from song_id: 219
# Extracting features from song_id: 220
# Extracting features from song_id: 221
# Extracting features from song_id: 222
# Extracting features from song_id: 224
# Extracting features from song_id: 225
# Extracting features from song_id: 226
# Extracting features from song_id: 227
# Extracting features from song_id: 228
# Extracting features from song_id: 229
# Extracting features from song_id: 230
# Extracting features from song_id: 231
# Extracting features from song_id: 232
# Extracting features from song_id: 233
# Extracting features from song_id: 234
# Extracting features from song_id: 235
# Extracting features from song_id: 236
# Extracting features from song_id: 237
# Extracting features from song_id: 238
# Extracting features from song_id: 239
# Extracting features from song_id: 241
# Extracting features from song_id: 242
# Extracting features from song_id: 244
# Extracting features from song_id: 249
# Extracting features from song_id: 251
# Extracting features from song_id: 252
# Extracting features from song_id: 253
# Extracting features from song_id: 257
# Extracting features from song_id: 258
# Extracting features from song_id: 260
# Extracting features from song_id: 263
# Extracting features from song_id: 264
# Extracting features from song_id: 265
# Extracting features from song_id: 267
# Extracting features from song_id: 269
# Extracting features from song_id: 273
# Extracting features from song_id: 275
# Extracting features from song_id: 276
# Extracting features from song_id: 277
# Extracting features from song_id: 278
# Extracting features from song_id: 279
# Extracting features from song_id: 280
# Extracting features from song_id: 282
# Extracting features from song_id: 283
# Extracting features from song_id: 284
# Extracting features from song_id: 285
# Extracting features from song_id: 291
# Extracting features from song_id: 287
# Extracting features from song_id: 292
# Extracting features from song_id: 293
# Extracting features from song_id: 294
# Extracting features from song_id: 295
# Extracting features from song_id: 296
# Extracting features from song_id: 297
# Extracting features from song_id: 298
# Extracting features from song_id: 299
# Extracting features from song_id: 300
# Extracting features from song_id: 301
# Extracting features from song_id: 302
# Extracting features from song_id: 303
# Extracting features from song_id: 304
# Extracting features from song_id: 305
# Extracting features from song_id: 306
# Extracting features from song_id: 307
# Extracting features from song_id: 308
# Extracting features from song_id: 309
# Extracting features from song_id: 310
# Extracting features from song_id: 311
# Extracting features from song_id: 312
# Extracting features from song_id: 313
# Extracting features from song_id: 314
# Extracting features from song_id: 315
# Extracting features from song_id: 316
# Extracting features from song_id: 317
# Extracting features from song_id: 318
# Extracting features from song_id: 319
# Extracting features from song_id: 320
# Extracting features from song_id: 321
# Extracting features from song_id: 323
# Extracting features from song_id: 324
# Extracting features from song_id: 325
# Extracting features from song_id: 326
# Extracting features from song_id: 327
# Extracting features from song_id: 329
# Extracting features from song_id: 331
# Extracting features from song_id: 332
# Extracting features from song_id: 333
# Extracting features from song_id: 334
# Extracting features from song_id: 336
# Extracting features from song_id: 337
# Extracting features from song_id: 338
# Extracting features from song_id: 339
# Extracting features from song_id: 341
# Extracting features from song_id: 342
# Extracting features from song_id: 343
# Extracting features from song_id: 347
# Extracting features from song_id: 348
# Extracting features from song_id: 349
# Extracting features from song_id: 350
# Extracting features from song_id: 351
# Extracting features from song_id: 352
# Extracting features from song_id: 353
# Extracting features from song_id: 354
# Extracting features from song_id: 355
# Extracting features from song_id: 356
# Extracting features from song_id: 358
# Extracting features from song_id: 359
# Extracting features from song_id: 360
# Extracting features from song_id: 361
# Extracting features from song_id: 362
# Extracting features from song_id: 364
# Extracting features from song_id: 366
# Extracting features from song_id: 367
# Extracting features from song_id: 368
# Extracting features from song_id: 370
# Extracting features from song_id: 371
# Extracting features from song_id: 372
# Extracting features from song_id: 373
# Extracting features from song_id: 375
# Extracting features from song_id: 376
# Extracting features from song_id: 379
# Extracting features from song_id: 381
# Extracting features from song_id: 382
# Extracting features from song_id: 383
# Extracting features from song_id: 384
# Extracting features from song_id: 385
# Extracting features from song_id: 386
# Extracting features from song_id: 388
# Extracting features from song_id: 389
# Extracting features from song_id: 391
# Extracting features from song_id: 392
# Extracting features from song_id: 393
# Extracting features from song_id: 394
# Extracting features from song_id: 395
# Extracting features from song_id: 396
# Extracting features from song_id: 397
# Extracting features from song_id: 398
# Extracting features from song_id: 399
# Extracting features from song_id: 401
# Extracting features from song_id: 402
# Extracting features from song_id: 403
# Extracting features from song_id: 404
# Extracting features from song_id: 405
# Extracting features from song_id: 407
# Extracting features from song_id: 408
# Extracting features from song_id: 409
# Extracting features from song_id: 410
# Extracting features from song_id: 411
# Extracting features from song_id: 412
# Extracting features from song_id: 413
# Extracting features from song_id: 414
# Extracting features from song_id: 415
# Extracting features from song_id: 417
# Extracting features from song_id: 418
# Extracting features from song_id: 419
# Extracting features from song_id: 420
# Extracting features from song_id: 421
# Extracting features from song_id: 423
# Extracting features from song_id: 424
# Extracting features from song_id: 425
# Extracting features from song_id: 426
# Extracting features from song_id: 427
# Extracting features from song_id: 428
# Extracting features from song_id: 429
# Extracting features from song_id: 431
# Extracting features from song_id: 432
# Extracting features from song_id: 433
# Extracting features from song_id: 434
# Extracting features from song_id: 435
# Extracting features from song_id: 436
# Extracting features from song_id: 437
# Extracting features from song_id: 438
# Extracting features from song_id: 439
# Extracting features from song_id: 440
# Extracting features from song_id: 441
# Extracting features from song_id: 442
# Extracting features from song_id: 443
# Extracting features from song_id: 444
# Extracting features from song_id: 445
# Extracting features from song_id: 446
# Extracting features from song_id: 447
# Extracting features from song_id: 448
# Extracting features from song_id: 449
# Extracting features from song_id: 450
# Extracting features from song_id: 451
# Extracting features from song_id: 452
# Extracting features from song_id: 454
# Extracting features from song_id: 455
# Extracting features from song_id: 456
# Extracting features from song_id: 457
# Extracting features from song_id: 458
# Extracting features from song_id: 459
# Extracting features from song_id: 460
# Extracting features from song_id: 461
# Extracting features from song_id: 462
# Extracting features from song_id: 463
# Extracting features from song_id: 464
# Extracting features from song_id: 465
# Extracting features from song_id: 466
# Extracting features from song_id: 468
# Extracting features from song_id: 469
# Extracting features from song_id: 470
# Extracting features from song_id: 471
# Extracting features from song_id: 472
# Extracting features from song_id: 476
# Extracting features from song_id: 477
# Extracting features from song_id: 478
# Extracting features from song_id: 479
# Extracting features from song_id: 480
# Extracting features from song_id: 481
# Extracting features from song_id: 482
# Extracting features from song_id: 483
# Extracting features from song_id: 484
# Extracting features from song_id: 485
# Extracting features from song_id: 486
# Extracting features from song_id: 487
# Extracting features from song_id: 488
# Extracting features from song_id: 489
# Extracting features from song_id: 490
# Extracting features from song_id: 491
# Extracting features from song_id: 492
# Extracting features from song_id: 493
# Extracting features from song_id: 494
# Extracting features from song_id: 495
# Extracting features from song_id: 496
# Extracting features from song_id: 499
# Extracting features from song_id: 500
# Extracting features from song_id: 501
# Extracting features from song_id: 503
# Extracting features from song_id: 504
# Extracting features from song_id: 505
# Extracting features from song_id: 506
# Extracting features from song_id: 507
# Extracting features from song_id: 508
# Extracting features from song_id: 510
# Extracting features from song_id: 511
# Extracting features from song_id: 512
# Extracting features from song_id: 514
# Extracting features from song_id: 515
# Extracting features from song_id: 516
# Extracting features from song_id: 517
# Extracting features from song_id: 518
# Extracting features from song_id: 519
# Extracting features from song_id: 520
# Extracting features from song_id: 521
# Extracting features from song_id: 522
# Extracting features from song_id: 523
# Extracting features from song_id: 524
# Extracting features from song_id: 525
# Extracting features from song_id: 526
# Extracting features from song_id: 530
# Extracting features from song_id: 531
# Extracting features from song_id: 532
# Extracting features from song_id: 534
# Extracting features from song_id: 535
# Extracting features from song_id: 536
# Extracting features from song_id: 537
# Extracting features from song_id: 539
# Extracting features from song_id: 540
# Extracting features from song_id: 541
# Extracting features from song_id: 542
# Extracting features from song_id: 544
# Extracting features from song_id: 546
# Extracting features from song_id: 548
# Extracting features from song_id: 549
# Extracting features from song_id: 550
# Extracting features from song_id: 551
# Extracting features from song_id: 552
# Extracting features from song_id: 554
# Extracting features from song_id: 555
# Extracting features from song_id: 558
# Extracting features from song_id: 560
# Extracting features from song_id: 561
# Extracting features from song_id: 562
# Extracting features from song_id: 563
# Extracting features from song_id: 564
# Extracting features from song_id: 565
# Extracting features from song_id: 566
# Extracting features from song_id: 567
# Extracting features from song_id: 568
# Extracting features from song_id: 569
# Extracting features from song_id: 570
# Extracting features from song_id: 571
# Extracting features from song_id: 572
# Extracting features from song_id: 573
# Extracting features from song_id: 574
# Extracting features from song_id: 575
# Extracting features from song_id: 576
# Extracting features from song_id: 577
# Extracting features from song_id: 578
# Extracting features from song_id: 579
# Extracting features from song_id: 580
# Extracting features from song_id: 582
# Extracting features from song_id: 583
# Extracting features from song_id: 584
# Extracting features from song_id: 585
# Extracting features from song_id: 587
# Extracting features from song_id: 588
# Extracting features from song_id: 589
# Extracting features from song_id: 590
# Extracting features from song_id: 591
# Extracting features from song_id: 592
# Extracting features from song_id: 594
# Extracting features from song_id: 595
# Extracting features from song_id: 596
# Extracting features from song_id: 597
# Extracting features from song_id: 598
# Extracting features from song_id: 599
# Extracting features from song_id: 600
# Extracting features from song_id: 601
# Extracting features from song_id: 602
# Extracting features from song_id: 603
# Extracting features from song_id: 605
# Extracting features from song_id: 606
# Extracting features from song_id: 607
# Extracting features from song_id: 608
# Extracting features from song_id: 609
# Extracting features from song_id: 610
# Extracting features from song_id: 611
# Extracting features from song_id: 612
# Extracting features from song_id: 613
# Extracting features from song_id: 614
# Extracting features from song_id: 615
# Extracting features from song_id: 616
# Extracting features from song_id: 617
# Extracting features from song_id: 621
# Extracting features from song_id: 622
# Extracting features from song_id: 623
# Extracting features from song_id: 624
# Extracting features from song_id: 625
# Extracting features from song_id: 626
# Extracting features from song_id: 627
# Extracting features from song_id: 628
# Extracting features from song_id: 629
# Extracting features from song_id: 630
# Extracting features from song_id: 631
# Extracting features from song_id: 632
# Extracting features from song_id: 634
# Extracting features from song_id: 635
# Extracting features from song_id: 636
# Extracting features from song_id: 637
# Extracting features from song_id: 638
# Extracting features from song_id: 639
# Extracting features from song_id: 643
# Extracting features from song_id: 644
# Extracting features from song_id: 645
# Extracting features from song_id: 646
# Extracting features from song_id: 647
# Extracting features from song_id: 648
# Extracting features from song_id: 649
# Extracting features from song_id: 650
# Extracting features from song_id: 651
# Extracting features from song_id: 652
# Extracting features from song_id: 653
# Extracting features from song_id: 654
# Extracting features from song_id: 656
# Extracting features from song_id: 657
# Extracting features from song_id: 659
# Extracting features from song_id: 660
# Extracting features from song_id: 661
# Extracting features from song_id: 662
# Extracting features from song_id: 665
# Extracting features from song_id: 666
# Extracting features from song_id: 668
# Extracting features from song_id: 670
# Extracting features from song_id: 671
# Extracting features from song_id: 672
# Extracting features from song_id: 673
# Extracting features from song_id: 674
# Extracting features from song_id: 675
# Extracting features from song_id: 676
# Extracting features from song_id: 677
# Extracting features from song_id: 678
# Extracting features from song_id: 679
# Extracting features from song_id: 681
# Extracting features from song_id: 682
# Extracting features from song_id: 683
# Extracting features from song_id: 684
# Extracting features from song_id: 685
# Extracting features from song_id: 686
# Extracting features from song_id: 687
# Extracting features from song_id: 688
# Extracting features from song_id: 689
# Extracting features from song_id: 692
# Extracting features from song_id: 693
# Extracting features from song_id: 694
# Extracting features from song_id: 697
# Extracting features from song_id: 698
# Extracting features from song_id: 699
# Extracting features from song_id: 700
# Extracting features from song_id: 703
# Extracting features from song_id: 704
# Extracting features from song_id: 705
# Extracting features from song_id: 706
# Extracting features from song_id: 707
# Extracting features from song_id: 708
# Extracting features from song_id: 710
# Extracting features from song_id: 711
# Extracting features from song_id: 713
# Extracting features from song_id: 715
# Extracting features from song_id: 716
# Extracting features from song_id: 717
# Extracting features from song_id: 718
# Extracting features from song_id: 719
# Extracting features from song_id: 720
# Extracting features from song_id: 722
# Extracting features from song_id: 726
# Extracting features from song_id: 727
# Extracting features from song_id: 728
# Extracting features from song_id: 729
# Extracting features from song_id: 730
# Extracting features from song_id: 731
# Extracting features from song_id: 732
# Extracting features from song_id: 733
# Extracting features from song_id: 734
# Extracting features from song_id: 736
# Extracting features from song_id: 738
# Extracting features from song_id: 739
# Extracting features from song_id: 740
# Extracting features from song_id: 741
# Extracting features from song_id: 742
# Extracting features from song_id: 743
# Extracting features from song_id: 744
# Extracting features from song_id: 745
# Extracting features from song_id: 746
# Extracting features from song_id: 747
# Extracting features from song_id: 748
# Extracting features from song_id: 749
# Extracting features from song_id: 750
# Extracting features from song_id: 751
# Extracting features from song_id: 752
# Extracting features from song_id: 753
# Extracting features from song_id: 754
# Extracting features from song_id: 755
# Extracting features from song_id: 757
# Extracting features from song_id: 758
# Extracting features from song_id: 759
# Extracting features from song_id: 760
# Extracting features from song_id: 761
# Extracting features from song_id: 763
# Extracting features from song_id: 765
# Extracting features from song_id: 767
# Extracting features from song_id: 769
# Extracting features from song_id: 770
# Extracting features from song_id: 771
# Extracting features from song_id: 772
# Extracting features from song_id: 773
# Extracting features from song_id: 774
# Extracting features from song_id: 775
# Extracting features from song_id: 776
# Extracting features from song_id: 777
# Extracting features from song_id: 778
# Extracting features from song_id: 779
# Extracting features from song_id: 780
# Extracting features from song_id: 783
# Extracting features from song_id: 784
# Extracting features from song_id: 786
# Extracting features from song_id: 788
# Extracting features from song_id: 789
# Extracting features from song_id: 790
# Extracting features from song_id: 791
# Extracting features from song_id: 792
# Extracting features from song_id: 793
# Extracting features from song_id: 794
# Extracting features from song_id: 796
# Extracting features from song_id: 797
# Extracting features from song_id: 798
# Extracting features from song_id: 799
# Extracting features from song_id: 801
# Extracting features from song_id: 803
# Extracting features from song_id: 804
# Extracting features from song_id: 806
# Extracting features from song_id: 807
# Extracting features from song_id: 808
# Extracting features from song_id: 809
# Extracting features from song_id: 810
# Extracting features from song_id: 812
# Extracting features from song_id: 813
# Extracting features from song_id: 814
# Extracting features from song_id: 815
# Extracting features from song_id: 816
# Extracting features from song_id: 818
# Extracting features from song_id: 820
# Extracting features from song_id: 821
# Extracting features from song_id: 823
# Extracting features from song_id: 824
# Extracting features from song_id: 825
# Extracting features from song_id: 827
# Extracting features from song_id: 828
# Extracting features from song_id: 830
# Extracting features from song_id: 829
# Extracting features from song_id: 831
# Extracting features from song_id: 832
# Extracting features from song_id: 833
# Extracting features from song_id: 834
# Extracting features from song_id: 835
# Extracting features from song_id: 836
# Extracting features from song_id: 837
# Extracting features from song_id: 839
# Extracting features from song_id: 842
# Extracting features from song_id: 844
# Extracting features from song_id: 846
# Extracting features from song_id: 847
# Extracting features from song_id: 848
# Extracting features from song_id: 850
# Extracting features from song_id: 851
# Extracting features from song_id: 852
# Extracting features from song_id: 853
# Extracting features from song_id: 854
# Extracting features from song_id: 855
# Extracting features from song_id: 857
# Extracting features from song_id: 858
# Extracting features from song_id: 859
# Extracting features from song_id: 860
# Extracting features from song_id: 861
# Extracting features from song_id: 862
# Extracting features from song_id: 863
# Extracting features from song_id: 864
# Extracting features from song_id: 865
# Extracting features from song_id: 866
# Extracting features from song_id: 868
# Extracting features from song_id: 869
# Extracting features from song_id: 870
# Extracting features from song_id: 871
# Extracting features from song_id: 876
# Extracting features from song_id: 879
# Extracting features from song_id: 880
# Extracting features from song_id: 881
# Extracting features from song_id: 882
# Extracting features from song_id: 883
# Extracting features from song_id: 884
# Extracting features from song_id: 885
# Extracting features from song_id: 886
# Extracting features from song_id: 888
# Extracting features from song_id: 889
# Extracting features from song_id: 890
# Extracting features from song_id: 892
# Extracting features from song_id: 894
# Extracting features from song_id: 895
# Extracting features from song_id: 896
# Extracting features from song_id: 897
# Extracting features from song_id: 900
# Extracting features from song_id: 903
# Extracting features from song_id: 904
# Extracting features from song_id: 905
# Extracting features from song_id: 906
# Extracting features from song_id: 907
# Extracting features from song_id: 908
# Extracting features from song_id: 909
# Extracting features from song_id: 911
# Extracting features from song_id: 913
# Extracting features from song_id: 915
# Extracting features from song_id: 916
# Extracting features from song_id: 917
# Extracting features from song_id: 918
# Extracting features from song_id: 919
# Extracting features from song_id: 921
# Extracting features from song_id: 922
# Extracting features from song_id: 924
# Extracting features from song_id: 925
# Extracting features from song_id: 926
# Extracting features from song_id: 927
# Extracting features from song_id: 928
# Extracting features from song_id: 929
# Extracting features from song_id: 931
# Extracting features from song_id: 932
# Extracting features from song_id: 933
# Extracting features from song_id: 934
# Extracting features from song_id: 935
# Extracting features from song_id: 936
# Extracting features from song_id: 937
# Extracting features from song_id: 938
# Extracting features from song_id: 939
# Extracting features from song_id: 940
# Extracting features from song_id: 941
# Extracting features from song_id: 943
# Extracting features from song_id: 945
# Extracting features from song_id: 946
# Extracting features from song_id: 948
# Extracting features from song_id: 950
# Extracting features from song_id: 951
# Extracting features from song_id: 952
# Extracting features from song_id: 953
# Extracting features from song_id: 957
# Extracting features from song_id: 958
# Extracting features from song_id: 959
# Extracting features from song_id: 962
# Extracting features from song_id: 964
# Extracting features from song_id: 965
# Extracting features from song_id: 966
# Extracting features from song_id: 967
# Extracting features from song_id: 968
# Extracting features from song_id: 969
# Extracting features from song_id: 970
# Extracting features from song_id: 971
# Extracting features from song_id: 973
# Extracting features from song_id: 974
# Extracting features from song_id: 978
# Extracting features from song_id: 979
# Extracting features from song_id: 980
# Extracting features from song_id: 981
# Extracting features from song_id: 983
# Extracting features from song_id: 984
# Extracting features from song_id: 985
# Extracting features from song_id: 989
# Extracting features from song_id: 992
# Extracting features from song_id: 993
# Extracting features from song_id: 996
# Extracting features from song_id: 997
# Extracting features from song_id: 999
# Extracting features from song_id: 1000
#      song_id  pcm_intensity_sma_max  pcm_intensity_sma_min  \
# 0          1               0.000069                    0.0
# 1          4               0.000203                    0.0
# 2          5               0.000207                    0.0
# 3          6               0.000145                    0.0
# 4          7               0.000140                    0.0
# ..       ...                    ...                    ...
# 789      993               0.000200                    0.0
# 790      996               0.000157                    0.0
# 791      997               0.000161                    0.0
# 792      999               0.000155                    0.0
# 793     1000               0.000156                    0.0
#
#      pcm_intensity_sma_range  pcm_intensity_sma_maxPos  \
# 0                   0.000069                     680.0
# 1                   0.000203                    2735.0
# 2                   0.000207                    7809.0
# 3                   0.000145                     324.0
# 4                   0.000140                    1182.0
# ..                       ...                       ...
# 789                 0.000200                    4500.0
# 790                 0.000157                     865.0
# 791                 0.000161                     589.0
# 792                 0.000155                    2217.0
# 793                 0.000156                    6664.0
#
#      pcm_intensity_sma_minPos  pcm_intensity_sma_amean  \
# 0                         0.0                 0.000010
# 1                         0.0                 0.000035
# 2                         0.0                 0.000025
# 3                         0.0                 0.000025
# 4                         0.0                 0.000024
# ..                        ...                      ...
# 789                       0.0                 0.000025
# 790                       0.0                 0.000028
# 791                       0.0                 0.000024
# 792                       0.0                 0.000032
# 793                       0.0                 0.000026
#
#      pcm_intensity_sma_linregc1  pcm_intensity_sma_linregc2  \
# 0                  1.561768e-09                    0.000007
# 1                  9.982415e-09                    0.000021
# 2                  9.522875e-10                    0.000021
# 3                 -4.371458e-09                    0.000031
# 4                  6.233813e-09                    0.000015
# ..                          ...                         ...
# 789               -1.041277e-09                    0.000028
# 790               -3.948721e-10                    0.000029
# 791               -7.007779e-09                    0.000045
# 792               -8.242266e-09                    0.000048
# 793                4.878849e-10                    0.000024
#
#      pcm_intensity_sma_linregerrA  ...  F0env_sma_de_linregerrQ  \
# 0                        0.000007  ...                24.663260
# 1                        0.000025  ...                 6.708408
# 2                        0.000023  ...                31.890631
# 3                        0.000022  ...                42.263218
# 4                        0.000018  ...                16.184336
# ..                            ...  ...                      ...
# 789                      0.000022  ...                21.283978
# 790                      0.000020  ...                16.420145
# 791                      0.000017  ...                16.416569
# 792                      0.000022  ...                21.666965
# 793                      0.000017  ...                 6.712265
#
#      F0env_sma_de_stddev  F0env_sma_de_skewness  F0env_sma_de_kurtosis  \
# 0               4.969058               1.753136              23.013176
# 1               2.596165               0.676692              38.048588
# 2               5.647370               0.340074               6.558109
# 3               6.504123              -0.035226               4.723821
# 4               4.024880               2.228209              31.618954
# ..                   ...                    ...                    ...
# 789             4.614609               1.045086              23.684689
# 790             4.055081               0.161662              11.100394
# 791             4.052447               1.994095              28.915573
# 792             4.656510               0.786846              19.122852
# 793             2.591530               3.255945              76.950317
#
#      F0env_sma_de_quartile1  F0env_sma_de_quartile2  F0env_sma_de_quartile3  \
# 0                 -0.823868                     0.0                0.684412
# 1                  0.000000                     0.0                0.000000
# 2                 -1.443779                     0.0                1.079922
# 3                 -2.500313                     0.0                2.730563
# 4                 -0.120087                     0.0                0.047111
# ..                      ...                     ...                     ...
# 789               -0.047910                     0.0                0.427303
# 790                0.000000                     0.0                0.000000
# 791               -0.340640                     0.0                0.133139
# 792                0.000000                     0.0                0.006744
# 793                0.000000                     0.0                0.000000
#
#      F0env_sma_de_iqr1-2  F0env_sma_de_iqr2-3  F0env_sma_de_iqr1-3
# 0               0.823868             0.684412             1.508279
# 1               0.000000             0.000000             0.000000
# 2               1.443779             1.079922             2.523702
# 3               2.500313             2.730563             5.230876
# 4               0.120087             0.047111             0.167197
# ..                   ...                  ...                  ...
# 789             0.047910             0.427303             0.475213
# 790             0.000000             0.000000             0.000000
# 791             0.340640             0.133139             0.473779
# 792             0.000000             0.006744             0.006744
# 793             0.000000             0.000000             0.000000
#
# [794 rows x 989 columns]

# %% [markdown]
# Save the openSmile-extracted features to .csv for emobase feature set

# %%
df_opensmile_emobase.to_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{OPENSMILE_EMOBASE_FEATURES_CSV}', index=False)

# %% [markdown]
# GeMAPS feature set

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.GeMAPS,
    feature_level=opensmile.FeatureLevel.Functionals,
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/opensmile/core/smile.py:251: UserWarning: Feature set 'FeatureSet.GeMAPS' is deprecated, consider switching to 'FeatureSet.GeMAPSv01b'.
#   warnings.warn(

# %%
# Parallelize the feature extraction process for all song IDs
dfs = Parallel(n_jobs=-1)(delayed(extract_features)(song_id) for song_id in song_ids)

# Concatenate the extracted DataFrames
df_opensmile_gemaps = pd.concat(dfs)

# Add the 'song_id' column
df_opensmile_gemaps.insert(0, column='song_id', value=song_ids)
df_opensmile_gemaps.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
df_opensmile_gemaps
# Out:
# Extracting features from song_id: 1
# Extracting features from song_id: 4
# Extracting features from song_id: 5
# Extracting features from song_id: 6
# Extracting features from song_id: 7
# Extracting features from song_id: 8
# Extracting features from song_id: 9
# Extracting features from song_id: 10
# Extracting features from song_id: 11
# Extracting features from song_id: 12
# Extracting features from song_id: 13
# Extracting features from song_id: 14
# Extracting features from song_id: 15
# Extracting features from song_id: 16
# Extracting features from song_id: 17
# Extracting features from song_id: 18
# Extracting features from song_id: 19
# Extracting features from song_id: 20
# Extracting features from song_id: 21
# Extracting features from song_id: 23
# Extracting features from song_id: 25
# Extracting features from song_id: 26
# Extracting features from song_id: 28
# Extracting features from song_id: 29
# Extracting features from song_id: 30
# Extracting features from song_id: 31
# Extracting features from song_id: 32
# Extracting features from song_id: 33
# Extracting features from song_id: 34
# Extracting features from song_id: 35
# Extracting features from song_id: 37
# Extracting features from song_id: 38
# Extracting features from song_id: 39
# Extracting features from song_id: 40
# Extracting features from song_id: 42
# Extracting features from song_id: 43
# Extracting features from song_id: 44
# Extracting features from song_id: 46
# Extracting features from song_id: 47
# Extracting features from song_id: 48
# Extracting features from song_id: 49
# Extracting features from song_id: 50
# Extracting features from song_id: 51
# Extracting features from song_id: 52
# Extracting features from song_id: 54
# Extracting features from song_id: 55
# Extracting features from song_id: 56
# Extracting features from song_id: 57
# Extracting features from song_id: 58
# Extracting features from song_id: 59
# Extracting features from song_id: 60
# Extracting features from song_id: 61
# Extracting features from song_id: 63
# Extracting features from song_id: 64
# Extracting features from song_id: 65
# Extracting features from song_id: 66
# Extracting features from song_id: 67
# Extracting features from song_id: 68
# Extracting features from song_id: 69
# Extracting features from song_id: 70
# Extracting features from song_id: 71
# Extracting features from song_id: 72
# Extracting features from song_id: 73
# Extracting features from song_id: 74
# Extracting features from song_id: 75
# Extracting features from song_id: 76
# Extracting features from song_id: 78
# Extracting features from song_id: 79
# Extracting features from song_id: 80
# Extracting features from song_id: 81
# Extracting features from song_id: 83
# Extracting features from song_id: 84
# Extracting features from song_id: 85
# Extracting features from song_id: 86
# Extracting features from song_id: 87
# Extracting features from song_id: 88
# Extracting features from song_id: 89
# Extracting features from song_id: 90
# Extracting features from song_id: 91
# Extracting features from song_id: 92
# Extracting features from song_id: 93
# Extracting features from song_id: 94
# Extracting features from song_id: 95
# Extracting features from song_id: 96
# Extracting features from song_id: 97
# Extracting features from song_id: 98
# Extracting features from song_id: 99
# Extracting features from song_id: 100
# Extracting features from song_id: 101
# Extracting features from song_id: 102
# Extracting features from song_id: 103
# Extracting features from song_id: 104
# Extracting features from song_id: 105
# Extracting features from song_id: 106
# Extracting features from song_id: 107
# Extracting features from song_id: 108
# Extracting features from song_id: 109
# Extracting features from song_id: 110
# Extracting features from song_id: 113
# Extracting features from song_id: 114
# Extracting features from song_id: 115
# Extracting features from song_id: 116
# Extracting features from song_id: 117
# Extracting features from song_id: 118
# Extracting features from song_id: 119
# Extracting features from song_id: 120
# Extracting features from song_id: 123
# Extracting features from song_id: 124
# Extracting features from song_id: 126
# Extracting features from song_id: 127
# Extracting features from song_id: 128
# Extracting features from song_id: 132
# Extracting features from song_id: 133
# Extracting features from song_id: 134
# Extracting features from song_id: 135
# Extracting features from song_id: 136
# Extracting features from song_id: 137
# Extracting features from song_id: 138
# Extracting features from song_id: 139
# Extracting features from song_id: 140
# Extracting features from song_id: 141
# Extracting features from song_id: 142
# Extracting features from song_id: 143
# Extracting features from song_id: 144
# Extracting features from song_id: 145
# Extracting features from song_id: 146
# Extracting features from song_id: 147
# Extracting features from song_id: 148
# Extracting features from song_id: 149
# Extracting features from song_id: 150
# Extracting features from song_id: 151
# Extracting features from song_id: 152
# Extracting features from song_id: 153
# Extracting features from song_id: 156
# Extracting features from song_id: 157
# Extracting features from song_id: 158
# Extracting features from song_id: 159
# Extracting features from song_id: 160
# Extracting features from song_id: 161
# Extracting features from song_id: 162
# Extracting features from song_id: 165
# Extracting features from song_id: 166
# Extracting features from song_id: 167
# Extracting features from song_id: 168
# Extracting features from song_id: 169
# Extracting features from song_id: 170
# Extracting features from song_id: 171
# Extracting features from song_id: 172
# Extracting features from song_id: 174
# Extracting features from song_id: 175
# Extracting features from song_id: 176
# Extracting features from song_id: 177
# Extracting features from song_id: 179
# Extracting features from song_id: 180
# Extracting features from song_id: 181
# Extracting features from song_id: 184
# Extracting features from song_id: 185
# Extracting features from song_id: 186
# Extracting features from song_id: 187
# Extracting features from song_id: 188
# Extracting features from song_id: 189
# Extracting features from song_id: 191
# Extracting features from song_id: 192
# Extracting features from song_id: 196
# Extracting features from song_id: 197
# Extracting features from song_id: 198
# Extracting features from song_id: 199
# Extracting features from song_id: 200
# Extracting features from song_id: 201
# Extracting features from song_id: 202
# Extracting features from song_id: 203
# Extracting features from song_id: 205
# Extracting features from song_id: 204
# Extracting features from song_id: 206
# Extracting features from song_id: 207
# Extracting features from song_id: 209
# Extracting features from song_id: 210
# Extracting features from song_id: 211
# Extracting features from song_id: 212
# Extracting features from song_id: 213
# Extracting features from song_id: 215
# Extracting features from song_id: 216
# Extracting features from song_id: 217
# Extracting features from song_id: 219
# Extracting features from song_id: 220
# Extracting features from song_id: 221
# Extracting features from song_id: 222
# Extracting features from song_id: 224
# Extracting features from song_id: 225
# Extracting features from song_id: 226
# Extracting features from song_id: 227
# Extracting features from song_id: 228
# Extracting features from song_id: 229
# Extracting features from song_id: 230
# Extracting features from song_id: 231
# Extracting features from song_id: 232
# Extracting features from song_id: 233
# Extracting features from song_id: 234
# Extracting features from song_id: 235
# Extracting features from song_id: 236
# Extracting features from song_id: 237
# Extracting features from song_id: 238
# Extracting features from song_id: 239
# Extracting features from song_id: 241
# Extracting features from song_id: 242
# Extracting features from song_id: 244
# Extracting features from song_id: 249
# Extracting features from song_id: 251
# Extracting features from song_id: 252
# Extracting features from song_id: 253
# Extracting features from song_id: 257
# Extracting features from song_id: 258
# Extracting features from song_id: 260
# Extracting features from song_id: 263
# Extracting features from song_id: 264
# Extracting features from song_id: 265
# Extracting features from song_id: 267
# Extracting features from song_id: 269
# Extracting features from song_id: 273
# Extracting features from song_id: 275
# Extracting features from song_id: 276
# Extracting features from song_id: 277
# Extracting features from song_id: 278
# Extracting features from song_id: 279
# Extracting features from song_id: 280
# Extracting features from song_id: 282
# Extracting features from song_id: 283
# Extracting features from song_id: 284
# Extracting features from song_id: 285
# Extracting features from song_id: 287
# Extracting features from song_id: 291
# Extracting features from song_id: 292
# Extracting features from song_id: 293
# Extracting features from song_id: 294
# Extracting features from song_id: 295
# Extracting features from song_id: 296
# Extracting features from song_id: 297
# Extracting features from song_id: 298
# Extracting features from song_id: 299
# Extracting features from song_id: 300
# Extracting features from song_id: 301
# Extracting features from song_id: 302
# Extracting features from song_id: 303
# Extracting features from song_id: 304
# Extracting features from song_id: 305
# Extracting features from song_id: 306
# Extracting features from song_id: 307
# Extracting features from song_id: 308
# Extracting features from song_id: 309
# Extracting features from song_id: 310
# Extracting features from song_id: 311
# Extracting features from song_id: 312
# Extracting features from song_id: 313
# Extracting features from song_id: 314
# Extracting features from song_id: 315
# Extracting features from song_id: 316
# Extracting features from song_id: 317
# Extracting features from song_id: 318
# Extracting features from song_id: 319
# Extracting features from song_id: 320
# Extracting features from song_id: 321
# Extracting features from song_id: 323
# Extracting features from song_id: 324
# Extracting features from song_id: 325
# Extracting features from song_id: 326
# Extracting features from song_id: 327
# Extracting features from song_id: 329
# Extracting features from song_id: 331
# Extracting features from song_id: 332
# Extracting features from song_id: 333
# Extracting features from song_id: 334
# Extracting features from song_id: 336
# Extracting features from song_id: 337
# Extracting features from song_id: 338
# Extracting features from song_id: 339
# Extracting features from song_id: 341
# Extracting features from song_id: 342
# Extracting features from song_id: 343
# Extracting features from song_id: 347
# Extracting features from song_id: 348
# Extracting features from song_id: 349
# Extracting features from song_id: 350
# Extracting features from song_id: 351
# Extracting features from song_id: 352
# Extracting features from song_id: 353
# Extracting features from song_id: 354
# Extracting features from song_id: 355
# Extracting features from song_id: 356
# Extracting features from song_id: 358
# Extracting features from song_id: 359
# Extracting features from song_id: 360
# Extracting features from song_id: 361
# Extracting features from song_id: 362
# Extracting features from song_id: 364
# Extracting features from song_id: 366
# Extracting features from song_id: 367
# Extracting features from song_id: 368
# Extracting features from song_id: 370
# Extracting features from song_id: 371
# Extracting features from song_id: 372
# Extracting features from song_id: 373
# Extracting features from song_id: 375
# Extracting features from song_id: 376
# Extracting features from song_id: 379
# Extracting features from song_id: 381
# Extracting features from song_id: 382
# Extracting features from song_id: 383
# Extracting features from song_id: 384
# Extracting features from song_id: 385
# Extracting features from song_id: 386
# Extracting features from song_id: 388
# Extracting features from song_id: 389
# Extracting features from song_id: 391
# Extracting features from song_id: 392
# Extracting features from song_id: 393
# Extracting features from song_id: 394
# Extracting features from song_id: 395
# Extracting features from song_id: 396
# Extracting features from song_id: 397
# Extracting features from song_id: 398
# Extracting features from song_id: 399
# Extracting features from song_id: 401
# Extracting features from song_id: 402
# Extracting features from song_id: 403
# Extracting features from song_id: 404
# Extracting features from song_id: 405
# Extracting features from song_id: 407
# Extracting features from song_id: 408
# Extracting features from song_id: 409
# Extracting features from song_id: 410
# Extracting features from song_id: 411
# Extracting features from song_id: 412
# Extracting features from song_id: 413
# Extracting features from song_id: 414
# Extracting features from song_id: 415
# Extracting features from song_id: 417
# Extracting features from song_id: 418
# Extracting features from song_id: 419
# Extracting features from song_id: 420
# Extracting features from song_id: 421
# Extracting features from song_id: 423
# Extracting features from song_id: 424
# Extracting features from song_id: 425
# Extracting features from song_id: 426
# Extracting features from song_id: 427
# Extracting features from song_id: 428
# Extracting features from song_id: 429
# Extracting features from song_id: 431
# Extracting features from song_id: 432
# Extracting features from song_id: 433
# Extracting features from song_id: 434
# Extracting features from song_id: 435
# Extracting features from song_id: 436
# Extracting features from song_id: 437
# Extracting features from song_id: 438
# Extracting features from song_id: 439
# Extracting features from song_id: 440
# Extracting features from song_id: 441
# Extracting features from song_id: 442
# Extracting features from song_id: 443
# Extracting features from song_id: 444
# Extracting features from song_id: 445
# Extracting features from song_id: 446
# Extracting features from song_id: 447
# Extracting features from song_id: 448
# Extracting features from song_id: 449
# Extracting features from song_id: 450
# Extracting features from song_id: 451
# Extracting features from song_id: 452
# Extracting features from song_id: 454
# Extracting features from song_id: 455
# Extracting features from song_id: 456
# Extracting features from song_id: 457
# Extracting features from song_id: 458
# Extracting features from song_id: 459
# Extracting features from song_id: 460
# Extracting features from song_id: 461
# Extracting features from song_id: 462
# Extracting features from song_id: 463
# Extracting features from song_id: 464
# Extracting features from song_id: 465
# Extracting features from song_id: 466
# Extracting features from song_id: 468
# Extracting features from song_id: 469
# Extracting features from song_id: 470
# Extracting features from song_id: 471
# Extracting features from song_id: 472
# Extracting features from song_id: 476
# Extracting features from song_id: 477
# Extracting features from song_id: 478
# Extracting features from song_id: 479
# Extracting features from song_id: 480
# Extracting features from song_id: 481
# Extracting features from song_id: 482
# Extracting features from song_id: 483
# Extracting features from song_id: 484
# Extracting features from song_id: 485
# Extracting features from song_id: 486
# Extracting features from song_id: 487
# Extracting features from song_id: 488
# Extracting features from song_id: 489
# Extracting features from song_id: 490
# Extracting features from song_id: 491
# Extracting features from song_id: 492
# Extracting features from song_id: 493
# Extracting features from song_id: 494
# Extracting features from song_id: 495
# Extracting features from song_id: 496
# Extracting features from song_id: 499
# Extracting features from song_id: 500
# Extracting features from song_id: 501
# Extracting features from song_id: 503
# Extracting features from song_id: 504
# Extracting features from song_id: 505
# Extracting features from song_id: 506
# Extracting features from song_id: 507
# Extracting features from song_id: 508
# Extracting features from song_id: 510
# Extracting features from song_id: 511
# Extracting features from song_id: 512
# Extracting features from song_id: 514
# Extracting features from song_id: 515
# Extracting features from song_id: 516
# Extracting features from song_id: 517
# Extracting features from song_id: 518
# Extracting features from song_id: 519
# Extracting features from song_id: 520
# Extracting features from song_id: 521
# Extracting features from song_id: 522
# Extracting features from song_id: 523
# Extracting features from song_id: 524
# Extracting features from song_id: 525
# Extracting features from song_id: 526
# Extracting features from song_id: 530
# Extracting features from song_id: 531
# Extracting features from song_id: 532
# Extracting features from song_id: 534
# Extracting features from song_id: 535
# Extracting features from song_id: 536
# Extracting features from song_id: 537
# Extracting features from song_id: 539
# Extracting features from song_id: 540
# Extracting features from song_id: 541
# Extracting features from song_id: 542
# Extracting features from song_id: 544
# Extracting features from song_id: 546
# Extracting features from song_id: 548
# Extracting features from song_id: 549
# Extracting features from song_id: 550
# Extracting features from song_id: 551
# Extracting features from song_id: 552
# Extracting features from song_id: 554
# Extracting features from song_id: 555
# Extracting features from song_id: 558
# Extracting features from song_id: 560
# Extracting features from song_id: 561
# Extracting features from song_id: 562
# Extracting features from song_id: 563
# Extracting features from song_id: 564
# Extracting features from song_id: 565
# Extracting features from song_id: 566
# Extracting features from song_id: 567
# Extracting features from song_id: 568
# Extracting features from song_id: 569
# Extracting features from song_id: 570
# Extracting features from song_id: 571
# Extracting features from song_id: 572
# Extracting features from song_id: 573
# Extracting features from song_id: 574
# Extracting features from song_id: 575
# Extracting features from song_id: 576
# Extracting features from song_id: 577
# Extracting features from song_id: 578
# Extracting features from song_id: 579
# Extracting features from song_id: 580
# Extracting features from song_id: 582
# Extracting features from song_id: 583
# Extracting features from song_id: 584
# Extracting features from song_id: 585
# Extracting features from song_id: 587
# Extracting features from song_id: 588
# Extracting features from song_id: 589
# Extracting features from song_id: 590
# Extracting features from song_id: 591
# Extracting features from song_id: 592
# Extracting features from song_id: 594
# Extracting features from song_id: 595
# Extracting features from song_id: 596
# Extracting features from song_id: 597
# Extracting features from song_id: 598
# Extracting features from song_id: 599
# Extracting features from song_id: 600
# Extracting features from song_id: 601
# Extracting features from song_id: 602
# Extracting features from song_id: 603
# Extracting features from song_id: 605
# Extracting features from song_id: 606
# Extracting features from song_id: 607
# Extracting features from song_id: 608
# Extracting features from song_id: 609
# Extracting features from song_id: 610
# Extracting features from song_id: 611
# Extracting features from song_id: 612
# Extracting features from song_id: 613
# Extracting features from song_id: 614
# Extracting features from song_id: 615
# Extracting features from song_id: 616
# Extracting features from song_id: 617
# Extracting features from song_id: 621
# Extracting features from song_id: 622
# Extracting features from song_id: 623
# Extracting features from song_id: 624
# Extracting features from song_id: 625
# Extracting features from song_id: 626
# Extracting features from song_id: 627
# Extracting features from song_id: 628
# Extracting features from song_id: 629
# Extracting features from song_id: 630
# Extracting features from song_id: 631
# Extracting features from song_id: 632
# Extracting features from song_id: 634
# Extracting features from song_id: 635
# Extracting features from song_id: 636
# Extracting features from song_id: 637
# Extracting features from song_id: 638
# Extracting features from song_id: 639
# Extracting features from song_id: 643
# Extracting features from song_id: 644
# Extracting features from song_id: 645
# Extracting features from song_id: 646
# Extracting features from song_id: 647
# Extracting features from song_id: 648
# Extracting features from song_id: 649
# Extracting features from song_id: 650
# Extracting features from song_id: 651
# Extracting features from song_id: 652
# Extracting features from song_id: 653
# Extracting features from song_id: 654
# Extracting features from song_id: 656
# Extracting features from song_id: 657
# Extracting features from song_id: 659
# Extracting features from song_id: 660
# Extracting features from song_id: 661
# Extracting features from song_id: 662
# Extracting features from song_id: 665
# Extracting features from song_id: 666
# Extracting features from song_id: 668
# Extracting features from song_id: 670
# Extracting features from song_id: 671
# Extracting features from song_id: 672
# Extracting features from song_id: 673
# Extracting features from song_id: 674
# Extracting features from song_id: 675
# Extracting features from song_id: 676
# Extracting features from song_id: 677
# Extracting features from song_id: 678
# Extracting features from song_id: 679
# Extracting features from song_id: 681
# Extracting features from song_id: 682
# Extracting features from song_id: 683
# Extracting features from song_id: 684
# Extracting features from song_id: 685
# Extracting features from song_id: 686
# Extracting features from song_id: 687
# Extracting features from song_id: 688
# Extracting features from song_id: 689
# Extracting features from song_id: 692
# Extracting features from song_id: 693
# Extracting features from song_id: 694
# Extracting features from song_id: 697
# Extracting features from song_id: 698
# Extracting features from song_id: 699
# Extracting features from song_id: 700
# Extracting features from song_id: 703
# Extracting features from song_id: 704
# Extracting features from song_id: 705
# Extracting features from song_id: 706
# Extracting features from song_id: 707
# Extracting features from song_id: 708
# Extracting features from song_id: 710
# Extracting features from song_id: 711
# Extracting features from song_id: 713
# Extracting features from song_id: 715
# Extracting features from song_id: 716
# Extracting features from song_id: 717
# Extracting features from song_id: 718
# Extracting features from song_id: 719
# Extracting features from song_id: 720
# Extracting features from song_id: 722
# Extracting features from song_id: 726
# Extracting features from song_id: 727
# Extracting features from song_id: 728
# Extracting features from song_id: 729
# Extracting features from song_id: 730
# Extracting features from song_id: 731
# Extracting features from song_id: 732
# Extracting features from song_id: 733
# Extracting features from song_id: 734
# Extracting features from song_id: 736
# Extracting features from song_id: 738
# Extracting features from song_id: 739
# Extracting features from song_id: 740
# Extracting features from song_id: 741
# Extracting features from song_id: 742
# Extracting features from song_id: 743
# Extracting features from song_id: 744
# Extracting features from song_id: 745
# Extracting features from song_id: 746
# Extracting features from song_id: 747
# Extracting features from song_id: 748
# Extracting features from song_id: 749
# Extracting features from song_id: 750
# Extracting features from song_id: 751
# Extracting features from song_id: 752
# Extracting features from song_id: 753
# Extracting features from song_id: 754
# Extracting features from song_id: 755
# Extracting features from song_id: 757
# Extracting features from song_id: 758
# Extracting features from song_id: 759
# Extracting features from song_id: 760
# Extracting features from song_id: 761
# Extracting features from song_id: 763
# Extracting features from song_id: 765
# Extracting features from song_id: 767
# Extracting features from song_id: 769
# Extracting features from song_id: 770
# Extracting features from song_id: 771
# Extracting features from song_id: 772
# Extracting features from song_id: 773
# Extracting features from song_id: 774
# Extracting features from song_id: 775
# Extracting features from song_id: 776
# Extracting features from song_id: 777
# Extracting features from song_id: 778
# Extracting features from song_id: 779
# Extracting features from song_id: 780
# Extracting features from song_id: 783
# Extracting features from song_id: 784
# Extracting features from song_id: 786
# Extracting features from song_id: 788
# Extracting features from song_id: 789
# Extracting features from song_id: 790
# Extracting features from song_id: 791
# Extracting features from song_id: 792
# Extracting features from song_id: 793
# Extracting features from song_id: 794
# Extracting features from song_id: 796
# Extracting features from song_id: 797
# Extracting features from song_id: 798
# Extracting features from song_id: 799
# Extracting features from song_id: 801
# Extracting features from song_id: 803
# Extracting features from song_id: 804
# Extracting features from song_id: 806
# Extracting features from song_id: 807
# Extracting features from song_id: 808
# Extracting features from song_id: 809
# Extracting features from song_id: 810
# Extracting features from song_id: 812
# Extracting features from song_id: 813
# Extracting features from song_id: 814
# Extracting features from song_id: 815
# Extracting features from song_id: 816
# Extracting features from song_id: 818
# Extracting features from song_id: 820
# Extracting features from song_id: 821
# Extracting features from song_id: 823
# Extracting features from song_id: 824
# Extracting features from song_id: 825
# Extracting features from song_id: 827
# Extracting features from song_id: 828
# Extracting features from song_id: 829
# Extracting features from song_id: 830
# Extracting features from song_id: 831
# Extracting features from song_id: 832
# Extracting features from song_id: 833
# Extracting features from song_id: 834
# Extracting features from song_id: 835
# Extracting features from song_id: 836
# Extracting features from song_id: 837
# Extracting features from song_id: 839
# Extracting features from song_id: 842
# Extracting features from song_id: 844
# Extracting features from song_id: 846
# Extracting features from song_id: 847
# Extracting features from song_id: 848
# Extracting features from song_id: 850
# Extracting features from song_id: 851
# Extracting features from song_id: 852
# Extracting features from song_id: 853
# Extracting features from song_id: 854
# Extracting features from song_id: 855
# Extracting features from song_id: 857
# Extracting features from song_id: 858
# Extracting features from song_id: 859
# Extracting features from song_id: 860
# Extracting features from song_id: 861
# Extracting features from song_id: 862
# Extracting features from song_id: 863
# Extracting features from song_id: 864
# Extracting features from song_id: 865
# Extracting features from song_id: 866
# Extracting features from song_id: 868
# Extracting features from song_id: 869
# Extracting features from song_id: 870
# Extracting features from song_id: 871
# Extracting features from song_id: 876
# Extracting features from song_id: 879
# Extracting features from song_id: 880
# Extracting features from song_id: 881
# Extracting features from song_id: 882
# Extracting features from song_id: 883
# Extracting features from song_id: 884
# Extracting features from song_id: 885
# Extracting features from song_id: 886
# Extracting features from song_id: 888
# Extracting features from song_id: 889
# Extracting features from song_id: 890
# Extracting features from song_id: 892
# Extracting features from song_id: 894
# Extracting features from song_id: 895
# Extracting features from song_id: 896
# Extracting features from song_id: 897
# Extracting features from song_id: 900
# Extracting features from song_id: 903
# Extracting features from song_id: 904
# Extracting features from song_id: 905
# Extracting features from song_id: 906
# Extracting features from song_id: 907
# Extracting features from song_id: 908
# Extracting features from song_id: 909
# Extracting features from song_id: 911
# Extracting features from song_id: 913
# Extracting features from song_id: 915
# Extracting features from song_id: 916
# Extracting features from song_id: 917
# Extracting features from song_id: 918
# Extracting features from song_id: 919
# Extracting features from song_id: 921
# Extracting features from song_id: 922
# Extracting features from song_id: 924
# Extracting features from song_id: 925
# Extracting features from song_id: 926
# Extracting features from song_id: 927
# Extracting features from song_id: 928
# Extracting features from song_id: 929
# Extracting features from song_id: 931
# Extracting features from song_id: 932
# Extracting features from song_id: 933
# Extracting features from song_id: 934
# Extracting features from song_id: 935
# Extracting features from song_id: 936
# Extracting features from song_id: 937
# Extracting features from song_id: 938
# Extracting features from song_id: 939
# Extracting features from song_id: 940
# Extracting features from song_id: 941
# Extracting features from song_id: 943
# Extracting features from song_id: 945
# Extracting features from song_id: 946
# Extracting features from song_id: 948
# Extracting features from song_id: 950
# Extracting features from song_id: 951
# Extracting features from song_id: 952
# Extracting features from song_id: 953
# Extracting features from song_id: 957
# Extracting features from song_id: 958
# Extracting features from song_id: 959
# Extracting features from song_id: 962
# Extracting features from song_id: 964
# Extracting features from song_id: 965
# Extracting features from song_id: 966
# Extracting features from song_id: 967
# Extracting features from song_id: 968
# Extracting features from song_id: 969
# Extracting features from song_id: 970
# Extracting features from song_id: 971
# Extracting features from song_id: 973
# Extracting features from song_id: 974
# Extracting features from song_id: 978
# Extracting features from song_id: 979
# Extracting features from song_id: 980
# Extracting features from song_id: 981
# Extracting features from song_id: 983
# Extracting features from song_id: 984
# Extracting features from song_id: 985
# Extracting features from song_id: 989
# Extracting features from song_id: 992
# Extracting features from song_id: 993
# Extracting features from song_id: 996
# Extracting features from song_id: 997
# Extracting features from song_id: 999
# Extracting features from song_id: 1000
#      song_id  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0          1                          33.337425
# 1          4                          28.663845
# 2          5                          17.131292
# 3          6                          27.172243
# 4          7                          27.857573
# ..       ...                                ...
# 789      993                          28.589037
# 790      996                          34.963680
# 791      997                          23.521826
# 792      999                          28.412848
# 793     1000                          28.422981
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.292724
# 1                                  0.257283
# 2                                  0.444438
# 3                                  0.447355
# 4                                  0.326031
# ..                                      ...
# 789                                0.445477
# 790                                0.308940
# 791                                0.515144
# 792                                0.529474
# 793                                0.465772
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                     26.119843
# 1                                     22.888889
# 2                                     12.300488
# 3                                     13.918818
# 4                                     16.902195
# ..                                          ...
# 789                                   16.152197
# 790                                   23.050102
# 791                                   13.664935
# 792                                   14.129504
# 793                                   14.124825
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                     36.004002
# 1                                     28.891180
# 2                                     12.616845
# 3                                     25.472513
# 4                                     30.955669
# ..                                          ...
# 789                                   24.940647
# 790                                   39.976578
# 791                                   16.773577
# 792                                   21.055300
# 793                                   23.073471
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                     40.604488
# 1                                     34.114971
# 2                                     24.207296
# 3                                     43.135548
# 4                                     36.047791
# ..                                          ...
# 789                                   44.368267
# 790                                   43.117737
# 791                                   37.080620
# 792                                   48.873077
# 793                                   44.002636
#
#      F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                   14.484646
# 1                                   11.226082
# 2                                   11.906808
# 3                                   29.216728
# 4                                   19.145596
# ..                                        ...
# 789                                 28.216070
# 790                                 20.067635
# 791                                 23.415684
# 792                                 34.743572
# 793                                 29.877811
#
#      F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                     305.862122
# 1                                     181.813644
# 2                                     164.744644
# 3                                     311.857635
# 4                                     331.957245
# ..                                           ...
# 789                                   673.328918
# 790                                   337.409668
# 791                                   354.207977
# 792                                   832.962341
# 793                                   462.043030
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                       450.777679
# 1                                       127.028496
# 2                                       236.056610
# 3                                       277.610321
# 4                                       427.345398
# ..                                             ...
# 789                                     974.933533
# 790                                     449.238007
# 791                                     692.777161
# 792                                     972.408142
# 793                                     684.217712
#
#      F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  ...  \
# 0                                      146.386749  ...
# 1                                       60.697544  ...
# 2                                      100.181328  ...
# 3                                       97.866791  ...
# 4                                      121.956184  ...
# ..                                            ...  ...
# 789                                    230.685242  ...
# 790                                    146.028763  ...
# 791                                    256.592255  ...
# 792                                    152.828995  ...
# 793                                    289.294830  ...
#
#      alphaRatioUV_sma3nz_amean  hammarbergIndexUV_sma3nz_amean  \
# 0                    -9.104095                       18.212526
# 1                   -23.523148                       34.651325
# 2                   -22.474178                       32.335781
# 3                   -13.287336                       22.688347
# 4                    -6.551864                       12.755936
# ..                         ...                             ...
# 789                  -5.758517                       12.847198
# 790                  -6.366639                       16.632452
# 791                  -4.795950                       14.046479
# 792                  -5.796313                       14.950939
# 793                  -4.264546                       11.774019
#
#      slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                    -0.064266                     -0.011526
# 1                    -0.106618                     -0.022618
# 2                    -0.098165                     -0.014625
# 3                    -0.116574                     -0.008948
# 4                    -0.000146                     -0.015459
# ..                         ...                           ...
# 789                  -0.031968                     -0.011104
# 790                  -0.027622                     -0.003730
# 791                  -0.042555                     -0.007021
# 792                  -0.058397                     -0.006240
# 793                  -0.046183                     -0.005782
#
#      loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0               3.623868              3.161190                    0.175842
# 1               4.177080              0.500715                    0.465000
# 2               4.177577              2.227251                    0.301123
# 3               3.565365              1.734694                    0.103922
# 4               3.375818              2.485330                    0.342917
# ..                   ...                   ...                         ...
# 789             2.822581              3.123903                    0.203596
# 790             3.517186              3.542834                    0.147345
# 791             3.032914              2.966540                    0.219593
# 792             2.307101              3.567762                    0.128705
# 793             2.129317              3.637781                    0.135143
#
#      StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                        0.189566                   0.130000
# 1                        0.899490                   1.410667
# 2                        0.359941                   0.153117
# 3                        0.143323                   0.489787
# 4                        0.373298                   0.054167
# ..                            ...                        ...
# 789                      0.721575                   0.106312
# 790                      0.171755                   0.125217
# 791                      0.315522                   0.112945
# 792                      0.298521                   0.140853
# 793                      0.219989                   0.142371
#
#      StddevUnvoicedSegmentLength
# 0                       0.104119
# 1                       1.558009
# 2                       0.170928
# 3                       0.522769
# 4                       0.046226
# ..                           ...
# 789                     0.100384
# 790                     0.128034
# 791                     0.254109
# 792                     0.374921
# 793                     0.187633
#
# [794 rows x 63 columns]

# %% [markdown]
# Save the openSMILE-extracted features to .csv for GeMAPS feature set

# %%
df_opensmile_gemaps.to_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{OPENSMILE_GEMAPS_FEATURES_CSV}', index=False)

# %% [markdown]
# eGeMAPS feature set

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPS,
    feature_level=opensmile.FeatureLevel.Functionals,
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/opensmile/core/smile.py:251: UserWarning: Feature set 'FeatureSet.eGeMAPS' is deprecated, consider switching to 'FeatureSet.eGeMAPSv02'.
#   warnings.warn(

# %%
# Parallelize the feature extraction process for all song IDs
dfs = Parallel(n_jobs=-1)(delayed(extract_features)(song_id) for song_id in song_ids)

# Concatenate the extracted DataFrames
df_opensmile_egemaps = pd.concat(dfs)

# Add the 'song_id' column
df_opensmile_egemaps.insert(0, column='song_id', value=song_ids)
df_opensmile_egemaps.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
df_opensmile_egemaps
# Out:
# Extracting features from song_id: 4
# Extracting features from song_id: 1
# Extracting features from song_id: 5
# Extracting features from song_id: 7
# Extracting features from song_id: 6
# Extracting features from song_id: 8
# Extracting features from song_id: 9
# Extracting features from song_id: 10
# Extracting features from song_id: 11
# Extracting features from song_id: 12
# Extracting features from song_id: 13
# Extracting features from song_id: 14
# Extracting features from song_id: 15
# Extracting features from song_id: 16
# Extracting features from song_id: 17
# Extracting features from song_id: 18
# Extracting features from song_id: 19
# Extracting features from song_id: 20
# Extracting features from song_id: 21
# Extracting features from song_id: 23
# Extracting features from song_id: 25
# Extracting features from song_id: 26
# Extracting features from song_id: 28
# Extracting features from song_id: 29
# Extracting features from song_id: 30
# Extracting features from song_id: 31
# Extracting features from song_id: 32
# Extracting features from song_id: 33
# Extracting features from song_id: 34
# Extracting features from song_id: 35
# Extracting features from song_id: 37
# Extracting features from song_id: 38
# Extracting features from song_id: 39
# Extracting features from song_id: 40
# Extracting features from song_id: 42
# Extracting features from song_id: 43
# Extracting features from song_id: 44
# Extracting features from song_id: 46
# Extracting features from song_id: 47
# Extracting features from song_id: 48
# Extracting features from song_id: 49
# Extracting features from song_id: 50
# Extracting features from song_id: 51
# Extracting features from song_id: 52
# Extracting features from song_id: 54
# Extracting features from song_id: 55
# Extracting features from song_id: 56
# Extracting features from song_id: 57
# Extracting features from song_id: 58
# Extracting features from song_id: 59
# Extracting features from song_id: 60
# Extracting features from song_id: 61
# Extracting features from song_id: 63
# Extracting features from song_id: 64
# Extracting features from song_id: 65
# Extracting features from song_id: 66
# Extracting features from song_id: 67
# Extracting features from song_id: 68
# Extracting features from song_id: 69
# Extracting features from song_id: 70
# Extracting features from song_id: 71
# Extracting features from song_id: 72
# Extracting features from song_id: 73
# Extracting features from song_id: 74
# Extracting features from song_id: 75
# Extracting features from song_id: 76
# Extracting features from song_id: 78
# Extracting features from song_id: 79
# Extracting features from song_id: 80
# Extracting features from song_id: 81
# Extracting features from song_id: 83
# Extracting features from song_id: 84
# Extracting features from song_id: 85
# Extracting features from song_id: 86
# Extracting features from song_id: 87
# Extracting features from song_id: 88
# Extracting features from song_id: 89
# Extracting features from song_id: 90
# Extracting features from song_id: 91
# Extracting features from song_id: 92
# Extracting features from song_id: 93
# Extracting features from song_id: 94
# Extracting features from song_id: 95
# Extracting features from song_id: 96
# Extracting features from song_id: 97
# Extracting features from song_id: 98
# Extracting features from song_id: 99
# Extracting features from song_id: 100
# Extracting features from song_id: 101
# Extracting features from song_id: 102
# Extracting features from song_id: 103
# Extracting features from song_id: 104
# Extracting features from song_id: 105
# Extracting features from song_id: 106
# Extracting features from song_id: 107
# Extracting features from song_id: 108
# Extracting features from song_id: 109
# Extracting features from song_id: 110
# Extracting features from song_id: 113
# Extracting features from song_id: 114
# Extracting features from song_id: 115
# Extracting features from song_id: 116
# Extracting features from song_id: 117
# Extracting features from song_id: 118
# Extracting features from song_id: 119
# Extracting features from song_id: 120
# Extracting features from song_id: 123
# Extracting features from song_id: 124
# Extracting features from song_id: 126
# Extracting features from song_id: 127
# Extracting features from song_id: 128
# Extracting features from song_id: 132
# Extracting features from song_id: 133
# Extracting features from song_id: 134
# Extracting features from song_id: 135
# Extracting features from song_id: 136
# Extracting features from song_id: 137
# Extracting features from song_id: 138
# Extracting features from song_id: 139
# Extracting features from song_id: 140
# Extracting features from song_id: 141
# Extracting features from song_id: 142
# Extracting features from song_id: 143
# Extracting features from song_id: 144
# Extracting features from song_id: 145
# Extracting features from song_id: 146
# Extracting features from song_id: 147
# Extracting features from song_id: 148
# Extracting features from song_id: 149
# Extracting features from song_id: 150
# Extracting features from song_id: 151
# Extracting features from song_id: 152
# Extracting features from song_id: 153
# Extracting features from song_id: 156
# Extracting features from song_id: 157
# Extracting features from song_id: 158
# Extracting features from song_id: 159
# Extracting features from song_id: 160
# Extracting features from song_id: 161
# Extracting features from song_id: 162
# Extracting features from song_id: 165
# Extracting features from song_id: 166
# Extracting features from song_id: 167
# Extracting features from song_id: 168
# Extracting features from song_id: 169
# Extracting features from song_id: 170
# Extracting features from song_id: 171
# Extracting features from song_id: 172
# Extracting features from song_id: 174
# Extracting features from song_id: 175
# Extracting features from song_id: 176
# Extracting features from song_id: 177
# Extracting features from song_id: 179
# Extracting features from song_id: 180
# Extracting features from song_id: 181
# Extracting features from song_id: 184
# Extracting features from song_id: 185
# Extracting features from song_id: 186
# Extracting features from song_id: 187
# Extracting features from song_id: 188
# Extracting features from song_id: 189
# Extracting features from song_id: 191
# Extracting features from song_id: 192
# Extracting features from song_id: 196
# Extracting features from song_id: 197
# Extracting features from song_id: 198
# Extracting features from song_id: 199
# Extracting features from song_id: 200
# Extracting features from song_id: 201
# Extracting features from song_id: 202
# Extracting features from song_id: 203
# Extracting features from song_id: 204
# Extracting features from song_id: 205
# Extracting features from song_id: 206
# Extracting features from song_id: 207
# Extracting features from song_id: 209
# Extracting features from song_id: 210
# Extracting features from song_id: 211
# Extracting features from song_id: 212
# Extracting features from song_id: 213
# Extracting features from song_id: 215
# Extracting features from song_id: 216
# Extracting features from song_id: 217
# Extracting features from song_id: 219
# Extracting features from song_id: 220
# Extracting features from song_id: 221
# Extracting features from song_id: 222
# Extracting features from song_id: 224
# Extracting features from song_id: 225
# Extracting features from song_id: 226
# Extracting features from song_id: 227
# Extracting features from song_id: 228
# Extracting features from song_id: 229
# Extracting features from song_id: 230
# Extracting features from song_id: 231
# Extracting features from song_id: 232
# Extracting features from song_id: 233
# Extracting features from song_id: 234
# Extracting features from song_id: 235
# Extracting features from song_id: 236
# Extracting features from song_id: 237
# Extracting features from song_id: 238
# Extracting features from song_id: 239
# Extracting features from song_id: 241
# Extracting features from song_id: 242
# Extracting features from song_id: 244
# Extracting features from song_id: 249
# Extracting features from song_id: 251
# Extracting features from song_id: 252
# Extracting features from song_id: 253
# Extracting features from song_id: 257
# Extracting features from song_id: 258
# Extracting features from song_id: 260
# Extracting features from song_id: 263
# Extracting features from song_id: 264
# Extracting features from song_id: 265
# Extracting features from song_id: 267
# Extracting features from song_id: 269
# Extracting features from song_id: 273
# Extracting features from song_id: 275
# Extracting features from song_id: 276
# Extracting features from song_id: 277
# Extracting features from song_id: 278
# Extracting features from song_id: 279
# Extracting features from song_id: 280
# Extracting features from song_id: 282
# Extracting features from song_id: 283
# Extracting features from song_id: 284
# Extracting features from song_id: 285
# Extracting features from song_id: 287
# Extracting features from song_id: 291
# Extracting features from song_id: 292
# Extracting features from song_id: 293
# Extracting features from song_id: 294
# Extracting features from song_id: 295
# Extracting features from song_id: 296
# Extracting features from song_id: 297
# Extracting features from song_id: 298
# Extracting features from song_id: 299
# Extracting features from song_id: 300
# Extracting features from song_id: 301
# Extracting features from song_id: 302
# Extracting features from song_id: 303
# Extracting features from song_id: 304
# Extracting features from song_id: 305
# Extracting features from song_id: 306
# Extracting features from song_id: 307
# Extracting features from song_id: 308
# Extracting features from song_id: 309
# Extracting features from song_id: 310
# Extracting features from song_id: 311
# Extracting features from song_id: 312
# Extracting features from song_id: 313
# Extracting features from song_id: 314
# Extracting features from song_id: 315
# Extracting features from song_id: 316
# Extracting features from song_id: 317
# Extracting features from song_id: 318
# Extracting features from song_id: 319
# Extracting features from song_id: 320
# Extracting features from song_id: 321
# Extracting features from song_id: 323
# Extracting features from song_id: 324
# Extracting features from song_id: 325
# Extracting features from song_id: 326
# Extracting features from song_id: 327
# Extracting features from song_id: 329
# Extracting features from song_id: 331
# Extracting features from song_id: 332
# Extracting features from song_id: 333
# Extracting features from song_id: 334
# Extracting features from song_id: 336
# Extracting features from song_id: 337
# Extracting features from song_id: 338
# Extracting features from song_id: 339
# Extracting features from song_id: 341
# Extracting features from song_id: 342
# Extracting features from song_id: 343
# Extracting features from song_id: 347
# Extracting features from song_id: 348
# Extracting features from song_id: 349
# Extracting features from song_id: 350
# Extracting features from song_id: 351
# Extracting features from song_id: 352
# Extracting features from song_id: 353
# Extracting features from song_id: 354
# Extracting features from song_id: 355
# Extracting features from song_id: 356
# Extracting features from song_id: 358
# Extracting features from song_id: 359
# Extracting features from song_id: 360
# Extracting features from song_id: 361
# Extracting features from song_id: 362
# Extracting features from song_id: 364
# Extracting features from song_id: 366
# Extracting features from song_id: 367
# Extracting features from song_id: 368
# Extracting features from song_id: 370
# Extracting features from song_id: 371
# Extracting features from song_id: 372
# Extracting features from song_id: 373
# Extracting features from song_id: 375
# Extracting features from song_id: 376
# Extracting features from song_id: 379
# Extracting features from song_id: 381
# Extracting features from song_id: 382
# Extracting features from song_id: 383
# Extracting features from song_id: 384
# Extracting features from song_id: 385
# Extracting features from song_id: 386
# Extracting features from song_id: 388
# Extracting features from song_id: 389
# Extracting features from song_id: 391
# Extracting features from song_id: 392
# Extracting features from song_id: 393
# Extracting features from song_id: 394
# Extracting features from song_id: 395
# Extracting features from song_id: 396
# Extracting features from song_id: 397
# Extracting features from song_id: 398
# Extracting features from song_id: 399
# Extracting features from song_id: 401
# Extracting features from song_id: 402
# Extracting features from song_id: 403
# Extracting features from song_id: 404
# Extracting features from song_id: 405
# Extracting features from song_id: 407
# Extracting features from song_id: 408
# Extracting features from song_id: 409
# Extracting features from song_id: 410
# Extracting features from song_id: 411
# Extracting features from song_id: 412
# Extracting features from song_id: 413
# Extracting features from song_id: 414
# Extracting features from song_id: 415
# Extracting features from song_id: 417
# Extracting features from song_id: 418
# Extracting features from song_id: 419
# Extracting features from song_id: 420
# Extracting features from song_id: 421
# Extracting features from song_id: 423
# Extracting features from song_id: 424
# Extracting features from song_id: 425
# Extracting features from song_id: 426
# Extracting features from song_id: 427
# Extracting features from song_id: 428
# Extracting features from song_id: 429
# Extracting features from song_id: 431
# Extracting features from song_id: 432
# Extracting features from song_id: 433
# Extracting features from song_id: 434
# Extracting features from song_id: 435
# Extracting features from song_id: 436
# Extracting features from song_id: 437
# Extracting features from song_id: 438
# Extracting features from song_id: 439
# Extracting features from song_id: 440
# Extracting features from song_id: 441
# Extracting features from song_id: 442
# Extracting features from song_id: 443
# Extracting features from song_id: 444
# Extracting features from song_id: 445
# Extracting features from song_id: 446
# Extracting features from song_id: 447
# Extracting features from song_id: 448
# Extracting features from song_id: 449
# Extracting features from song_id: 450
# Extracting features from song_id: 451
# Extracting features from song_id: 452
# Extracting features from song_id: 454
# Extracting features from song_id: 455
# Extracting features from song_id: 456
# Extracting features from song_id: 457
# Extracting features from song_id: 458
# Extracting features from song_id: 459
# Extracting features from song_id: 460
# Extracting features from song_id: 461
# Extracting features from song_id: 462
# Extracting features from song_id: 463
# Extracting features from song_id: 464
# Extracting features from song_id: 465
# Extracting features from song_id: 466
# Extracting features from song_id: 468
# Extracting features from song_id: 469
# Extracting features from song_id: 470
# Extracting features from song_id: 471
# Extracting features from song_id: 472
# Extracting features from song_id: 476
# Extracting features from song_id: 477
# Extracting features from song_id: 478
# Extracting features from song_id: 479
# Extracting features from song_id: 480
# Extracting features from song_id: 481
# Extracting features from song_id: 482
# Extracting features from song_id: 483
# Extracting features from song_id: 484
# Extracting features from song_id: 485
# Extracting features from song_id: 486
# Extracting features from song_id: 487
# Extracting features from song_id: 488
# Extracting features from song_id: 489
# Extracting features from song_id: 490
# Extracting features from song_id: 491
# Extracting features from song_id: 492
# Extracting features from song_id: 493
# Extracting features from song_id: 494
# Extracting features from song_id: 495
# Extracting features from song_id: 496
# Extracting features from song_id: 499
# Extracting features from song_id: 500
# Extracting features from song_id: 501
# Extracting features from song_id: 503
# Extracting features from song_id: 504
# Extracting features from song_id: 505
# Extracting features from song_id: 506
# Extracting features from song_id: 507
# Extracting features from song_id: 508
# Extracting features from song_id: 510
# Extracting features from song_id: 511
# Extracting features from song_id: 512
# Extracting features from song_id: 514
# Extracting features from song_id: 515
# Extracting features from song_id: 516
# Extracting features from song_id: 517
# Extracting features from song_id: 518
# Extracting features from song_id: 519
# Extracting features from song_id: 520
# Extracting features from song_id: 521
# Extracting features from song_id: 522
# Extracting features from song_id: 523
# Extracting features from song_id: 524
# Extracting features from song_id: 525
# Extracting features from song_id: 526
# Extracting features from song_id: 530
# Extracting features from song_id: 531
# Extracting features from song_id: 532
# Extracting features from song_id: 534
# Extracting features from song_id: 535
# Extracting features from song_id: 536
# Extracting features from song_id: 537
# Extracting features from song_id: 539
# Extracting features from song_id: 540
# Extracting features from song_id: 541
# Extracting features from song_id: 542
# Extracting features from song_id: 544
# Extracting features from song_id: 546
# Extracting features from song_id: 548
# Extracting features from song_id: 549
# Extracting features from song_id: 550
# Extracting features from song_id: 551
# Extracting features from song_id: 552
# Extracting features from song_id: 554
# Extracting features from song_id: 555
# Extracting features from song_id: 558
# Extracting features from song_id: 560
# Extracting features from song_id: 561
# Extracting features from song_id: 562
# Extracting features from song_id: 563
# Extracting features from song_id: 564
# Extracting features from song_id: 565
# Extracting features from song_id: 566
# Extracting features from song_id: 567
# Extracting features from song_id: 568
# Extracting features from song_id: 569
# Extracting features from song_id: 571
# Extracting features from song_id: 570
# Extracting features from song_id: 572
# Extracting features from song_id: 574
# Extracting features from song_id: 573
# Extracting features from song_id: 575
# Extracting features from song_id: 576
# Extracting features from song_id: 577
# Extracting features from song_id: 578
# Extracting features from song_id: 579
# Extracting features from song_id: 580
# Extracting features from song_id: 582
# Extracting features from song_id: 583
# Extracting features from song_id: 584
# Extracting features from song_id: 585
# Extracting features from song_id: 587
# Extracting features from song_id: 588
# Extracting features from song_id: 589
# Extracting features from song_id: 590
# Extracting features from song_id: 591
# Extracting features from song_id: 592
# Extracting features from song_id: 594
# Extracting features from song_id: 595
# Extracting features from song_id: 596
# Extracting features from song_id: 597
# Extracting features from song_id: 598
# Extracting features from song_id: 599
# Extracting features from song_id: 600
# Extracting features from song_id: 601
# Extracting features from song_id: 602
# Extracting features from song_id: 603
# Extracting features from song_id: 605
# Extracting features from song_id: 606
# Extracting features from song_id: 607
# Extracting features from song_id: 608
# Extracting features from song_id: 609
# Extracting features from song_id: 610
# Extracting features from song_id: 611
# Extracting features from song_id: 612
# Extracting features from song_id: 613
# Extracting features from song_id: 614
# Extracting features from song_id: 615
# Extracting features from song_id: 616
# Extracting features from song_id: 617
# Extracting features from song_id: 621
# Extracting features from song_id: 622
# Extracting features from song_id: 623
# Extracting features from song_id: 624
# Extracting features from song_id: 625
# Extracting features from song_id: 626
# Extracting features from song_id: 627
# Extracting features from song_id: 628
# Extracting features from song_id: 629
# Extracting features from song_id: 630
# Extracting features from song_id: 631
# Extracting features from song_id: 632
# Extracting features from song_id: 634
# Extracting features from song_id: 635
# Extracting features from song_id: 636
# Extracting features from song_id: 637
# Extracting features from song_id: 638
# Extracting features from song_id: 639
# Extracting features from song_id: 643
# Extracting features from song_id: 644
# Extracting features from song_id: 645
# Extracting features from song_id: 646
# Extracting features from song_id: 647
# Extracting features from song_id: 648
# Extracting features from song_id: 649
# Extracting features from song_id: 650
# Extracting features from song_id: 651
# Extracting features from song_id: 652
# Extracting features from song_id: 653
# Extracting features from song_id: 654
# Extracting features from song_id: 656
# Extracting features from song_id: 657
# Extracting features from song_id: 659
# Extracting features from song_id: 660
# Extracting features from song_id: 661
# Extracting features from song_id: 662
# Extracting features from song_id: 665
# Extracting features from song_id: 666
# Extracting features from song_id: 668
# Extracting features from song_id: 670
# Extracting features from song_id: 671
# Extracting features from song_id: 672
# Extracting features from song_id: 673
# Extracting features from song_id: 674
# Extracting features from song_id: 675
# Extracting features from song_id: 676
# Extracting features from song_id: 677
# Extracting features from song_id: 678
# Extracting features from song_id: 679
# Extracting features from song_id: 681
# Extracting features from song_id: 682
# Extracting features from song_id: 683
# Extracting features from song_id: 684
# Extracting features from song_id: 685
# Extracting features from song_id: 686
# Extracting features from song_id: 687
# Extracting features from song_id: 688
# Extracting features from song_id: 689
# Extracting features from song_id: 692
# Extracting features from song_id: 693
# Extracting features from song_id: 694
# Extracting features from song_id: 697
# Extracting features from song_id: 698
# Extracting features from song_id: 699
# Extracting features from song_id: 700
# Extracting features from song_id: 703
# Extracting features from song_id: 704
# Extracting features from song_id: 705
# Extracting features from song_id: 706
# Extracting features from song_id: 707
# Extracting features from song_id: 708
# Extracting features from song_id: 710
# Extracting features from song_id: 711
# Extracting features from song_id: 713
# Extracting features from song_id: 715
# Extracting features from song_id: 716
# Extracting features from song_id: 717
# Extracting features from song_id: 718
# Extracting features from song_id: 719
# Extracting features from song_id: 720
# Extracting features from song_id: 722
# Extracting features from song_id: 726
# Extracting features from song_id: 727
# Extracting features from song_id: 728
# Extracting features from song_id: 730
# Extracting features from song_id: 729
# Extracting features from song_id: 731
# Extracting features from song_id: 732
# Extracting features from song_id: 733
# Extracting features from song_id: 734
# Extracting features from song_id: 736
# Extracting features from song_id: 738
# Extracting features from song_id: 739
# Extracting features from song_id: 740
# Extracting features from song_id: 741
# Extracting features from song_id: 742
# Extracting features from song_id: 743
# Extracting features from song_id: 744
# Extracting features from song_id: 745
# Extracting features from song_id: 746
# Extracting features from song_id: 747
# Extracting features from song_id: 748
# Extracting features from song_id: 749
# Extracting features from song_id: 750
# Extracting features from song_id: 751
# Extracting features from song_id: 752
# Extracting features from song_id: 753
# Extracting features from song_id: 754
# Extracting features from song_id: 755
# Extracting features from song_id: 757
# Extracting features from song_id: 758
# Extracting features from song_id: 759
# Extracting features from song_id: 760
# Extracting features from song_id: 761
# Extracting features from song_id: 763
# Extracting features from song_id: 765
# Extracting features from song_id: 767
# Extracting features from song_id: 769
# Extracting features from song_id: 770
# Extracting features from song_id: 771
# Extracting features from song_id: 772
# Extracting features from song_id: 773
# Extracting features from song_id: 774
# Extracting features from song_id: 775
# Extracting features from song_id: 776
# Extracting features from song_id: 777
# Extracting features from song_id: 778
# Extracting features from song_id: 779
# Extracting features from song_id: 780
# Extracting features from song_id: 783
# Extracting features from song_id: 784
# Extracting features from song_id: 786
# Extracting features from song_id: 788
# Extracting features from song_id: 789
# Extracting features from song_id: 790
# Extracting features from song_id: 791
# Extracting features from song_id: 792
# Extracting features from song_id: 793
# Extracting features from song_id: 794
# Extracting features from song_id: 796
# Extracting features from song_id: 797
# Extracting features from song_id: 798
# Extracting features from song_id: 799
# Extracting features from song_id: 801
# Extracting features from song_id: 803
# Extracting features from song_id: 804
# Extracting features from song_id: 806
# Extracting features from song_id: 807
# Extracting features from song_id: 808
# Extracting features from song_id: 809
# Extracting features from song_id: 810
# Extracting features from song_id: 812
# Extracting features from song_id: 813
# Extracting features from song_id: 814
# Extracting features from song_id: 815
# Extracting features from song_id: 816
# Extracting features from song_id: 818
# Extracting features from song_id: 820
# Extracting features from song_id: 821
# Extracting features from song_id: 823
# Extracting features from song_id: 824
# Extracting features from song_id: 825
# Extracting features from song_id: 827
# Extracting features from song_id: 828
# Extracting features from song_id: 829
# Extracting features from song_id: 830
# Extracting features from song_id: 831
# Extracting features from song_id: 832
# Extracting features from song_id: 833
# Extracting features from song_id: 834
# Extracting features from song_id: 835
# Extracting features from song_id: 836
# Extracting features from song_id: 837
# Extracting features from song_id: 839
# Extracting features from song_id: 842
# Extracting features from song_id: 844
# Extracting features from song_id: 846
# Extracting features from song_id: 847
# Extracting features from song_id: 848
# Extracting features from song_id: 850
# Extracting features from song_id: 851
# Extracting features from song_id: 852
# Extracting features from song_id: 853
# Extracting features from song_id: 854
# Extracting features from song_id: 855
# Extracting features from song_id: 857
# Extracting features from song_id: 858
# Extracting features from song_id: 859
# Extracting features from song_id: 860
# Extracting features from song_id: 861
# Extracting features from song_id: 862
# Extracting features from song_id: 863
# Extracting features from song_id: 864
# Extracting features from song_id: 865
# Extracting features from song_id: 866
# Extracting features from song_id: 868
# Extracting features from song_id: 869
# Extracting features from song_id: 870
# Extracting features from song_id: 871
# Extracting features from song_id: 876
# Extracting features from song_id: 879
# Extracting features from song_id: 880
# Extracting features from song_id: 881
# Extracting features from song_id: 882
# Extracting features from song_id: 883
# Extracting features from song_id: 884
# Extracting features from song_id: 885
# Extracting features from song_id: 886
# Extracting features from song_id: 888
# Extracting features from song_id: 889
# Extracting features from song_id: 890
# Extracting features from song_id: 892
# Extracting features from song_id: 894
# Extracting features from song_id: 895
# Extracting features from song_id: 896
# Extracting features from song_id: 897
# Extracting features from song_id: 900
# Extracting features from song_id: 903
# Extracting features from song_id: 904
# Extracting features from song_id: 905
# Extracting features from song_id: 906
# Extracting features from song_id: 907
# Extracting features from song_id: 908
# Extracting features from song_id: 909
# Extracting features from song_id: 911
# Extracting features from song_id: 913
# Extracting features from song_id: 915
# Extracting features from song_id: 916
# Extracting features from song_id: 917
# Extracting features from song_id: 918
# Extracting features from song_id: 919
# Extracting features from song_id: 921
# Extracting features from song_id: 922
# Extracting features from song_id: 924
# Extracting features from song_id: 925
# Extracting features from song_id: 926
# Extracting features from song_id: 927
# Extracting features from song_id: 928
# Extracting features from song_id: 929
# Extracting features from song_id: 931
# Extracting features from song_id: 932
# Extracting features from song_id: 933
# Extracting features from song_id: 934
# Extracting features from song_id: 935
# Extracting features from song_id: 936
# Extracting features from song_id: 937
# Extracting features from song_id: 938
# Extracting features from song_id: 939
# Extracting features from song_id: 940
# Extracting features from song_id: 941
# Extracting features from song_id: 943
# Extracting features from song_id: 945
# Extracting features from song_id: 946
# Extracting features from song_id: 948
# Extracting features from song_id: 950
# Extracting features from song_id: 951
# Extracting features from song_id: 952
# Extracting features from song_id: 953
# Extracting features from song_id: 957
# Extracting features from song_id: 958
# Extracting features from song_id: 959
# Extracting features from song_id: 962
# Extracting features from song_id: 964
# Extracting features from song_id: 965
# Extracting features from song_id: 966
# Extracting features from song_id: 967
# Extracting features from song_id: 968
# Extracting features from song_id: 969
# Extracting features from song_id: 970
# Extracting features from song_id: 971
# Extracting features from song_id: 973
# Extracting features from song_id: 974
# Extracting features from song_id: 978
# Extracting features from song_id: 979
# Extracting features from song_id: 980
# Extracting features from song_id: 981
# Extracting features from song_id: 983
# Extracting features from song_id: 984
# Extracting features from song_id: 985
# Extracting features from song_id: 989
# Extracting features from song_id: 992
# Extracting features from song_id: 993
# Extracting features from song_id: 996
# Extracting features from song_id: 997
# Extracting features from song_id: 999
# Extracting features from song_id: 1000
#      song_id  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0          1                          33.337425
# 1          4                          28.663845
# 2          5                          17.131292
# 3          6                          27.172243
# 4          7                          27.857573
# ..       ...                                ...
# 789      993                          28.589037
# 790      996                          34.963680
# 791      997                          23.521826
# 792      999                          28.412848
# 793     1000                          28.422981
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.292724
# 1                                  0.257283
# 2                                  0.444438
# 3                                  0.447355
# 4                                  0.326031
# ..                                      ...
# 789                                0.445477
# 790                                0.308940
# 791                                0.515144
# 792                                0.529474
# 793                                0.465772
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                     26.119843
# 1                                     22.888889
# 2                                     12.300488
# 3                                     13.918818
# 4                                     16.902195
# ..                                          ...
# 789                                   16.152197
# 790                                   23.050102
# 791                                   13.664935
# 792                                   14.129504
# 793                                   14.124825
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                     36.004002
# 1                                     28.891180
# 2                                     12.616845
# 3                                     25.472513
# 4                                     30.955669
# ..                                          ...
# 789                                   24.940647
# 790                                   39.976578
# 791                                   16.773577
# 792                                   21.055300
# 793                                   23.073471
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                     40.604488
# 1                                     34.114971
# 2                                     24.207296
# 3                                     43.135548
# 4                                     36.047791
# ..                                          ...
# 789                                   44.368267
# 790                                   43.117737
# 791                                   37.080620
# 792                                   48.873077
# 793                                   44.002636
#
#      F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                   14.484646
# 1                                   11.226082
# 2                                   11.906808
# 3                                   29.216728
# 4                                   19.145596
# ..                                        ...
# 789                                 28.216070
# 790                                 20.067635
# 791                                 23.415684
# 792                                 34.743572
# 793                                 29.877811
#
#      F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                     305.862122
# 1                                     181.813644
# 2                                     164.744644
# 3                                     311.857635
# 4                                     331.957245
# ..                                           ...
# 789                                   673.328918
# 790                                   337.409668
# 791                                   354.207977
# 792                                   832.962341
# 793                                   462.043030
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                       450.777679
# 1                                       127.028496
# 2                                       236.056610
# 3                                       277.610321
# 4                                       427.345398
# ..                                             ...
# 789                                     974.933533
# 790                                     449.238007
# 791                                     692.777161
# 792                                     972.408142
# 793                                     684.217712
#
#      F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  ...  \
# 0                                      146.386749  ...
# 1                                       60.697544  ...
# 2                                      100.181328  ...
# 3                                       97.866791  ...
# 4                                      121.956184  ...
# ..                                            ...  ...
# 789                                    230.685242  ...
# 790                                    146.028763  ...
# 791                                    256.592255  ...
# 792                                    152.828995  ...
# 793                                    289.294830  ...
#
#      slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                    -0.064266                     -0.011526
# 1                    -0.106618                     -0.022618
# 2                    -0.098165                     -0.014625
# 3                    -0.116574                     -0.008948
# 4                    -0.000146                     -0.015459
# ..                         ...                           ...
# 789                  -0.031968                     -0.011104
# 790                  -0.027622                     -0.003730
# 791                  -0.042555                     -0.007021
# 792                  -0.058397                     -0.006240
# 793                  -0.046183                     -0.005782
#
#      spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                       3.343537             3.623868              3.161190
# 1                       9.082945             4.177080              0.500715
# 2                       4.480471             4.177577              2.227251
# 3                       3.457023             3.565365              1.734694
# 4                       4.280516             3.375818              2.485330
# ..                           ...                  ...                   ...
# 789                     5.368369             2.822581              3.123903
# 790                     5.295775             3.517186              3.542834
# 791                     3.952860             3.032914              2.966540
# 792                     5.495892             2.307101              3.567762
# 793                     5.516090             2.129317              3.637781
#
#      MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                      0.175842                      0.189566
# 1                      0.465000                      0.899490
# 2                      0.301123                      0.359941
# 3                      0.103922                      0.143323
# 4                      0.342917                      0.373298
# ..                          ...                           ...
# 789                    0.203596                      0.721575
# 790                    0.147345                      0.171755
# 791                    0.219593                      0.315522
# 792                    0.128705                      0.298521
# 793                    0.135143                      0.219989
#
#      MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 0                     0.130000                     0.104119
# 1                     1.410667                     1.558009
# 2                     0.153117                     0.170928
# 3                     0.489787                     0.522769
# 4                     0.054167                     0.046226
# ..                         ...                          ...
# 789                   0.106312                     0.100384
# 790                   0.125217                     0.128034
# 791                   0.112945                     0.254109
# 792                   0.140853                     0.374921
# 793                   0.142371                     0.187633
#
#      equivalentSoundLevel_dBp
# 0                  -14.376077
# 1                   -8.796783
# 2                  -10.281398
# 3                  -10.272443
# 4                  -10.382742
# ..                        ...
# 789                -10.396038
# 790                 -9.722353
# 791                -10.379034
# 792                 -8.888767
# 793                -10.109124
#
# [794 rows x 89 columns]

# %% [markdown]
# Save the openSMILE-extracted features to .csv for eGeMAPS feature set

# %%
df_opensmile_egemaps.to_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{OPENSMILE_EGEMAPS_FEATURES_CSV}', index=False)

# %% [markdown]
# ### Import feature .csv files

# %%
df_opensmile_compare_2016 = pd.read_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{OPENSMILE_COMPARE2016_FEATURES_CSV}')
df_opensmile_emobase = pd.read_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{OPENSMILE_EMOBASE_FEATURES_CSV}')
df_opensmile_gemaps = pd.read_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{OPENSMILE_GEMAPS_FEATURES_CSV}')
df_opensmile_egemaps = pd.read_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{OPENSMILE_EGEMAPS_FEATURES_CSV}')

display(df_opensmile_compare_2016)
print(df_opensmile_compare_2016.shape)
# Out:
#      song_id  audspec_lengthL1norm_sma_range  audspec_lengthL1norm_sma_maxPos  \
# 0          1                        7.322202                         0.160250
# 1          4                        6.582460                         0.703399
# 2          5                        8.124249                         0.368032
# 3          6                        9.011615                         0.281728
# 4          7                        8.349628                         0.942354
# ..       ...                             ...                              ...
# 789      993                        8.483475                         0.763250
# 790      996                        8.911368                         0.202281
# 791      997                        8.573480                         0.461791
# 792      999                        8.656339                         0.792811
# 793     1000                        8.824550                         0.244802
#
#      audspec_lengthL1norm_sma_minPos  audspec_lengthL1norm_sma_quartile1  \
# 0                                0.0                            2.621674
# 1                                0.0                            1.656607
# 2                                0.0                            1.477557
# 3                                0.0                            2.313058
# 4                                0.0                            4.132348
# ..                               ...                                 ...
# 789                              0.0                            3.067161
# 790                              0.0                            4.574404
# 791                              0.0                            2.674772
# 792                              0.0                            4.998912
# 793                              0.0                            5.542526
#
#      audspec_lengthL1norm_sma_quartile2  audspec_lengthL1norm_sma_quartile3  \
# 0                              3.417233                            4.200210
# 1                              2.151616                            2.964223
# 2                              2.042911                            2.738106
# 3                              3.485445                            4.404951
# 4                              5.013152                            5.750350
# ..                                  ...                                 ...
# 789                            4.405553                            5.770013
# 790                            6.361631                            7.147145
# 791                            5.131298                            6.267901
# 792                            6.388689                            7.008387
# 793                            6.469470                            7.050390
#
#      audspec_lengthL1norm_sma_iqr1-2  audspec_lengthL1norm_sma_iqr2-3  \
# 0                           0.795559                         0.782976
# 1                           0.495009                         0.812608
# 2                           0.565354                         0.695195
# 3                           1.172387                         0.919506
# 4                           0.880803                         0.737199
# ..                               ...                              ...
# 789                         1.338392                         1.364460
# 790                         1.787228                         0.785513
# 791                         2.456525                         1.136603
# 792                         1.389777                         0.619698
# 793                         0.926944                         0.580920
#
#      audspec_lengthL1norm_sma_iqr1-3  ...  mfcc_sma_de[14]_peakRangeAbs  \
# 0                           1.578536  ...                      9.387893
# 1                           1.307617  ...                      7.649520
# 2                           1.260549  ...                      9.301864
# 3                           2.091893  ...                      9.001396
# 4                           1.618002  ...                      8.049467
# ..                               ...  ...                           ...
# 789                         2.702852  ...                      9.415093
# 790                         2.572741  ...                      9.883374
# 791                         3.593128  ...                      9.722556
# 792                         2.009475  ...                      8.010264
# 793                         1.507864  ...                      7.769637
#
#      mfcc_sma_de[14]_peakRangeRel  mfcc_sma_de[14]_peakMeanAbs  \
# 0                        0.527035                     2.584944
# 1                        0.493504                     2.592234
# 2                        0.578882                     2.421328
# 3                        0.577419                     2.309364
# 4                        0.513050                     2.204685
# ..                            ...                          ...
# 789                      0.519761                     2.557367
# 790                      0.546208                     2.423050
# 791                      0.604539                     2.208963
# 792                      0.556838                     2.027305
# 793                      0.510933                     2.139556
#
#      mfcc_sma_de[14]_peakMeanMeanDist  mfcc_sma_de[14]_peakMeanRel  \
# 0                            2.586223                   -20.000000
# 1                            2.594137                   -19.999989
# 2                            2.420420                    20.000000
# 3                            2.310359                   -20.000000
# 4                            2.211791                   -19.971230
# ..                                ...                          ...
# 789                          2.557284                    20.000000
# 790                          2.423151                   -20.000000
# 791                          2.208760                    20.000000
# 792                          2.026831                    20.000000
# 793                          2.138716                    20.000000
#
#      mfcc_sma_de[14]_minRangeRel  mfcc_sma_de[14]_meanRisingSlope  \
# 0                       0.636703                       108.890144
# 1                       0.637455                       104.337410
# 2                       0.547071                       104.202470
# 3                       0.491508                        97.956540
# 4                       0.553399                        94.180350
# ..                           ...                              ...
# 789                     0.653659                       103.939530
# 790                     0.616050                       112.232630
# 791                     0.511724                       104.249886
# 792                     0.565515                        98.668120
# 793                     0.571413                        93.072820
#
#      mfcc_sma_de[14]_stddevRisingSlope  mfcc_sma_de[14]_meanFallingSlope  \
# 0                            50.417366                        107.016620
# 1                            59.133785                        104.376335
# 2                            53.521988                        107.850940
# 3                            49.070080                         99.153725
# 4                            49.567486                         91.844630
# ..                                 ...                               ...
# 789                          59.248730                        107.771060
# 790                          57.986270                        107.318695
# 791                          53.459106                        100.819820
# 792                          51.425926                         96.999370
# 793                          48.014465                         91.802080
#
#      mfcc_sma_de[14]_stddevFallingSlope
# 0                             58.077972
# 1                             56.402073
# 2                             53.353096
# 3                             51.412000
# 4                             46.409393
# ..                                  ...
# 789                           58.497486
# 790                           52.195194
# 791                           54.904305
# 792                           52.407906
# 793                           48.417427
#
# [794 rows x 6374 columns]
# (794, 6374)

# %%
display(df_opensmile_emobase)
print(df_opensmile_emobase.shape)
# Out:
#      song_id  pcm_intensity_sma_max  pcm_intensity_sma_min  \
# 0          1               0.000069                    0.0
# 1          4               0.000203                    0.0
# 2          5               0.000207                    0.0
# 3          6               0.000145                    0.0
# 4          7               0.000140                    0.0
# ..       ...                    ...                    ...
# 789      993               0.000200                    0.0
# 790      996               0.000157                    0.0
# 791      997               0.000161                    0.0
# 792      999               0.000155                    0.0
# 793     1000               0.000156                    0.0
#
#      pcm_intensity_sma_range  pcm_intensity_sma_maxPos  \
# 0                   0.000069                     680.0
# 1                   0.000203                    2735.0
# 2                   0.000207                    7809.0
# 3                   0.000145                     324.0
# 4                   0.000140                    1182.0
# ..                       ...                       ...
# 789                 0.000200                    4500.0
# 790                 0.000157                     865.0
# 791                 0.000161                     589.0
# 792                 0.000155                    2217.0
# 793                 0.000156                    6664.0
#
#      pcm_intensity_sma_minPos  pcm_intensity_sma_amean  \
# 0                         0.0                 0.000010
# 1                         0.0                 0.000035
# 2                         0.0                 0.000025
# 3                         0.0                 0.000025
# 4                         0.0                 0.000024
# ..                        ...                      ...
# 789                       0.0                 0.000025
# 790                       0.0                 0.000028
# 791                       0.0                 0.000024
# 792                       0.0                 0.000032
# 793                       0.0                 0.000026
#
#      pcm_intensity_sma_linregc1  pcm_intensity_sma_linregc2  \
# 0                  1.561768e-09                    0.000007
# 1                  9.982415e-09                    0.000021
# 2                  9.522875e-10                    0.000021
# 3                 -4.371458e-09                    0.000031
# 4                  6.233813e-09                    0.000015
# ..                          ...                         ...
# 789               -1.041277e-09                    0.000028
# 790               -3.948720e-10                    0.000029
# 791               -7.007779e-09                    0.000045
# 792               -8.242266e-09                    0.000048
# 793                4.878849e-10                    0.000024
#
#      pcm_intensity_sma_linregerrA  ...  F0env_sma_de_linregerrQ  \
# 0                        0.000007  ...                24.663260
# 1                        0.000025  ...                 6.708408
# 2                        0.000023  ...                31.890630
# 3                        0.000022  ...                42.263218
# 4                        0.000018  ...                16.184336
# ..                            ...  ...                      ...
# 789                      0.000022  ...                21.283978
# 790                      0.000020  ...                16.420145
# 791                      0.000017  ...                16.416569
# 792                      0.000022  ...                21.666965
# 793                      0.000017  ...                 6.712265
#
#      F0env_sma_de_stddev  F0env_sma_de_skewness  F0env_sma_de_kurtosis  \
# 0               4.969058               1.753136              23.013176
# 1               2.596165               0.676692              38.048588
# 2               5.647370               0.340074               6.558109
# 3               6.504123              -0.035226               4.723821
# 4               4.024880               2.228209              31.618954
# ..                   ...                    ...                    ...
# 789             4.614609               1.045086              23.684689
# 790             4.055081               0.161662              11.100394
# 791             4.052447               1.994095              28.915573
# 792             4.656510               0.786846              19.122852
# 793             2.591530               3.255945              76.950320
#
#      F0env_sma_de_quartile1  F0env_sma_de_quartile2  F0env_sma_de_quartile3  \
# 0                 -0.823868                     0.0                0.684412
# 1                  0.000000                     0.0                0.000000
# 2                 -1.443779                     0.0                1.079922
# 3                 -2.500313                     0.0                2.730563
# 4                 -0.120087                     0.0                0.047111
# ..                      ...                     ...                     ...
# 789               -0.047910                     0.0                0.427303
# 790                0.000000                     0.0                0.000000
# 791               -0.340640                     0.0                0.133139
# 792                0.000000                     0.0                0.006744
# 793                0.000000                     0.0                0.000000
#
#      F0env_sma_de_iqr1-2  F0env_sma_de_iqr2-3  F0env_sma_de_iqr1-3
# 0               0.823868             0.684412             1.508279
# 1               0.000000             0.000000             0.000000
# 2               1.443779             1.079922             2.523702
# 3               2.500313             2.730563             5.230876
# 4               0.120087             0.047111             0.167197
# ..                   ...                  ...                  ...
# 789             0.047910             0.427303             0.475213
# 790             0.000000             0.000000             0.000000
# 791             0.340640             0.133139             0.473779
# 792             0.000000             0.006744             0.006744
# 793             0.000000             0.000000             0.000000
#
# [794 rows x 989 columns]
# (794, 989)

# %%
display(df_opensmile_gemaps)
print(df_opensmile_gemaps.shape)
# Out:
#      song_id  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0          1                          33.337425
# 1          4                          28.663845
# 2          5                          17.131292
# 3          6                          27.172243
# 4          7                          27.857573
# ..       ...                                ...
# 789      993                          28.589037
# 790      996                          34.963680
# 791      997                          23.521826
# 792      999                          28.412848
# 793     1000                          28.422981
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.292724
# 1                                  0.257283
# 2                                  0.444438
# 3                                  0.447355
# 4                                  0.326031
# ..                                      ...
# 789                                0.445477
# 790                                0.308940
# 791                                0.515144
# 792                                0.529474
# 793                                0.465772
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                     26.119843
# 1                                     22.888890
# 2                                     12.300488
# 3                                     13.918818
# 4                                     16.902195
# ..                                          ...
# 789                                   16.152197
# 790                                   23.050102
# 791                                   13.664935
# 792                                   14.129504
# 793                                   14.124825
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                     36.004000
# 1                                     28.891180
# 2                                     12.616845
# 3                                     25.472513
# 4                                     30.955670
# ..                                          ...
# 789                                   24.940647
# 790                                   39.976578
# 791                                   16.773577
# 792                                   21.055300
# 793                                   23.073471
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                     40.604490
# 1                                     34.114970
# 2                                     24.207296
# 3                                     43.135548
# 4                                     36.047790
# ..                                          ...
# 789                                   44.368267
# 790                                   43.117737
# 791                                   37.080620
# 792                                   48.873077
# 793                                   44.002636
#
#      F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                   14.484646
# 1                                   11.226082
# 2                                   11.906808
# 3                                   29.216728
# 4                                   19.145596
# ..                                        ...
# 789                                 28.216070
# 790                                 20.067635
# 791                                 23.415684
# 792                                 34.743572
# 793                                 29.877811
#
#      F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                      305.86212
# 1                                      181.81364
# 2                                      164.74464
# 3                                      311.85764
# 4                                      331.95724
# ..                                           ...
# 789                                    673.32890
# 790                                    337.40967
# 791                                    354.20798
# 792                                    832.96234
# 793                                    462.04303
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                       450.777680
# 1                                       127.028496
# 2                                       236.056610
# 3                                       277.610320
# 4                                       427.345400
# ..                                             ...
# 789                                     974.933530
# 790                                     449.238000
# 791                                     692.777160
# 792                                     972.408140
# 793                                     684.217700
#
#      F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  ...  \
# 0                                      146.386750  ...
# 1                                       60.697544  ...
# 2                                      100.181330  ...
# 3                                       97.866790  ...
# 4                                      121.956184  ...
# ..                                            ...  ...
# 789                                    230.685240  ...
# 790                                    146.028760  ...
# 791                                    256.592250  ...
# 792                                    152.829000  ...
# 793                                    289.294830  ...
#
#      alphaRatioUV_sma3nz_amean  hammarbergIndexUV_sma3nz_amean  \
# 0                    -9.104095                       18.212526
# 1                   -23.523148                       34.651325
# 2                   -22.474178                       32.335780
# 3                   -13.287336                       22.688347
# 4                    -6.551864                       12.755936
# ..                         ...                             ...
# 789                  -5.758517                       12.847198
# 790                  -6.366639                       16.632452
# 791                  -4.795950                       14.046479
# 792                  -5.796313                       14.950939
# 793                  -4.264546                       11.774019
#
#      slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                    -0.064266                     -0.011526
# 1                    -0.106618                     -0.022618
# 2                    -0.098165                     -0.014625
# 3                    -0.116574                     -0.008948
# 4                    -0.000146                     -0.015459
# ..                         ...                           ...
# 789                  -0.031968                     -0.011104
# 790                  -0.027622                     -0.003730
# 791                  -0.042555                     -0.007021
# 792                  -0.058397                     -0.006240
# 793                  -0.046183                     -0.005782
#
#      loudnessPeaksPerSec  VoicedSegmentsPerSec  MeanVoicedSegmentLengthSec  \
# 0               3.623868              3.161190                    0.175842
# 1               4.177080              0.500715                    0.465000
# 2               4.177577              2.227251                    0.301123
# 3               3.565365              1.734694                    0.103922
# 4               3.375818              2.485330                    0.342917
# ..                   ...                   ...                         ...
# 789             2.822581              3.123903                    0.203596
# 790             3.517186              3.542834                    0.147345
# 791             3.032914              2.966540                    0.219593
# 792             2.307101              3.567762                    0.128705
# 793             2.129317              3.637781                    0.135143
#
#      StddevVoicedSegmentLengthSec  MeanUnvoicedSegmentLength  \
# 0                        0.189566                   0.130000
# 1                        0.899490                   1.410667
# 2                        0.359941                   0.153117
# 3                        0.143323                   0.489787
# 4                        0.373298                   0.054167
# ..                            ...                        ...
# 789                      0.721575                   0.106313
# 790                      0.171755                   0.125217
# 791                      0.315522                   0.112945
# 792                      0.298521                   0.140853
# 793                      0.219989                   0.142371
#
#      StddevUnvoicedSegmentLength
# 0                       0.104119
# 1                       1.558009
# 2                       0.170928
# 3                       0.522769
# 4                       0.046226
# ..                           ...
# 789                     0.100384
# 790                     0.128034
# 791                     0.254109
# 792                     0.374921
# 793                     0.187633
#
# [794 rows x 63 columns]
# (794, 63)

# %%
display(df_opensmile_egemaps)
print(df_opensmile_egemaps.shape)
# Out:
#      song_id  F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0          1                          33.337425
# 1          4                          28.663845
# 2          5                          17.131292
# 3          6                          27.172243
# 4          7                          27.857573
# ..       ...                                ...
# 789      993                          28.589037
# 790      996                          34.963680
# 791      997                          23.521826
# 792      999                          28.412848
# 793     1000                          28.422981
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                  0.292724
# 1                                  0.257283
# 2                                  0.444438
# 3                                  0.447355
# 4                                  0.326031
# ..                                      ...
# 789                                0.445477
# 790                                0.308940
# 791                                0.515144
# 792                                0.529474
# 793                                0.465772
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                     26.119843
# 1                                     22.888890
# 2                                     12.300488
# 3                                     13.918818
# 4                                     16.902195
# ..                                          ...
# 789                                   16.152197
# 790                                   23.050102
# 791                                   13.664935
# 792                                   14.129504
# 793                                   14.124825
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                     36.004000
# 1                                     28.891180
# 2                                     12.616845
# 3                                     25.472513
# 4                                     30.955670
# ..                                          ...
# 789                                   24.940647
# 790                                   39.976578
# 791                                   16.773577
# 792                                   21.055300
# 793                                   23.073471
#
#      F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                     40.604490
# 1                                     34.114970
# 2                                     24.207296
# 3                                     43.135548
# 4                                     36.047790
# ..                                          ...
# 789                                   44.368267
# 790                                   43.117737
# 791                                   37.080620
# 792                                   48.873077
# 793                                   44.002636
#
#      F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                   14.484646
# 1                                   11.226082
# 2                                   11.906808
# 3                                   29.216728
# 4                                   19.145596
# ..                                        ...
# 789                                 28.216070
# 790                                 20.067635
# 791                                 23.415684
# 792                                 34.743572
# 793                                 29.877811
#
#      F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  \
# 0                                      305.86212
# 1                                      181.81364
# 2                                      164.74464
# 3                                      311.85764
# 4                                      331.95724
# ..                                           ...
# 789                                    673.32890
# 790                                    337.40967
# 791                                    354.20798
# 792                                    832.96234
# 793                                    462.04303
#
#      F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope  \
# 0                                       450.777680
# 1                                       127.028496
# 2                                       236.056610
# 3                                       277.610320
# 4                                       427.345400
# ..                                             ...
# 789                                     974.933530
# 790                                     449.238000
# 791                                     692.777160
# 792                                     972.408140
# 793                                     684.217700
#
#      F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope  ...  \
# 0                                      146.386750  ...
# 1                                       60.697544  ...
# 2                                      100.181330  ...
# 3                                       97.866790  ...
# 4                                      121.956184  ...
# ..                                            ...  ...
# 789                                    230.685240  ...
# 790                                    146.028760  ...
# 791                                    256.592250  ...
# 792                                    152.829000  ...
# 793                                    289.294830  ...
#
#      slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                    -0.064266                     -0.011526
# 1                    -0.106618                     -0.022618
# 2                    -0.098165                     -0.014625
# 3                    -0.116574                     -0.008948
# 4                    -0.000146                     -0.015459
# ..                         ...                           ...
# 789                  -0.031968                     -0.011104
# 790                  -0.027622                     -0.003730
# 791                  -0.042555                     -0.007021
# 792                  -0.058397                     -0.006240
# 793                  -0.046183                     -0.005782
#
#      spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                       3.343537             3.623868              3.161190
# 1                       9.082945             4.177080              0.500715
# 2                       4.480471             4.177577              2.227251
# 3                       3.457023             3.565365              1.734694
# 4                       4.280516             3.375818              2.485330
# ..                           ...                  ...                   ...
# 789                     5.368369             2.822581              3.123903
# 790                     5.295775             3.517186              3.542834
# 791                     3.952860             3.032914              2.966540
# 792                     5.495892             2.307101              3.567762
# 793                     5.516090             2.129317              3.637781
#
#      MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                      0.175842                      0.189566
# 1                      0.465000                      0.899490
# 2                      0.301123                      0.359941
# 3                      0.103922                      0.143323
# 4                      0.342917                      0.373298
# ..                          ...                           ...
# 789                    0.203596                      0.721575
# 790                    0.147345                      0.171755
# 791                    0.219593                      0.315522
# 792                    0.128705                      0.298521
# 793                    0.135143                      0.219989
#
#      MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 0                     0.130000                     0.104119
# 1                     1.410667                     1.558009
# 2                     0.153117                     0.170928
# 3                     0.489787                     0.522769
# 4                     0.054167                     0.046226
# ..                         ...                          ...
# 789                   0.106313                     0.100384
# 790                   0.125217                     0.128034
# 791                   0.112945                     0.254109
# 792                   0.140853                     0.374921
# 793                   0.142371                     0.187633
#
#      equivalentSoundLevel_dBp
# 0                  -14.376077
# 1                   -8.796783
# 2                  -10.281398
# 3                  -10.272443
# 4                  -10.382742
# ..                        ...
# 789                -10.396038
# 790                 -9.722353
# 791                -10.379034
# 792                 -8.888767
# 793                -10.109124
#
# [794 rows x 89 columns]
# (794, 89)

# %% [markdown]
# ## Essentia

# %% [markdown]
# Import Essentia and other relevant libraries

# %%
import essentia
import essentia.standard as es
from essentia.standard import *

import json
import numpy as np

# %% [markdown]
# Extract the features from one .mp3 file and see the features

# %%
audio_file = SAMPLE_PMEMO_AUDIO_PATH

features, features_frames = es.MusicExtractor()(audio_file)

feature_names = features.descriptorNames()
feature_values = [features[name] for name in feature_names]

# Create a dictionary with feature names and values
features_dict = {name: value for name, value in zip(feature_names, feature_values)}
df_essentia_all_sample = pd.json_normalize(features_dict)

df_essentia_all_sample
# Out:
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#    lowlevel.average_loudness  lowlevel.barkbands_crest.dmean  \
# 0                   0.930816                        2.393482
#
#    lowlevel.barkbands_crest.dmean2  lowlevel.barkbands_crest.dvar  \
# 0                         3.616346                       9.754375
#
#    lowlevel.barkbands_crest.dvar2  lowlevel.barkbands_crest.max  \
# 0                       20.004459                     26.715527
#
#    lowlevel.barkbands_crest.mean  lowlevel.barkbands_crest.median  \
# 0                      18.051006                        18.184444
#
#    lowlevel.barkbands_crest.min  lowlevel.barkbands_crest.stdev  ...  \
# 0                      2.864332                        6.100605  ...
#
#    tonal.key_edma.key  tonal.key_edma.scale  tonal.key_krumhansl.key  \
# 0                   D                 minor                        D
#
#    tonal.key_krumhansl.scale  tonal.key_temperley.key  \
# 0                      minor                        D
#
#    tonal.key_temperley.scale  metadata.tags.album  metadata.tags.artist  \
# 0                      minor        [Savage Mode]           [21 Savage]
#
#    metadata.tags.encoding  metadata.tags.title
# 0         [Lavf57.83.100]           [No Heart]
#
# [1 rows x 581 columns]

# %% [markdown]
# Lets drop the last 4 metadata columns

# %%
feature_names = features.descriptorNames()[:-4]
feature_values = [features[name] for name in feature_names]

# Create a dictionary with feature names and values
features_dict = {name: value for name, value in zip(feature_names, feature_values)}
df_essentia_all_sample = pd.json_normalize(features_dict)

df_essentia_all_sample
# Out:
#    lowlevel.average_loudness  lowlevel.barkbands_crest.dmean  \
# 0                   0.930816                        2.393482
#
#    lowlevel.barkbands_crest.dmean2  lowlevel.barkbands_crest.dvar  \
# 0                         3.616346                       9.754375
#
#    lowlevel.barkbands_crest.dvar2  lowlevel.barkbands_crest.max  \
# 0                       20.004459                     26.715527
#
#    lowlevel.barkbands_crest.mean  lowlevel.barkbands_crest.median  \
# 0                      18.051006                        18.184444
#
#    lowlevel.barkbands_crest.min  lowlevel.barkbands_crest.stdev  ...  \
# 0                      2.864332                        6.100605  ...
#
#    metadata.version.essentia_git_sha  metadata.version.extractor  \
# 0    v2.1_beta5-1110-g77a6a954-dirty                   music 2.0
#
#    tonal.chords_key  tonal.chords_scale  tonal.key_edma.key  \
# 0                 A               minor                   D
#
#    tonal.key_edma.scale  tonal.key_krumhansl.key  tonal.key_krumhansl.scale  \
# 0                 minor                        D                      minor
#
#    tonal.key_temperley.key  tonal.key_temperley.scale
# 0                        D                      minor
#
# [1 rows x 577 columns]

# %% [markdown]
# Extract all 577 features from all songs

# %% [markdown]
# Prepare to extract features from all audio files

# %%
# Function to extract features for a song ID
def extract_features(song_id):
    print(f'Extracting features from song_id: {song_id}')
    audio_file = f'{PMEMO_AUDIO_FOLDER}/{song_id}.mp3'
    features, _ = es.MusicExtractor()(audio_file)
    feature_values = [features[name] for name in feature_names]
    features_dict = {name: value for name, value in zip(feature_names, feature_values)}
    return pd.json_normalize(features_dict)

# %% [markdown]
# Extract all features from all audio files using Essentia

# %%
# Parallelize feature extraction for all song IDs
dfs = Parallel(n_jobs=-1)(delayed(extract_features)(song_id) for song_id in song_ids)

# Concatenate the extracted DataFrames
df_essentia_all = pd.concat(dfs, ignore_index=True)

# Add the 'song_id' column
df_essentia_all.insert(0, 'song_id', song_ids)

# Display the resulting DataFrame
df_essentia_all
# Out:
# Extracting features from song_id: 6
# Extracting features from song_id: 14
# Extracting features from song_id: 7
# Extracting features from song_id: 10
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 8
# Extracting features from song_id: 9
# Extracting features from song_id: 1
# Extracting features from song_id: 5
# Extracting features from song_id: 4
# Extracting features from song_id: 13
# Extracting features from song_id: 12
# Extracting features from song_id: 11
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 15
# Extracting features from song_id: 16
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# Extracting features from song_id: 17
# Extracting features from song_id: 18
# Extracting features from song_id: 19
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 20
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 21
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 23
# Extracting features from song_id: 25
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 26
# Extracting features from song_id: 28
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 29
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 30
# Extracting features from song_id: 31
# Extracting features from song_id: 32
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 33
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 34
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 35
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 37
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 38
# Extracting features from song_id: 39
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 40
# Extracting features from song_id: 42
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# Extracting features from song_id: 43
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 44
# Extracting features from song_id: 46
# Extracting features from song_id: 47
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 48
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 49
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 50
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# Extracting features from song_id: 51
# Extracting features from song_id: 52
# Extracting features from song_id: 54
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 55
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 56
# Extracting features from song_id: 57
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 58
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 59
# Extracting features from song_id: 60
# Extracting features from song_id: 61
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# Extracting features from song_id: 63
# Extracting features from song_id: 64
# Extracting features from song_id: 65
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 66
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 67
# Extracting features from song_id: 68
# Extracting features from song_id: 69
# Extracting features from song_id: 70
# Extracting features from song_id: 71
# Extracting features from song_id: 72
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 73
# Extracting features from song_id: 74
# Extracting features from song_id: 75
# Extracting features from song_id: 76
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 78
# Extracting features from song_id: 79
# Extracting features from song_id: 80
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 81
# Extracting features from song_id: 83
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 84
# Extracting features from song_id: 85
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 86
# Extracting features from song_id: 87
# Extracting features from song_id: 88
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# Extracting features from song_id: 89
# Extracting features from song_id: 90
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 91
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 92
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# Extracting features from song_id: 93
# Extracting features from song_id: 94
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# Extracting features from song_id: 95
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 96
# Extracting features from song_id: 97
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# Extracting features from song_id: 98
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 99
# Extracting features from song_id: 100
# Extracting features from song_id: 101
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# Extracting features from song_id: 102
# Extracting features from song_id: 103
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# Extracting features from song_id: 104
# Extracting features from song_id: 105
# Extracting features from song_id: 106
# Extracting features from song_id: 107
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# Extracting features from song_id: 108
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 109
# Extracting features from song_id: 110
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 113
# Extracting features from song_id: 114
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# Extracting features from song_id: 115
# Extracting features from song_id: 116
# Extracting features from song_id: 117
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 118
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 119
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# Extracting features from song_id: 120
# Extracting features from song_id: 123
# Extracting features from song_id: 124
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 126
# Extracting features from song_id: 127
# Extracting features from song_id: 128
# Extracting features from song_id: 132
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 133
# Extracting features from song_id: 134
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 135
# Extracting features from song_id: 136
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 137
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# Extracting features from song_id: 138
# Extracting features from song_id: 139
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 140
# Extracting features from song_id: 141
# Extracting features from song_id: 142
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# Extracting features from song_id: 143
# Extracting features from song_id: 144
# Extracting features from song_id: 145
# Extracting features from song_id: 146
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# Extracting features from song_id: 147
# Extracting features from song_id: 148
# Extracting features from song_id: 149
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# Extracting features from song_id: 150
# Extracting features from song_id: 151
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 152
# Extracting features from song_id: 153
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 156
# Extracting features from song_id: 157
# Extracting features from song_id: 158
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 159
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# Extracting features from song_id: 160
# Extracting features from song_id: 161
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# Extracting features from song_id: 162
# Extracting features from song_id: 165
# Extracting features from song_id: 166
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 167
# Extracting features from song_id: 168
# Extracting features from song_id: 169
# Extracting features from song_id: 170
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# Extracting features from song_id: 171
# [   INFO   ] MusicExtractor: Read metadata
# ...
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# Extracting features from song_id: 965
# Extracting features from song_id: 966
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# Extracting features from song_id: 967
# Extracting features from song_id: 968
# Extracting features from song_id: 969
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] All done
# Extracting features from song_id: 970
# Extracting features from song_id: 971
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 973
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 974
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# Extracting features from song_id: 978
# Extracting features from song_id: 979
# Extracting features from song_id: 980
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# Extracting features from song_id: 981
# Extracting features from song_id: 983
# Extracting features from song_id: 984
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Replay gain
# Extracting features from song_id: 985
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 989
# Extracting features from song_id: 992
# Extracting features from song_id: 993
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute audio features
# Extracting features from song_id: 996
# Extracting features from song_id: 997
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# [   INFO   ] MusicExtractor: Read metadata
# [   INFO   ] MusicExtractor: Compute md5 audio hash, codec, length, and EBU 128 loudness
# Extracting features from song_id: 999
# Extracting features from song_id: 1000
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Replay gain
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute audio features
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
# [   INFO   ] MusicExtractor: Compute aggregation
# [   INFO   ] All done
#      song_id  lowlevel.average_loudness  lowlevel.barkbands_crest.dmean  \
# 0          1                   0.970365                        2.386094
# 1          4                   0.938222                        2.208982
# 2          5                   0.930816                        2.393396
# 3          6                   0.954429                        1.710108
# 4          7                   0.970629                        3.049570
# ..       ...                        ...                             ...
# 789      993                   0.900841                        2.860945
# 790      996                   0.923707                        2.780023
# 791      997                   0.913454                        2.711854
# 792      999                   0.955402                        2.754321
# 793     1000                   0.960873                        2.290872
#
#      lowlevel.barkbands_crest.dmean2  lowlevel.barkbands_crest.dvar  \
# 0                           3.595045                       6.739827
# 1                           3.674735                       5.079084
# 2                           3.616220                       9.754746
# 3                           2.438493                       4.898606
# 4                           4.716667                      10.768312
# ..                               ...                            ...
# 789                         4.524004                       7.773111
# 790                         4.445585                       9.030848
# 791                         4.339240                       7.626590
# 792                         3.944306                       5.840963
# 793                         3.772490                       4.869064
#
#      lowlevel.barkbands_crest.dvar2  lowlevel.barkbands_crest.max  \
# 0                         14.443331                     25.484644
# 1                         13.380701                     24.118259
# 2                         20.005306                     26.715527
# 3                          8.559372                     24.963417
# 4                         23.467182                     25.671312
# ..                              ...                           ...
# 789                       19.615166                     24.813204
# 790                       20.220987                     25.388409
# 791                       20.526991                     25.967821
# 792                       11.530771                     25.688959
# 793                       12.682041                     23.621254
#
#      lowlevel.barkbands_crest.mean  lowlevel.barkbands_crest.median  \
# 0                        11.411405                        10.707484
# 1                        14.165496                        14.635095
# 2                        18.051132                        18.184444
# 3                        17.044807                        18.244125
# 4                        10.193559                         8.912777
# ..                             ...                              ...
# 789                      11.215879                        10.689340
# 790                      10.426328                         8.341273
# 791                      11.850028                        11.506009
# 792                      11.403641                         9.805414
# 793                       8.802839                         7.796326
#
#      lowlevel.barkbands_crest.min  ...  metadata.version.essentia_git_sha  \
# 0                        2.498400  ...    v2.1_beta5-1110-g77a6a954-dirty
# 1                        4.408802  ...    v2.1_beta5-1110-g77a6a954-dirty
# 2                        2.864332  ...    v2.1_beta5-1110-g77a6a954-dirty
# 3                        2.253785  ...    v2.1_beta5-1110-g77a6a954-dirty
# 4                        2.406512  ...    v2.1_beta5-1110-g77a6a954-dirty
# ..                            ...  ...                                ...
# 789                      2.157647  ...    v2.1_beta5-1110-g77a6a954-dirty
# 790                      2.059642  ...    v2.1_beta5-1110-g77a6a954-dirty
# 791                      2.347258  ...    v2.1_beta5-1110-g77a6a954-dirty
# 792                      2.655332  ...    v2.1_beta5-1110-g77a6a954-dirty
# 793                      2.127222  ...    v2.1_beta5-1110-g77a6a954-dirty
#
#      metadata.version.extractor  tonal.chords_key  tonal.chords_scale  \
# 0                     music 2.0                 G               major
# 1                     music 2.0                F#               major
# 2                     music 2.0                 A               minor
# 3                     music 2.0                 E               minor
# 4                     music 2.0                 G               major
# ..                          ...               ...                 ...
# 789                   music 2.0                 F               minor
# 790                   music 2.0                C#               minor
# 791                   music 2.0                Eb               major
# 792                   music 2.0                 B               minor
# 793                   music 2.0                Eb               major
#
#      tonal.key_edma.key  tonal.key_edma.scale  tonal.key_krumhansl.key  \
# 0                     G                 major                        G
# 1                    Bb                 major                       Bb
# 2                     D                 minor                        D
# 3                     C                 major                        C
# 4                     G                 major                        G
# ..                  ...                   ...                      ...
# 789                  Ab                 major                       Ab
# 790                  C#                 minor                       C#
# 791                  Ab                 major                       Ab
# 792                   B                 minor                        B
# 793                   G                 major                        G
#
#      tonal.key_krumhansl.scale  tonal.key_temperley.key  \
# 0                        major                        G
# 1                        major                       Bb
# 2                        minor                        D
# 3                        major                        C
# 4                        major                        G
# ..                         ...                      ...
# 789                      major                       Ab
# 790                      minor                       C#
# 791                      major                       Ab
# 792                      minor                        B
# 793                      major                        G
#
#      tonal.key_temperley.scale
# 0                        major
# 1                        major
# 2                        minor
# 3                        major
# 4                        major
# ..                         ...
# 789                      major
# 790                      minor
# 791                      major
# 792                      minor
# 793                      major
#
# [794 rows x 578 columns]

# %% [markdown]
# Save the extracted features dataframe to .csv

# %%
df_essentia_all.to_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{ESSENTIA_FEATURES_CSV}', index=False)

# %% [markdown]
# ### Import features .csv file

# %%
df_essentia_all = pd.read_csv(f'{PMEMO_EXTRACTED_FEATURES_FOLDER}/{ESSENTIA_FEATURES_CSV}')

display(df_essentia_all)
print(df_essentia_all.shape)
# Out:
#      song_id  lowlevel.average_loudness  lowlevel.barkbands_crest.dmean  \
# 0          1                   0.970365                        2.386094
# 1          4                   0.938222                        2.208982
# 2          5                   0.930816                        2.393396
# 3          6                   0.954429                        1.710108
# 4          7                   0.970629                        3.049570
# ..       ...                        ...                             ...
# 789      993                   0.900841                        2.860945
# 790      996                   0.923707                        2.780023
# 791      997                   0.913454                        2.711854
# 792      999                   0.955402                        2.754321
# 793     1000                   0.960873                        2.290872
#
#      lowlevel.barkbands_crest.dmean2  lowlevel.barkbands_crest.dvar  \
# 0                           3.595045                       6.739827
# 1                           3.674735                       5.079084
# 2                           3.616220                       9.754746
# 3                           2.438493                       4.898606
# 4                           4.716667                      10.768312
# ..                               ...                            ...
# 789                         4.524004                       7.773111
# 790                         4.445585                       9.030848
# 791                         4.339240                       7.626590
# 792                         3.944306                       5.840963
# 793                         3.772490                       4.869064
#
#      lowlevel.barkbands_crest.dvar2  lowlevel.barkbands_crest.max  \
# 0                         14.443331                     25.484644
# 1                         13.380701                     24.118259
# 2                         20.005306                     26.715527
# 3                          8.559372                     24.963417
# 4                         23.467182                     25.671312
# ..                              ...                           ...
# 789                       19.615166                     24.813204
# 790                       20.220987                     25.388409
# 791                       20.526991                     25.967821
# 792                       11.530771                     25.688959
# 793                       12.682041                     23.621254
#
#      lowlevel.barkbands_crest.mean  lowlevel.barkbands_crest.median  \
# 0                        11.411405                        10.707484
# 1                        14.165496                        14.635095
# 2                        18.051132                        18.184444
# 3                        17.044807                        18.244125
# 4                        10.193559                         8.912777
# ..                             ...                              ...
# 789                      11.215879                        10.689340
# 790                      10.426328                         8.341273
# 791                      11.850028                        11.506009
# 792                      11.403641                         9.805414
# 793                       8.802839                         7.796326
#
#      lowlevel.barkbands_crest.min  ...  metadata.version.essentia_git_sha  \
# 0                        2.498400  ...    v2.1_beta5-1110-g77a6a954-dirty
# 1                        4.408802  ...    v2.1_beta5-1110-g77a6a954-dirty
# 2                        2.864332  ...    v2.1_beta5-1110-g77a6a954-dirty
# 3                        2.253785  ...    v2.1_beta5-1110-g77a6a954-dirty
# 4                        2.406512  ...    v2.1_beta5-1110-g77a6a954-dirty
# ..                            ...  ...                                ...
# 789                      2.157647  ...    v2.1_beta5-1110-g77a6a954-dirty
# 790                      2.059642  ...    v2.1_beta5-1110-g77a6a954-dirty
# 791                      2.347258  ...    v2.1_beta5-1110-g77a6a954-dirty
# 792                      2.655332  ...    v2.1_beta5-1110-g77a6a954-dirty
# 793                      2.127222  ...    v2.1_beta5-1110-g77a6a954-dirty
#
#      metadata.version.extractor  tonal.chords_key  tonal.chords_scale  \
# 0                     music 2.0                 G               major
# 1                     music 2.0                F#               major
# 2                     music 2.0                 A               minor
# 3                     music 2.0                 E               minor
# 4                     music 2.0                 G               major
# ..                          ...               ...                 ...
# 789                   music 2.0                 F               minor
# 790                   music 2.0                C#               minor
# 791                   music 2.0                Eb               major
# 792                   music 2.0                 B               minor
# 793                   music 2.0                Eb               major
#
#      tonal.key_edma.key  tonal.key_edma.scale  tonal.key_krumhansl.key  \
# 0                     G                 major                        G
# 1                    Bb                 major                       Bb
# 2                     D                 minor                        D
# 3                     C                 major                        C
# 4                     G                 major                        G
# ..                  ...                   ...                      ...
# 789                  Ab                 major                       Ab
# 790                  C#                 minor                       C#
# 791                  Ab                 major                       Ab
# 792                   B                 minor                        B
# 793                   G                 major                        G
#
#      tonal.key_krumhansl.scale  tonal.key_temperley.key  \
# 0                        major                        G
# 1                        major                       Bb
# 2                        minor                        D
# 3                        major                        C
# 4                        major                        G
# ..                         ...                      ...
# 789                      major                       Ab
# 790                      minor                       C#
# 791                      major                       Ab
# 792                      minor                        B
# 793                      major                        G
#
#      tonal.key_temperley.scale
# 0                        major
# 1                        major
# 2                        minor
# 3                        major
# 4                        major
# ..                         ...
# 789                      major
# 790                      minor
# 791                      major
# 792                      minor
# 793                      major
#
# [794 rows x 578 columns]
# (794, 578)

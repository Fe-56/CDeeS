# %% [markdown]
# # Model Visualiser

# %%
import torchvision
from torchview import draw_graph

from feedforward_nn_combined import NeuralNetworkCombined

# %%
model_graph = draw_graph(
  NeuralNetworkCombined(62), 
  input_size=(2511, 62), 
  expand_nested=True
)
model_graph.visual_graph

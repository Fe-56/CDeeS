# %% [markdown]
# # DEAM Dataset - Feed Forward Neural Network
# ## openSMILE emobase Featureset

# %% [markdown]
# ## Import relevant libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torcheval.metrics import R2Score

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import math

import sys
sys.path.insert(1, '../../utils')
from paths import *

# %% [markdown]
# ## Define Functions for Neural Networks

# %% [markdown]
# Define function for converting dataframes to PyTorch tensors

# %%
def string_to_numpy_array(str):
  values = str.strip('[]').split()
  return np.array([float(value)for value in values]).flatten()

def convert_ndarray_col_to_tensor(df_object_col):
  # the df_object_col may be of the type object, but it is actually a numpy.ndarray
  df_object_col = df_object_col.apply(string_to_numpy_array)
  return torch.tensor(df_object_col.tolist(), dtype=torch.float64)

# %% [markdown]
# ## Neural Network Training

# %% [markdown]
# ### Import annotations dataset

# %%
df_annotations = pd.read_csv(get_deam_path('processed/annotations/deam_static_annotations.csv'))
df_annotations
# Out:
#       song_id  valence_mean_mapped  arousal_mean_mapped
# 0           2               -0.475               -0.500
# 1           3               -0.375               -0.425
# 2           4                0.175                0.125
# 3           5               -0.150                0.075
# 4           7                0.200                0.350
# ...       ...                  ...                  ...
# 1739     1996               -0.275                0.225
# 1740     1997                0.075               -0.275
# 1741     1998                0.350                0.300
# 1742     1999               -0.100                0.100
# 1743     2000                0.200                0.250
#
# [1744 rows x 3 columns]

# %% [markdown]
# ### Import the featureset

# %%
df_opensmile_emobase_features = pd.read_csv(get_deam_path('processed/features/opensmile_emobase_features.csv'))

# drop Unnamed:0 column
df_opensmile_emobase_features = df_opensmile_emobase_features[df_opensmile_emobase_features.columns[1:]]

df_opensmile_emobase_features
# Out:
#       song_id  pcm_intensity_sma_max  pcm_intensity_sma_min  \
# 0           2               0.000100           0.000000e+00
# 1           3               0.000051           0.000000e+00
# 2           4               0.000088           0.000000e+00
# 3           5               0.000060           0.000000e+00
# 4           7               0.000113           0.000000e+00
# ...       ...                    ...                    ...
# 1739     1996               0.000023           1.535268e-08
# 1740     1997               0.000012           1.499340e-08
# 1741     1998               0.000026           1.076092e-08
# 1742     1999               0.000030           5.323769e-09
# 1743     2000               0.000032           6.140887e-09
#
#       pcm_intensity_sma_range  pcm_intensity_sma_maxPos  \
# 0                    0.000100                    3821.0
# 1                    0.000051                    2809.0
# 2                    0.000088                    1800.0
# 3                    0.000060                     488.0
# 4                    0.000113                    1061.0
# ...                       ...                       ...
# 1739                 0.000023                    2355.0
# 1740                 0.000012                    3905.0
# 1741                 0.000026                    3411.0
# 1742                 0.000030                    4167.0
# 1743                 0.000032                    1713.0
#
#       pcm_intensity_sma_minPos  pcm_intensity_sma_amean  \
# 0                          0.0                 0.000003
# 1                          0.0                 0.000005
# 2                          0.0                 0.000011
# 3                          0.0                 0.000006
# 4                          0.0                 0.000020
# ...                        ...                      ...
# 1739                     548.0                 0.000005
# 1740                    4487.0                 0.000002
# 1741                    3137.0                 0.000003
# 1742                    1089.0                 0.000002
# 1743                     437.0                 0.000003
#
#       pcm_intensity_sma_linregc1  pcm_intensity_sma_linregc2  \
# 0                   9.746145e-11                    0.000003
# 1                   1.012040e-10                    0.000004
# 2                   5.901333e-11                    0.000011
# 3                  -3.841752e-10                    0.000007
# 4                  -4.199130e-11                    0.000020
# ...                          ...                         ...
# 1739               -8.072022e-11                    0.000005
# 1740               -4.315512e-11                    0.000002
# 1741               -1.908036e-10                    0.000004
# 1742                9.297152e-11                    0.000002
# 1743                8.342206e-10                    0.000002
#
#       pcm_intensity_sma_linregerrA  ...  F0env_sma_de_linregerrQ  \
# 0                         0.000002  ...                34.224740
# 1                         0.000004  ...                11.536975
# 2                         0.000008  ...                31.980932
# 3                         0.000005  ...                33.398550
# 4                         0.000011  ...                23.441298
# ...                            ...  ...                      ...
# 1739                      0.000003  ...                 8.894216
# 1740                      0.000001  ...                 2.125242
# 1741                      0.000003  ...                11.348680
# 1742                      0.000002  ...                 7.925314
# 1743                      0.000003  ...                16.543354
#
#       F0env_sma_de_stddev  F0env_sma_de_skewness  F0env_sma_de_kurtosis  \
# 0                5.851549               0.815608              11.220467
# 1                3.397905               1.259240              29.973100
# 2                5.655746               0.692436               9.787511
# 3                5.780117               0.625557               9.257450
# 4                4.842434               0.802300              13.485694
# ...                   ...                    ...                    ...
# 1739             2.983331               7.053555             145.043520
# 1740             1.458878               1.890596              27.465874
# 1741             3.371960               0.621677              18.409992
# 1742             2.818051               3.872501              60.610363
# 1743             4.068033               0.368404              11.077601
#
#       F0env_sma_de_quartile1  F0env_sma_de_quartile2  F0env_sma_de_quartile3  \
# 0                  -2.025291                     0.0                1.749724
# 1                   0.000000                     0.0                0.000000
# 2                  -1.309070                     0.0                1.036872
# 3                  -1.881530                     0.0                1.791142
# 4                  -1.159967                     0.0                1.114847
# ...                      ...                     ...                     ...
# 1739                0.000000                     0.0                0.000000
# 1740               -0.168976                     0.0                0.000000
# 1741                0.000000                     0.0                0.000000
# 1742                0.000000                     0.0                0.000000
# 1743                0.000000                     0.0                0.000000
#
#       F0env_sma_de_iqr1-2  F0env_sma_de_iqr2-3  F0env_sma_de_iqr1-3
# 0                2.025291             1.749724             3.775015
# 1                0.000000             0.000000             0.000000
# 2                1.309070             1.036872             2.345942
# 3                1.881530             1.791142             3.672672
# 4                1.159967             1.114847             2.274814
# ...                   ...                  ...                  ...
# 1739             0.000000             0.000000             0.000000
# 1740             0.168976             0.000000             0.168976
# 1741             0.000000             0.000000             0.000000
# 1742             0.000000             0.000000             0.000000
# 1743             0.000000             0.000000             0.000000
#
# [1744 rows x 989 columns]

# %%
df_opensmile_emobase_features.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1744 entries, 0 to 1743
# Data columns (total 989 columns):
#  #    Column                           Dtype
# ---   ------                           -----
#  0    song_id                          int64
#  1    pcm_intensity_sma_max            float64
#  2    pcm_intensity_sma_min            float64
#  3    pcm_intensity_sma_range          float64
#  4    pcm_intensity_sma_maxPos         float64
#  5    pcm_intensity_sma_minPos         float64
#  6    pcm_intensity_sma_amean          float64
#  7    pcm_intensity_sma_linregc1       float64
#  8    pcm_intensity_sma_linregc2       float64
#  9    pcm_intensity_sma_linregerrA     float64
#  10   pcm_intensity_sma_linregerrQ     float64
#  11   pcm_intensity_sma_stddev         float64
#  12   pcm_intensity_sma_skewness       float64
#  13   pcm_intensity_sma_kurtosis       float64
#  14   pcm_intensity_sma_quartile1      float64
#  15   pcm_intensity_sma_quartile2      float64
#  16   pcm_intensity_sma_quartile3      float64
#  17   pcm_intensity_sma_iqr1-2         float64
#  18   pcm_intensity_sma_iqr2-3         float64
#  19   pcm_intensity_sma_iqr1-3         float64
#  20   pcm_loudness_sma_max             float64
#  21   pcm_loudness_sma_min             float64
#  22   pcm_loudness_sma_range           float64
#  23   pcm_loudness_sma_maxPos          float64
#  24   pcm_loudness_sma_minPos          float64
#  25   pcm_loudness_sma_amean           float64
#  26   pcm_loudness_sma_linregc1        float64
#  27   pcm_loudness_sma_linregc2        float64
#  28   pcm_loudness_sma_linregerrA      float64
#  29   pcm_loudness_sma_linregerrQ      float64
#  30   pcm_loudness_sma_stddev          float64
#  31   pcm_loudness_sma_skewness        float64
#  32   pcm_loudness_sma_kurtosis        float64
#  33   pcm_loudness_sma_quartile1       float64
#  34   pcm_loudness_sma_quartile2       float64
#  35   pcm_loudness_sma_quartile3       float64
#  36   pcm_loudness_sma_iqr1-2          float64
#  37   pcm_loudness_sma_iqr2-3          float64
#  38   pcm_loudness_sma_iqr1-3          float64
#  39   mfcc_sma[1]_max                  float64
#  40   mfcc_sma[1]_min                  float64
#  41   mfcc_sma[1]_range                float64
#  42   mfcc_sma[1]_maxPos               float64
#  43   mfcc_sma[1]_minPos               float64
#  44   mfcc_sma[1]_amean                float64
#  45   mfcc_sma[1]_linregc1             float64
#  46   mfcc_sma[1]_linregc2             float64
#  47   mfcc_sma[1]_linregerrA           float64
#  48   mfcc_sma[1]_linregerrQ           float64
#  49   mfcc_sma[1]_stddev               float64
#  50   mfcc_sma[1]_skewness             float64
#  51   mfcc_sma[1]_kurtosis             float64
#  52   mfcc_sma[1]_quartile1            float64
#  53   mfcc_sma[1]_quartile2            float64
#  54   mfcc_sma[1]_quartile3            float64
#  55   mfcc_sma[1]_iqr1-2               float64
#  56   mfcc_sma[1]_iqr2-3               float64
#  57   mfcc_sma[1]_iqr1-3               float64
#  58   mfcc_sma[2]_max                  float64
#  59   mfcc_sma[2]_min                  float64
#  60   mfcc_sma[2]_range                float64
#  61   mfcc_sma[2]_maxPos               float64
#  62   mfcc_sma[2]_minPos               float64
#  63   mfcc_sma[2]_amean                float64
#  64   mfcc_sma[2]_linregc1             float64
#  65   mfcc_sma[2]_linregc2             float64
#  66   mfcc_sma[2]_linregerrA           float64
#  67   mfcc_sma[2]_linregerrQ           float64
#  68   mfcc_sma[2]_stddev               float64
#  69   mfcc_sma[2]_skewness             float64
#  70   mfcc_sma[2]_kurtosis             float64
#  71   mfcc_sma[2]_quartile1            float64
#  72   mfcc_sma[2]_quartile2            float64
#  73   mfcc_sma[2]_quartile3            float64
#  74   mfcc_sma[2]_iqr1-2               float64
#  75   mfcc_sma[2]_iqr2-3               float64
#  76   mfcc_sma[2]_iqr1-3               float64
#  77   mfcc_sma[3]_max                  float64
#  78   mfcc_sma[3]_min                  float64
#  79   mfcc_sma[3]_range                float64
#  80   mfcc_sma[3]_maxPos               float64
#  81   mfcc_sma[3]_minPos               float64
#  82   mfcc_sma[3]_amean                float64
#  83   mfcc_sma[3]_linregc1             float64
#  84   mfcc_sma[3]_linregc2             float64
#  85   mfcc_sma[3]_linregerrA           float64
#  86   mfcc_sma[3]_linregerrQ           float64
#  87   mfcc_sma[3]_stddev               float64
#  88   mfcc_sma[3]_skewness             float64
#  89   mfcc_sma[3]_kurtosis             float64
#  90   mfcc_sma[3]_quartile1            float64
#  91   mfcc_sma[3]_quartile2            float64
#  92   mfcc_sma[3]_quartile3            float64
#  93   mfcc_sma[3]_iqr1-2               float64
#  94   mfcc_sma[3]_iqr2-3               float64
#  95   mfcc_sma[3]_iqr1-3               float64
#  96   mfcc_sma[4]_max                  float64
#  97   mfcc_sma[4]_min                  float64
#  98   mfcc_sma[4]_range                float64
#  99   mfcc_sma[4]_maxPos               float64
#  100  mfcc_sma[4]_minPos               float64
#  101  mfcc_sma[4]_amean                float64
#  102  mfcc_sma[4]_linregc1             float64
#  103  mfcc_sma[4]_linregc2             float64
#  104  mfcc_sma[4]_linregerrA           float64
#  105  mfcc_sma[4]_linregerrQ           float64
#  106  mfcc_sma[4]_stddev               float64
#  107  mfcc_sma[4]_skewness             float64
#  108  mfcc_sma[4]_kurtosis             float64
#  109  mfcc_sma[4]_quartile1            float64
#  110  mfcc_sma[4]_quartile2            float64
#  111  mfcc_sma[4]_quartile3            float64
#  112  mfcc_sma[4]_iqr1-2               float64
#  113  mfcc_sma[4]_iqr2-3               float64
#  114  mfcc_sma[4]_iqr1-3               float64
#  115  mfcc_sma[5]_max                  float64
#  116  mfcc_sma[5]_min                  float64
#  117  mfcc_sma[5]_range                float64
#  118  mfcc_sma[5]_maxPos               float64
#  119  mfcc_sma[5]_minPos               float64
#  120  mfcc_sma[5]_amean                float64
#  121  mfcc_sma[5]_linregc1             float64
#  122  mfcc_sma[5]_linregc2             float64
#  123  mfcc_sma[5]_linregerrA           float64
#  124  mfcc_sma[5]_linregerrQ           float64
#  125  mfcc_sma[5]_stddev               float64
#  126  mfcc_sma[5]_skewness             float64
#  127  mfcc_sma[5]_kurtosis             float64
#  128  mfcc_sma[5]_quartile1            float64
#  129  mfcc_sma[5]_quartile2            float64
#  130  mfcc_sma[5]_quartile3            float64
#  131  mfcc_sma[5]_iqr1-2               float64
#  132  mfcc_sma[5]_iqr2-3               float64
#  133  mfcc_sma[5]_iqr1-3               float64
#  134  mfcc_sma[6]_max                  float64
#  135  mfcc_sma[6]_min                  float64
#  136  mfcc_sma[6]_range                float64
#  137  mfcc_sma[6]_maxPos               float64
#  138  mfcc_sma[6]_minPos               float64
#  139  mfcc_sma[6]_amean                float64
#  140  mfcc_sma[6]_linregc1             float64
#  141  mfcc_sma[6]_linregc2             float64
#  142  mfcc_sma[6]_linregerrA           float64
#  143  mfcc_sma[6]_linregerrQ           float64
#  144  mfcc_sma[6]_stddev               float64
#  145  mfcc_sma[6]_skewness             float64
#  146  mfcc_sma[6]_kurtosis             float64
#  147  mfcc_sma[6]_quartile1            float64
#  148  mfcc_sma[6]_quartile2            float64
#  149  mfcc_sma[6]_quartile3            float64
#  150  mfcc_sma[6]_iqr1-2               float64
#  151  mfcc_sma[6]_iqr2-3               float64
#  152  mfcc_sma[6]_iqr1-3               float64
#  153  mfcc_sma[7]_max                  float64
#  154  mfcc_sma[7]_min                  float64
#  155  mfcc_sma[7]_range                float64
#  156  mfcc_sma[7]_maxPos               float64
#  157  mfcc_sma[7]_minPos               float64
#  158  mfcc_sma[7]_amean                float64
#  159  mfcc_sma[7]_linregc1             float64
#  160  mfcc_sma[7]_linregc2             float64
#  161  mfcc_sma[7]_linregerrA           float64
#  162  mfcc_sma[7]_linregerrQ           float64
#  163  mfcc_sma[7]_stddev               float64
#  164  mfcc_sma[7]_skewness             float64
#  165  mfcc_sma[7]_kurtosis             float64
#  166  mfcc_sma[7]_quartile1            float64
#  167  mfcc_sma[7]_quartile2            float64
#  168  mfcc_sma[7]_quartile3            float64
#  169  mfcc_sma[7]_iqr1-2               float64
#  170  mfcc_sma[7]_iqr2-3               float64
#  171  mfcc_sma[7]_iqr1-3               float64
#  172  mfcc_sma[8]_max                  float64
#  173  mfcc_sma[8]_min                  float64
#  174  mfcc_sma[8]_range                float64
#  175  mfcc_sma[8]_maxPos               float64
#  176  mfcc_sma[8]_minPos               float64
#  177  mfcc_sma[8]_amean                float64
#  178  mfcc_sma[8]_linregc1             float64
#  179  mfcc_sma[8]_linregc2             float64
#  180  mfcc_sma[8]_linregerrA           float64
#  181  mfcc_sma[8]_linregerrQ           float64
#  182  mfcc_sma[8]_stddev               float64
#  183  mfcc_sma[8]_skewness             float64
#  184  mfcc_sma[8]_kurtosis             float64
#  185  mfcc_sma[8]_quartile1            float64
#  186  mfcc_sma[8]_quartile2            float64
#  187  mfcc_sma[8]_quartile3            float64
#  188  mfcc_sma[8]_iqr1-2               float64
#  189  mfcc_sma[8]_iqr2-3               float64
#  190  mfcc_sma[8]_iqr1-3               float64
#  191  mfcc_sma[9]_max                  float64
#  192  mfcc_sma[9]_min                  float64
#  193  mfcc_sma[9]_range                float64
#  194  mfcc_sma[9]_maxPos               float64
#  195  mfcc_sma[9]_minPos               float64
#  196  mfcc_sma[9]_amean                float64
#  197  mfcc_sma[9]_linregc1             float64
#  198  mfcc_sma[9]_linregc2             float64
#  199  mfcc_sma[9]_linregerrA           float64
#  200  mfcc_sma[9]_linregerrQ           float64
#  201  mfcc_sma[9]_stddev               float64
#  202  mfcc_sma[9]_skewness             float64
#  203  mfcc_sma[9]_kurtosis             float64
#  204  mfcc_sma[9]_quartile1            float64
#  205  mfcc_sma[9]_quartile2            float64
#  206  mfcc_sma[9]_quartile3            float64
#  207  mfcc_sma[9]_iqr1-2               float64
#  208  mfcc_sma[9]_iqr2-3               float64
#  209  mfcc_sma[9]_iqr1-3               float64
#  210  mfcc_sma[10]_max                 float64
#  211  mfcc_sma[10]_min                 float64
#  212  mfcc_sma[10]_range               float64
#  213  mfcc_sma[10]_maxPos              float64
#  214  mfcc_sma[10]_minPos              float64
#  215  mfcc_sma[10]_amean               float64
#  216  mfcc_sma[10]_linregc1            float64
#  217  mfcc_sma[10]_linregc2            float64
#  218  mfcc_sma[10]_linregerrA          float64
#  219  mfcc_sma[10]_linregerrQ          float64
#  220  mfcc_sma[10]_stddev              float64
#  221  mfcc_sma[10]_skewness            float64
#  222  mfcc_sma[10]_kurtosis            float64
#  223  mfcc_sma[10]_quartile1           float64
#  224  mfcc_sma[10]_quartile2           float64
#  225  mfcc_sma[10]_quartile3           float64
#  226  mfcc_sma[10]_iqr1-2              float64
#  227  mfcc_sma[10]_iqr2-3              float64
#  228  mfcc_sma[10]_iqr1-3              float64
#  229  mfcc_sma[11]_max                 float64
#  230  mfcc_sma[11]_min                 float64
#  231  mfcc_sma[11]_range               float64
#  232  mfcc_sma[11]_maxPos              float64
#  233  mfcc_sma[11]_minPos              float64
#  234  mfcc_sma[11]_amean               float64
#  235  mfcc_sma[11]_linregc1            float64
#  236  mfcc_sma[11]_linregc2            float64
#  237  mfcc_sma[11]_linregerrA          float64
#  238  mfcc_sma[11]_linregerrQ          float64
#  239  mfcc_sma[11]_stddev              float64
#  240  mfcc_sma[11]_skewness            float64
#  241  mfcc_sma[11]_kurtosis            float64
#  242  mfcc_sma[11]_quartile1           float64
#  243  mfcc_sma[11]_quartile2           float64
#  244  mfcc_sma[11]_quartile3           float64
#  245  mfcc_sma[11]_iqr1-2              float64
#  246  mfcc_sma[11]_iqr2-3              float64
#  247  mfcc_sma[11]_iqr1-3              float64
#  248  mfcc_sma[12]_max                 float64
#  249  mfcc_sma[12]_min                 float64
#  250  mfcc_sma[12]_range               float64
#  251  mfcc_sma[12]_maxPos              float64
#  252  mfcc_sma[12]_minPos              float64
#  253  mfcc_sma[12]_amean               float64
#  254  mfcc_sma[12]_linregc1            float64
#  255  mfcc_sma[12]_linregc2            float64
#  256  mfcc_sma[12]_linregerrA          float64
#  257  mfcc_sma[12]_linregerrQ          float64
#  258  mfcc_sma[12]_stddev              float64
#  259  mfcc_sma[12]_skewness            float64
#  260  mfcc_sma[12]_kurtosis            float64
#  261  mfcc_sma[12]_quartile1           float64
#  262  mfcc_sma[12]_quartile2           float64
#  263  mfcc_sma[12]_quartile3           float64
#  264  mfcc_sma[12]_iqr1-2              float64
#  265  mfcc_sma[12]_iqr2-3              float64
#  266  mfcc_sma[12]_iqr1-3              float64
#  267  lspFreq_sma[0]_max               float64
#  268  lspFreq_sma[0]_min               float64
#  269  lspFreq_sma[0]_range             float64
#  270  lspFreq_sma[0]_maxPos            float64
#  271  lspFreq_sma[0]_minPos            float64
#  272  lspFreq_sma[0]_amean             float64
#  273  lspFreq_sma[0]_linregc1          float64
#  274  lspFreq_sma[0]_linregc2          float64
#  275  lspFreq_sma[0]_linregerrA        float64
#  276  lspFreq_sma[0]_linregerrQ        float64
#  277  lspFreq_sma[0]_stddev            float64
#  278  lspFreq_sma[0]_skewness          float64
#  279  lspFreq_sma[0]_kurtosis          float64
#  280  lspFreq_sma[0]_quartile1         float64
#  281  lspFreq_sma[0]_quartile2         float64
#  282  lspFreq_sma[0]_quartile3         float64
#  283  lspFreq_sma[0]_iqr1-2            float64
#  284  lspFreq_sma[0]_iqr2-3            float64
#  285  lspFreq_sma[0]_iqr1-3            float64
#  286  lspFreq_sma[1]_max               float64
#  287  lspFreq_sma[1]_min               float64
#  288  lspFreq_sma[1]_range             float64
#  289  lspFreq_sma[1]_maxPos            float64
#  290  lspFreq_sma[1]_minPos            float64
#  291  lspFreq_sma[1]_amean             float64
#  292  lspFreq_sma[1]_linregc1          float64
#  293  lspFreq_sma[1]_linregc2          float64
#  294  lspFreq_sma[1]_linregerrA        float64
#  295  lspFreq_sma[1]_linregerrQ        float64
#  296  lspFreq_sma[1]_stddev            float64
#  297  lspFreq_sma[1]_skewness          float64
#  298  lspFreq_sma[1]_kurtosis          float64
#  299  lspFreq_sma[1]_quartile1         float64
#  300  lspFreq_sma[1]_quartile2         float64
#  301  lspFreq_sma[1]_quartile3         float64
#  302  lspFreq_sma[1]_iqr1-2            float64
#  303  lspFreq_sma[1]_iqr2-3            float64
#  304  lspFreq_sma[1]_iqr1-3            float64
#  305  lspFreq_sma[2]_max               float64
#  306  lspFreq_sma[2]_min               float64
#  307  lspFreq_sma[2]_range             float64
#  308  lspFreq_sma[2]_maxPos            float64
#  309  lspFreq_sma[2]_minPos            float64
#  310  lspFreq_sma[2]_amean             float64
#  311  lspFreq_sma[2]_linregc1          float64
#  312  lspFreq_sma[2]_linregc2          float64
#  313  lspFreq_sma[2]_linregerrA        float64
#  314  lspFreq_sma[2]_linregerrQ        float64
#  315  lspFreq_sma[2]_stddev            float64
#  316  lspFreq_sma[2]_skewness          float64
#  317  lspFreq_sma[2]_kurtosis          float64
#  318  lspFreq_sma[2]_quartile1         float64
#  319  lspFreq_sma[2]_quartile2         float64
#  320  lspFreq_sma[2]_quartile3         float64
#  321  lspFreq_sma[2]_iqr1-2            float64
#  322  lspFreq_sma[2]_iqr2-3            float64
#  323  lspFreq_sma[2]_iqr1-3            float64
#  324  lspFreq_sma[3]_max               float64
#  325  lspFreq_sma[3]_min               float64
#  326  lspFreq_sma[3]_range             float64
#  327  lspFreq_sma[3]_maxPos            float64
#  328  lspFreq_sma[3]_minPos            float64
#  329  lspFreq_sma[3]_amean             float64
#  330  lspFreq_sma[3]_linregc1          float64
#  331  lspFreq_sma[3]_linregc2          float64
#  332  lspFreq_sma[3]_linregerrA        float64
#  333  lspFreq_sma[3]_linregerrQ        float64
#  334  lspFreq_sma[3]_stddev            float64
#  335  lspFreq_sma[3]_skewness          float64
#  336  lspFreq_sma[3]_kurtosis          float64
#  337  lspFreq_sma[3]_quartile1         float64
#  338  lspFreq_sma[3]_quartile2         float64
#  339  lspFreq_sma[3]_quartile3         float64
#  340  lspFreq_sma[3]_iqr1-2            float64
#  341  lspFreq_sma[3]_iqr2-3            float64
#  342  lspFreq_sma[3]_iqr1-3            float64
#  343  lspFreq_sma[4]_max               float64
#  344  lspFreq_sma[4]_min               float64
#  345  lspFreq_sma[4]_range             float64
#  346  lspFreq_sma[4]_maxPos            float64
#  347  lspFreq_sma[4]_minPos            float64
#  348  lspFreq_sma[4]_amean             float64
#  349  lspFreq_sma[4]_linregc1          float64
#  350  lspFreq_sma[4]_linregc2          float64
#  351  lspFreq_sma[4]_linregerrA        float64
#  352  lspFreq_sma[4]_linregerrQ        float64
#  353  lspFreq_sma[4]_stddev            float64
#  354  lspFreq_sma[4]_skewness          float64
#  355  lspFreq_sma[4]_kurtosis          float64
#  356  lspFreq_sma[4]_quartile1         float64
#  357  lspFreq_sma[4]_quartile2         float64
#  358  lspFreq_sma[4]_quartile3         float64
#  359  lspFreq_sma[4]_iqr1-2            float64
#  360  lspFreq_sma[4]_iqr2-3            float64
#  361  lspFreq_sma[4]_iqr1-3            float64
#  362  lspFreq_sma[5]_max               float64
#  363  lspFreq_sma[5]_min               float64
#  364  lspFreq_sma[5]_range             float64
#  365  lspFreq_sma[5]_maxPos            float64
#  366  lspFreq_sma[5]_minPos            float64
#  367  lspFreq_sma[5]_amean             float64
#  368  lspFreq_sma[5]_linregc1          float64
#  369  lspFreq_sma[5]_linregc2          float64
#  370  lspFreq_sma[5]_linregerrA        float64
#  371  lspFreq_sma[5]_linregerrQ        float64
#  372  lspFreq_sma[5]_stddev            float64
#  373  lspFreq_sma[5]_skewness          float64
#  374  lspFreq_sma[5]_kurtosis          float64
#  375  lspFreq_sma[5]_quartile1         float64
#  376  lspFreq_sma[5]_quartile2         float64
#  377  lspFreq_sma[5]_quartile3         float64
#  378  lspFreq_sma[5]_iqr1-2            float64
#  379  lspFreq_sma[5]_iqr2-3            float64
#  380  lspFreq_sma[5]_iqr1-3            float64
#  381  lspFreq_sma[6]_max               float64
#  382  lspFreq_sma[6]_min               float64
#  383  lspFreq_sma[6]_range             float64
#  384  lspFreq_sma[6]_maxPos            float64
#  385  lspFreq_sma[6]_minPos            float64
#  386  lspFreq_sma[6]_amean             float64
#  387  lspFreq_sma[6]_linregc1          float64
#  388  lspFreq_sma[6]_linregc2          float64
#  389  lspFreq_sma[6]_linregerrA        float64
#  390  lspFreq_sma[6]_linregerrQ        float64
#  391  lspFreq_sma[6]_stddev            float64
#  392  lspFreq_sma[6]_skewness          float64
#  393  lspFreq_sma[6]_kurtosis          float64
#  394  lspFreq_sma[6]_quartile1         float64
#  395  lspFreq_sma[6]_quartile2         float64
#  396  lspFreq_sma[6]_quartile3         float64
#  397  lspFreq_sma[6]_iqr1-2            float64
#  398  lspFreq_sma[6]_iqr2-3            float64
#  399  lspFreq_sma[6]_iqr1-3            float64
#  400  lspFreq_sma[7]_max               float64
#  401  lspFreq_sma[7]_min               float64
#  402  lspFreq_sma[7]_range             float64
#  403  lspFreq_sma[7]_maxPos            float64
#  404  lspFreq_sma[7]_minPos            float64
#  405  lspFreq_sma[7]_amean             float64
#  406  lspFreq_sma[7]_linregc1          float64
#  407  lspFreq_sma[7]_linregc2          float64
#  408  lspFreq_sma[7]_linregerrA        float64
#  409  lspFreq_sma[7]_linregerrQ        float64
#  410  lspFreq_sma[7]_stddev            float64
#  411  lspFreq_sma[7]_skewness          float64
#  412  lspFreq_sma[7]_kurtosis          float64
#  413  lspFreq_sma[7]_quartile1         float64
#  414  lspFreq_sma[7]_quartile2         float64
#  415  lspFreq_sma[7]_quartile3         float64
#  416  lspFreq_sma[7]_iqr1-2            float64
#  417  lspFreq_sma[7]_iqr2-3            float64
#  418  lspFreq_sma[7]_iqr1-3            float64
#  419  pcm_zcr_sma_max                  float64
#  420  pcm_zcr_sma_min                  float64
#  421  pcm_zcr_sma_range                float64
#  422  pcm_zcr_sma_maxPos               float64
#  423  pcm_zcr_sma_minPos               float64
#  424  pcm_zcr_sma_amean                float64
#  425  pcm_zcr_sma_linregc1             float64
#  426  pcm_zcr_sma_linregc2             float64
#  427  pcm_zcr_sma_linregerrA           float64
#  428  pcm_zcr_sma_linregerrQ           float64
#  429  pcm_zcr_sma_stddev               float64
#  430  pcm_zcr_sma_skewness             float64
#  431  pcm_zcr_sma_kurtosis             float64
#  432  pcm_zcr_sma_quartile1            float64
#  433  pcm_zcr_sma_quartile2            float64
#  434  pcm_zcr_sma_quartile3            float64
#  435  pcm_zcr_sma_iqr1-2               float64
#  436  pcm_zcr_sma_iqr2-3               float64
#  437  pcm_zcr_sma_iqr1-3               float64
#  438  voiceProb_sma_max                float64
#  439  voiceProb_sma_min                float64
#  440  voiceProb_sma_range              float64
#  441  voiceProb_sma_maxPos             float64
#  442  voiceProb_sma_minPos             float64
#  443  voiceProb_sma_amean              float64
#  444  voiceProb_sma_linregc1           float64
#  445  voiceProb_sma_linregc2           float64
#  446  voiceProb_sma_linregerrA         float64
#  447  voiceProb_sma_linregerrQ         float64
#  448  voiceProb_sma_stddev             float64
#  449  voiceProb_sma_skewness           float64
#  450  voiceProb_sma_kurtosis           float64
#  451  voiceProb_sma_quartile1          float64
#  452  voiceProb_sma_quartile2          float64
#  453  voiceProb_sma_quartile3          float64
#  454  voiceProb_sma_iqr1-2             float64
#  455  voiceProb_sma_iqr2-3             float64
#  456  voiceProb_sma_iqr1-3             float64
#  457  F0_sma_max                       float64
#  458  F0_sma_min                       float64
#  459  F0_sma_range                     float64
#  460  F0_sma_maxPos                    float64
#  461  F0_sma_minPos                    float64
#  462  F0_sma_amean                     float64
#  463  F0_sma_linregc1                  float64
#  464  F0_sma_linregc2                  float64
#  465  F0_sma_linregerrA                float64
#  466  F0_sma_linregerrQ                float64
#  467  F0_sma_stddev                    float64
#  468  F0_sma_skewness                  float64
#  469  F0_sma_kurtosis                  float64
#  470  F0_sma_quartile1                 float64
#  471  F0_sma_quartile2                 float64
#  472  F0_sma_quartile3                 float64
#  473  F0_sma_iqr1-2                    float64
#  474  F0_sma_iqr2-3                    float64
#  475  F0_sma_iqr1-3                    float64
#  476  F0env_sma_max                    float64
#  477  F0env_sma_min                    float64
#  478  F0env_sma_range                  float64
#  479  F0env_sma_maxPos                 float64
#  480  F0env_sma_minPos                 float64
#  481  F0env_sma_amean                  float64
#  482  F0env_sma_linregc1               float64
#  483  F0env_sma_linregc2               float64
#  484  F0env_sma_linregerrA             float64
#  485  F0env_sma_linregerrQ             float64
#  486  F0env_sma_stddev                 float64
#  487  F0env_sma_skewness               float64
#  488  F0env_sma_kurtosis               float64
#  489  F0env_sma_quartile1              float64
#  490  F0env_sma_quartile2              float64
#  491  F0env_sma_quartile3              float64
#  492  F0env_sma_iqr1-2                 float64
#  493  F0env_sma_iqr2-3                 float64
#  494  F0env_sma_iqr1-3                 float64
#  495  pcm_intensity_sma_de_max         float64
#  496  pcm_intensity_sma_de_min         float64
#  497  pcm_intensity_sma_de_range       float64
#  498  pcm_intensity_sma_de_maxPos      float64
#  499  pcm_intensity_sma_de_minPos      float64
#  500  pcm_intensity_sma_de_amean       float64
#  501  pcm_intensity_sma_de_linregc1    float64
#  502  pcm_intensity_sma_de_linregc2    float64
#  503  pcm_intensity_sma_de_linregerrA  float64
#  504  pcm_intensity_sma_de_linregerrQ  float64
#  505  pcm_intensity_sma_de_stddev      float64
#  506  pcm_intensity_sma_de_skewness    float64
#  507  pcm_intensity_sma_de_kurtosis    float64
#  508  pcm_intensity_sma_de_quartile1   float64
#  509  pcm_intensity_sma_de_quartile2   float64
#  510  pcm_intensity_sma_de_quartile3   float64
#  511  pcm_intensity_sma_de_iqr1-2      float64
#  512  pcm_intensity_sma_de_iqr2-3      float64
#  513  pcm_intensity_sma_de_iqr1-3      float64
#  514  pcm_loudness_sma_de_max          float64
#  515  pcm_loudness_sma_de_min          float64
#  516  pcm_loudness_sma_de_range        float64
#  517  pcm_loudness_sma_de_maxPos       float64
#  518  pcm_loudness_sma_de_minPos       float64
#  519  pcm_loudness_sma_de_amean        float64
#  520  pcm_loudness_sma_de_linregc1     float64
#  521  pcm_loudness_sma_de_linregc2     float64
#  522  pcm_loudness_sma_de_linregerrA   float64
#  523  pcm_loudness_sma_de_linregerrQ   float64
#  524  pcm_loudness_sma_de_stddev       float64
#  525  pcm_loudness_sma_de_skewness     float64
#  526  pcm_loudness_sma_de_kurtosis     float64
#  527  pcm_loudness_sma_de_quartile1    float64
#  528  pcm_loudness_sma_de_quartile2    float64
#  529  pcm_loudness_sma_de_quartile3    float64
#  530  pcm_loudness_sma_de_iqr1-2       float64
#  531  pcm_loudness_sma_de_iqr2-3       float64
#  532  pcm_loudness_sma_de_iqr1-3       float64
#  533  mfcc_sma_de[1]_max               float64
#  534  mfcc_sma_de[1]_min               float64
#  535  mfcc_sma_de[1]_range             float64
#  536  mfcc_sma_de[1]_maxPos            float64
#  537  mfcc_sma_de[1]_minPos            float64
#  538  mfcc_sma_de[1]_amean             float64
#  539  mfcc_sma_de[1]_linregc1          float64
#  540  mfcc_sma_de[1]_linregc2          float64
#  541  mfcc_sma_de[1]_linregerrA        float64
#  542  mfcc_sma_de[1]_linregerrQ        float64
#  543  mfcc_sma_de[1]_stddev            float64
#  544  mfcc_sma_de[1]_skewness          float64
#  545  mfcc_sma_de[1]_kurtosis          float64
#  546  mfcc_sma_de[1]_quartile1         float64
#  547  mfcc_sma_de[1]_quartile2         float64
#  548  mfcc_sma_de[1]_quartile3         float64
#  549  mfcc_sma_de[1]_iqr1-2            float64
#  550  mfcc_sma_de[1]_iqr2-3            float64
#  551  mfcc_sma_de[1]_iqr1-3            float64
#  552  mfcc_sma_de[2]_max               float64
#  553  mfcc_sma_de[2]_min               float64
#  554  mfcc_sma_de[2]_range             float64
#  555  mfcc_sma_de[2]_maxPos            float64
#  556  mfcc_sma_de[2]_minPos            float64
#  557  mfcc_sma_de[2]_amean             float64
#  558  mfcc_sma_de[2]_linregc1          float64
#  559  mfcc_sma_de[2]_linregc2          float64
#  560  mfcc_sma_de[2]_linregerrA        float64
#  561  mfcc_sma_de[2]_linregerrQ        float64
#  562  mfcc_sma_de[2]_stddev            float64
#  563  mfcc_sma_de[2]_skewness          float64
#  564  mfcc_sma_de[2]_kurtosis          float64
#  565  mfcc_sma_de[2]_quartile1         float64
#  566  mfcc_sma_de[2]_quartile2         float64
#  567  mfcc_sma_de[2]_quartile3         float64
#  568  mfcc_sma_de[2]_iqr1-2            float64
#  569  mfcc_sma_de[2]_iqr2-3            float64
#  570  mfcc_sma_de[2]_iqr1-3            float64
#  571  mfcc_sma_de[3]_max               float64
#  572  mfcc_sma_de[3]_min               float64
#  573  mfcc_sma_de[3]_range             float64
#  574  mfcc_sma_de[3]_maxPos            float64
#  575  mfcc_sma_de[3]_minPos            float64
#  576  mfcc_sma_de[3]_amean             float64
#  577  mfcc_sma_de[3]_linregc1          float64
#  578  mfcc_sma_de[3]_linregc2          float64
#  579  mfcc_sma_de[3]_linregerrA        float64
#  580  mfcc_sma_de[3]_linregerrQ        float64
#  581  mfcc_sma_de[3]_stddev            float64
#  582  mfcc_sma_de[3]_skewness          float64
#  583  mfcc_sma_de[3]_kurtosis          float64
#  584  mfcc_sma_de[3]_quartile1         float64
#  585  mfcc_sma_de[3]_quartile2         float64
#  586  mfcc_sma_de[3]_quartile3         float64
#  587  mfcc_sma_de[3]_iqr1-2            float64
#  588  mfcc_sma_de[3]_iqr2-3            float64
#  589  mfcc_sma_de[3]_iqr1-3            float64
#  590  mfcc_sma_de[4]_max               float64
#  591  mfcc_sma_de[4]_min               float64
#  592  mfcc_sma_de[4]_range             float64
#  593  mfcc_sma_de[4]_maxPos            float64
#  594  mfcc_sma_de[4]_minPos            float64
#  595  mfcc_sma_de[4]_amean             float64
#  596  mfcc_sma_de[4]_linregc1          float64
#  597  mfcc_sma_de[4]_linregc2          float64
#  598  mfcc_sma_de[4]_linregerrA        float64
#  599  mfcc_sma_de[4]_linregerrQ        float64
#  600  mfcc_sma_de[4]_stddev            float64
#  601  mfcc_sma_de[4]_skewness          float64
#  602  mfcc_sma_de[4]_kurtosis          float64
#  603  mfcc_sma_de[4]_quartile1         float64
#  604  mfcc_sma_de[4]_quartile2         float64
#  605  mfcc_sma_de[4]_quartile3         float64
#  606  mfcc_sma_de[4]_iqr1-2            float64
#  607  mfcc_sma_de[4]_iqr2-3            float64
#  608  mfcc_sma_de[4]_iqr1-3            float64
#  609  mfcc_sma_de[5]_max               float64
#  610  mfcc_sma_de[5]_min               float64
#  611  mfcc_sma_de[5]_range             float64
#  612  mfcc_sma_de[5]_maxPos            float64
#  613  mfcc_sma_de[5]_minPos            float64
#  614  mfcc_sma_de[5]_amean             float64
#  615  mfcc_sma_de[5]_linregc1          float64
#  616  mfcc_sma_de[5]_linregc2          float64
#  617  mfcc_sma_de[5]_linregerrA        float64
#  618  mfcc_sma_de[5]_linregerrQ        float64
#  619  mfcc_sma_de[5]_stddev            float64
#  620  mfcc_sma_de[5]_skewness          float64
#  621  mfcc_sma_de[5]_kurtosis          float64
#  622  mfcc_sma_de[5]_quartile1         float64
#  623  mfcc_sma_de[5]_quartile2         float64
#  624  mfcc_sma_de[5]_quartile3         float64
#  625  mfcc_sma_de[5]_iqr1-2            float64
#  626  mfcc_sma_de[5]_iqr2-3            float64
#  627  mfcc_sma_de[5]_iqr1-3            float64
#  628  mfcc_sma_de[6]_max               float64
#  629  mfcc_sma_de[6]_min               float64
#  630  mfcc_sma_de[6]_range             float64
#  631  mfcc_sma_de[6]_maxPos            float64
#  632  mfcc_sma_de[6]_minPos            float64
#  633  mfcc_sma_de[6]_amean             float64
#  634  mfcc_sma_de[6]_linregc1          float64
#  635  mfcc_sma_de[6]_linregc2          float64
#  636  mfcc_sma_de[6]_linregerrA        float64
#  637  mfcc_sma_de[6]_linregerrQ        float64
#  638  mfcc_sma_de[6]_stddev            float64
#  639  mfcc_sma_de[6]_skewness          float64
#  640  mfcc_sma_de[6]_kurtosis          float64
#  641  mfcc_sma_de[6]_quartile1         float64
#  642  mfcc_sma_de[6]_quartile2         float64
#  643  mfcc_sma_de[6]_quartile3         float64
#  644  mfcc_sma_de[6]_iqr1-2            float64
#  645  mfcc_sma_de[6]_iqr2-3            float64
#  646  mfcc_sma_de[6]_iqr1-3            float64
#  647  mfcc_sma_de[7]_max               float64
#  648  mfcc_sma_de[7]_min               float64
#  649  mfcc_sma_de[7]_range             float64
#  650  mfcc_sma_de[7]_maxPos            float64
#  651  mfcc_sma_de[7]_minPos            float64
#  652  mfcc_sma_de[7]_amean             float64
#  653  mfcc_sma_de[7]_linregc1          float64
#  654  mfcc_sma_de[7]_linregc2          float64
#  655  mfcc_sma_de[7]_linregerrA        float64
#  656  mfcc_sma_de[7]_linregerrQ        float64
#  657  mfcc_sma_de[7]_stddev            float64
#  658  mfcc_sma_de[7]_skewness          float64
#  659  mfcc_sma_de[7]_kurtosis          float64
#  660  mfcc_sma_de[7]_quartile1         float64
#  661  mfcc_sma_de[7]_quartile2         float64
#  662  mfcc_sma_de[7]_quartile3         float64
#  663  mfcc_sma_de[7]_iqr1-2            float64
#  664  mfcc_sma_de[7]_iqr2-3            float64
#  665  mfcc_sma_de[7]_iqr1-3            float64
#  666  mfcc_sma_de[8]_max               float64
#  667  mfcc_sma_de[8]_min               float64
#  668  mfcc_sma_de[8]_range             float64
#  669  mfcc_sma_de[8]_maxPos            float64
#  670  mfcc_sma_de[8]_minPos            float64
#  671  mfcc_sma_de[8]_amean             float64
#  672  mfcc_sma_de[8]_linregc1          float64
#  673  mfcc_sma_de[8]_linregc2          float64
#  674  mfcc_sma_de[8]_linregerrA        float64
#  675  mfcc_sma_de[8]_linregerrQ        float64
#  676  mfcc_sma_de[8]_stddev            float64
#  677  mfcc_sma_de[8]_skewness          float64
#  678  mfcc_sma_de[8]_kurtosis          float64
#  679  mfcc_sma_de[8]_quartile1         float64
#  680  mfcc_sma_de[8]_quartile2         float64
#  681  mfcc_sma_de[8]_quartile3         float64
#  682  mfcc_sma_de[8]_iqr1-2            float64
#  683  mfcc_sma_de[8]_iqr2-3            float64
#  684  mfcc_sma_de[8]_iqr1-3            float64
#  685  mfcc_sma_de[9]_max               float64
#  686  mfcc_sma_de[9]_min               float64
#  687  mfcc_sma_de[9]_range             float64
#  688  mfcc_sma_de[9]_maxPos            float64
#  689  mfcc_sma_de[9]_minPos            float64
#  690  mfcc_sma_de[9]_amean             float64
#  691  mfcc_sma_de[9]_linregc1          float64
#  692  mfcc_sma_de[9]_linregc2          float64
#  693  mfcc_sma_de[9]_linregerrA        float64
#  694  mfcc_sma_de[9]_linregerrQ        float64
#  695  mfcc_sma_de[9]_stddev            float64
#  696  mfcc_sma_de[9]_skewness          float64
#  697  mfcc_sma_de[9]_kurtosis          float64
#  698  mfcc_sma_de[9]_quartile1         float64
#  699  mfcc_sma_de[9]_quartile2         float64
#  700  mfcc_sma_de[9]_quartile3         float64
#  701  mfcc_sma_de[9]_iqr1-2            float64
#  702  mfcc_sma_de[9]_iqr2-3            float64
#  703  mfcc_sma_de[9]_iqr1-3            float64
#  704  mfcc_sma_de[10]_max              float64
#  705  mfcc_sma_de[10]_min              float64
#  706  mfcc_sma_de[10]_range            float64
#  707  mfcc_sma_de[10]_maxPos           float64
#  708  mfcc_sma_de[10]_minPos           float64
#  709  mfcc_sma_de[10]_amean            float64
#  710  mfcc_sma_de[10]_linregc1         float64
#  711  mfcc_sma_de[10]_linregc2         float64
#  712  mfcc_sma_de[10]_linregerrA       float64
#  713  mfcc_sma_de[10]_linregerrQ       float64
#  714  mfcc_sma_de[10]_stddev           float64
#  715  mfcc_sma_de[10]_skewness         float64
#  716  mfcc_sma_de[10]_kurtosis         float64
#  717  mfcc_sma_de[10]_quartile1        float64
#  718  mfcc_sma_de[10]_quartile2        float64
#  719  mfcc_sma_de[10]_quartile3        float64
#  720  mfcc_sma_de[10]_iqr1-2           float64
#  721  mfcc_sma_de[10]_iqr2-3           float64
#  722  mfcc_sma_de[10]_iqr1-3           float64
#  723  mfcc_sma_de[11]_max              float64
#  724  mfcc_sma_de[11]_min              float64
#  725  mfcc_sma_de[11]_range            float64
#  726  mfcc_sma_de[11]_maxPos           float64
#  727  mfcc_sma_de[11]_minPos           float64
#  728  mfcc_sma_de[11]_amean            float64
#  729  mfcc_sma_de[11]_linregc1         float64
#  730  mfcc_sma_de[11]_linregc2         float64
#  731  mfcc_sma_de[11]_linregerrA       float64
#  732  mfcc_sma_de[11]_linregerrQ       float64
#  733  mfcc_sma_de[11]_stddev           float64
#  734  mfcc_sma_de[11]_skewness         float64
#  735  mfcc_sma_de[11]_kurtosis         float64
#  736  mfcc_sma_de[11]_quartile1        float64
#  737  mfcc_sma_de[11]_quartile2        float64
#  738  mfcc_sma_de[11]_quartile3        float64
#  739  mfcc_sma_de[11]_iqr1-2           float64
#  740  mfcc_sma_de[11]_iqr2-3           float64
#  741  mfcc_sma_de[11]_iqr1-3           float64
#  742  mfcc_sma_de[12]_max              float64
#  743  mfcc_sma_de[12]_min              float64
#  744  mfcc_sma_de[12]_range            float64
#  745  mfcc_sma_de[12]_maxPos           float64
#  746  mfcc_sma_de[12]_minPos           float64
#  747  mfcc_sma_de[12]_amean            float64
#  748  mfcc_sma_de[12]_linregc1         float64
#  749  mfcc_sma_de[12]_linregc2         float64
#  750  mfcc_sma_de[12]_linregerrA       float64
#  751  mfcc_sma_de[12]_linregerrQ       float64
#  752  mfcc_sma_de[12]_stddev           float64
#  753  mfcc_sma_de[12]_skewness         float64
#  754  mfcc_sma_de[12]_kurtosis         float64
#  755  mfcc_sma_de[12]_quartile1        float64
#  756  mfcc_sma_de[12]_quartile2        float64
#  757  mfcc_sma_de[12]_quartile3        float64
#  758  mfcc_sma_de[12]_iqr1-2           float64
#  759  mfcc_sma_de[12]_iqr2-3           float64
#  760  mfcc_sma_de[12]_iqr1-3           float64
#  761  lspFreq_sma_de[0]_max            float64
#  762  lspFreq_sma_de[0]_min            float64
#  763  lspFreq_sma_de[0]_range          float64
#  764  lspFreq_sma_de[0]_maxPos         float64
#  765  lspFreq_sma_de[0]_minPos         float64
#  766  lspFreq_sma_de[0]_amean          float64
#  767  lspFreq_sma_de[0]_linregc1       float64
#  768  lspFreq_sma_de[0]_linregc2       float64
#  769  lspFreq_sma_de[0]_linregerrA     float64
#  770  lspFreq_sma_de[0]_linregerrQ     float64
#  771  lspFreq_sma_de[0]_stddev         float64
#  772  lspFreq_sma_de[0]_skewness       float64
#  773  lspFreq_sma_de[0]_kurtosis       float64
#  774  lspFreq_sma_de[0]_quartile1      float64
#  775  lspFreq_sma_de[0]_quartile2      float64
#  776  lspFreq_sma_de[0]_quartile3      float64
#  777  lspFreq_sma_de[0]_iqr1-2         float64
#  778  lspFreq_sma_de[0]_iqr2-3         float64
#  779  lspFreq_sma_de[0]_iqr1-3         float64
#  780  lspFreq_sma_de[1]_max            float64
#  781  lspFreq_sma_de[1]_min            float64
#  782  lspFreq_sma_de[1]_range          float64
#  783  lspFreq_sma_de[1]_maxPos         float64
#  784  lspFreq_sma_de[1]_minPos         float64
#  785  lspFreq_sma_de[1]_amean          float64
#  786  lspFreq_sma_de[1]_linregc1       float64
#  787  lspFreq_sma_de[1]_linregc2       float64
#  788  lspFreq_sma_de[1]_linregerrA     float64
#  789  lspFreq_sma_de[1]_linregerrQ     float64
#  790  lspFreq_sma_de[1]_stddev         float64
#  791  lspFreq_sma_de[1]_skewness       float64
#  792  lspFreq_sma_de[1]_kurtosis       float64
#  793  lspFreq_sma_de[1]_quartile1      float64
#  794  lspFreq_sma_de[1]_quartile2      float64
#  795  lspFreq_sma_de[1]_quartile3      float64
#  796  lspFreq_sma_de[1]_iqr1-2         float64
#  797  lspFreq_sma_de[1]_iqr2-3         float64
#  798  lspFreq_sma_de[1]_iqr1-3         float64
#  799  lspFreq_sma_de[2]_max            float64
#  800  lspFreq_sma_de[2]_min            float64
#  801  lspFreq_sma_de[2]_range          float64
#  802  lspFreq_sma_de[2]_maxPos         float64
#  803  lspFreq_sma_de[2]_minPos         float64
#  804  lspFreq_sma_de[2]_amean          float64
#  805  lspFreq_sma_de[2]_linregc1       float64
#  806  lspFreq_sma_de[2]_linregc2       float64
#  807  lspFreq_sma_de[2]_linregerrA     float64
#  808  lspFreq_sma_de[2]_linregerrQ     float64
#  809  lspFreq_sma_de[2]_stddev         float64
#  810  lspFreq_sma_de[2]_skewness       float64
#  811  lspFreq_sma_de[2]_kurtosis       float64
#  812  lspFreq_sma_de[2]_quartile1      float64
#  813  lspFreq_sma_de[2]_quartile2      float64
#  814  lspFreq_sma_de[2]_quartile3      float64
#  815  lspFreq_sma_de[2]_iqr1-2         float64
#  816  lspFreq_sma_de[2]_iqr2-3         float64
#  817  lspFreq_sma_de[2]_iqr1-3         float64
#  818  lspFreq_sma_de[3]_max            float64
#  819  lspFreq_sma_de[3]_min            float64
#  820  lspFreq_sma_de[3]_range          float64
#  821  lspFreq_sma_de[3]_maxPos         float64
#  822  lspFreq_sma_de[3]_minPos         float64
#  823  lspFreq_sma_de[3]_amean          float64
#  824  lspFreq_sma_de[3]_linregc1       float64
#  825  lspFreq_sma_de[3]_linregc2       float64
#  826  lspFreq_sma_de[3]_linregerrA     float64
#  827  lspFreq_sma_de[3]_linregerrQ     float64
#  828  lspFreq_sma_de[3]_stddev         float64
#  829  lspFreq_sma_de[3]_skewness       float64
#  830  lspFreq_sma_de[3]_kurtosis       float64
#  831  lspFreq_sma_de[3]_quartile1      float64
#  832  lspFreq_sma_de[3]_quartile2      float64
#  833  lspFreq_sma_de[3]_quartile3      float64
#  834  lspFreq_sma_de[3]_iqr1-2         float64
#  835  lspFreq_sma_de[3]_iqr2-3         float64
#  836  lspFreq_sma_de[3]_iqr1-3         float64
#  837  lspFreq_sma_de[4]_max            float64
#  838  lspFreq_sma_de[4]_min            float64
#  839  lspFreq_sma_de[4]_range          float64
#  840  lspFreq_sma_de[4]_maxPos         float64
#  841  lspFreq_sma_de[4]_minPos         float64
#  842  lspFreq_sma_de[4]_amean          float64
#  843  lspFreq_sma_de[4]_linregc1       float64
#  844  lspFreq_sma_de[4]_linregc2       float64
#  845  lspFreq_sma_de[4]_linregerrA     float64
#  846  lspFreq_sma_de[4]_linregerrQ     float64
#  847  lspFreq_sma_de[4]_stddev         float64
#  848  lspFreq_sma_de[4]_skewness       float64
#  849  lspFreq_sma_de[4]_kurtosis       float64
#  850  lspFreq_sma_de[4]_quartile1      float64
#  851  lspFreq_sma_de[4]_quartile2      float64
#  852  lspFreq_sma_de[4]_quartile3      float64
#  853  lspFreq_sma_de[4]_iqr1-2         float64
#  854  lspFreq_sma_de[4]_iqr2-3         float64
#  855  lspFreq_sma_de[4]_iqr1-3         float64
#  856  lspFreq_sma_de[5]_max            float64
#  857  lspFreq_sma_de[5]_min            float64
#  858  lspFreq_sma_de[5]_range          float64
#  859  lspFreq_sma_de[5]_maxPos         float64
#  860  lspFreq_sma_de[5]_minPos         float64
#  861  lspFreq_sma_de[5]_amean          float64
#  862  lspFreq_sma_de[5]_linregc1       float64
#  863  lspFreq_sma_de[5]_linregc2       float64
#  864  lspFreq_sma_de[5]_linregerrA     float64
#  865  lspFreq_sma_de[5]_linregerrQ     float64
#  866  lspFreq_sma_de[5]_stddev         float64
#  867  lspFreq_sma_de[5]_skewness       float64
#  868  lspFreq_sma_de[5]_kurtosis       float64
#  869  lspFreq_sma_de[5]_quartile1      float64
#  870  lspFreq_sma_de[5]_quartile2      float64
#  871  lspFreq_sma_de[5]_quartile3      float64
#  872  lspFreq_sma_de[5]_iqr1-2         float64
#  873  lspFreq_sma_de[5]_iqr2-3         float64
#  874  lspFreq_sma_de[5]_iqr1-3         float64
#  875  lspFreq_sma_de[6]_max            float64
#  876  lspFreq_sma_de[6]_min            float64
#  877  lspFreq_sma_de[6]_range          float64
#  878  lspFreq_sma_de[6]_maxPos         float64
#  879  lspFreq_sma_de[6]_minPos         float64
#  880  lspFreq_sma_de[6]_amean          float64
#  881  lspFreq_sma_de[6]_linregc1       float64
#  882  lspFreq_sma_de[6]_linregc2       float64
#  883  lspFreq_sma_de[6]_linregerrA     float64
#  884  lspFreq_sma_de[6]_linregerrQ     float64
#  885  lspFreq_sma_de[6]_stddev         float64
#  886  lspFreq_sma_de[6]_skewness       float64
#  887  lspFreq_sma_de[6]_kurtosis       float64
#  888  lspFreq_sma_de[6]_quartile1      float64
#  889  lspFreq_sma_de[6]_quartile2      float64
#  890  lspFreq_sma_de[6]_quartile3      float64
#  891  lspFreq_sma_de[6]_iqr1-2         float64
#  892  lspFreq_sma_de[6]_iqr2-3         float64
#  893  lspFreq_sma_de[6]_iqr1-3         float64
#  894  lspFreq_sma_de[7]_max            float64
#  895  lspFreq_sma_de[7]_min            float64
#  896  lspFreq_sma_de[7]_range          float64
#  897  lspFreq_sma_de[7]_maxPos         float64
#  898  lspFreq_sma_de[7]_minPos         float64
#  899  lspFreq_sma_de[7]_amean          float64
#  900  lspFreq_sma_de[7]_linregc1       float64
#  901  lspFreq_sma_de[7]_linregc2       float64
#  902  lspFreq_sma_de[7]_linregerrA     float64
#  903  lspFreq_sma_de[7]_linregerrQ     float64
#  904  lspFreq_sma_de[7]_stddev         float64
#  905  lspFreq_sma_de[7]_skewness       float64
#  906  lspFreq_sma_de[7]_kurtosis       float64
#  907  lspFreq_sma_de[7]_quartile1      float64
#  908  lspFreq_sma_de[7]_quartile2      float64
#  909  lspFreq_sma_de[7]_quartile3      float64
#  910  lspFreq_sma_de[7]_iqr1-2         float64
#  911  lspFreq_sma_de[7]_iqr2-3         float64
#  912  lspFreq_sma_de[7]_iqr1-3         float64
#  913  pcm_zcr_sma_de_max               float64
#  914  pcm_zcr_sma_de_min               float64
#  915  pcm_zcr_sma_de_range             float64
#  916  pcm_zcr_sma_de_maxPos            float64
#  917  pcm_zcr_sma_de_minPos            float64
#  918  pcm_zcr_sma_de_amean             float64
#  919  pcm_zcr_sma_de_linregc1          float64
#  920  pcm_zcr_sma_de_linregc2          float64
#  921  pcm_zcr_sma_de_linregerrA        float64
#  922  pcm_zcr_sma_de_linregerrQ        float64
#  923  pcm_zcr_sma_de_stddev            float64
#  924  pcm_zcr_sma_de_skewness          float64
#  925  pcm_zcr_sma_de_kurtosis          float64
#  926  pcm_zcr_sma_de_quartile1         float64
#  927  pcm_zcr_sma_de_quartile2         float64
#  928  pcm_zcr_sma_de_quartile3         float64
#  929  pcm_zcr_sma_de_iqr1-2            float64
#  930  pcm_zcr_sma_de_iqr2-3            float64
#  931  pcm_zcr_sma_de_iqr1-3            float64
#  932  voiceProb_sma_de_max             float64
#  933  voiceProb_sma_de_min             float64
#  934  voiceProb_sma_de_range           float64
#  935  voiceProb_sma_de_maxPos          float64
#  936  voiceProb_sma_de_minPos          float64
#  937  voiceProb_sma_de_amean           float64
#  938  voiceProb_sma_de_linregc1        float64
#  939  voiceProb_sma_de_linregc2        float64
#  940  voiceProb_sma_de_linregerrA      float64
#  941  voiceProb_sma_de_linregerrQ      float64
#  942  voiceProb_sma_de_stddev          float64
#  943  voiceProb_sma_de_skewness        float64
#  944  voiceProb_sma_de_kurtosis        float64
#  945  voiceProb_sma_de_quartile1       float64
#  946  voiceProb_sma_de_quartile2       float64
#  947  voiceProb_sma_de_quartile3       float64
#  948  voiceProb_sma_de_iqr1-2          float64
#  949  voiceProb_sma_de_iqr2-3          float64
#  950  voiceProb_sma_de_iqr1-3          float64
#  951  F0_sma_de_max                    float64
#  952  F0_sma_de_min                    float64
#  953  F0_sma_de_range                  float64
#  954  F0_sma_de_maxPos                 float64
#  955  F0_sma_de_minPos                 float64
#  956  F0_sma_de_amean                  float64
#  957  F0_sma_de_linregc1               float64
#  958  F0_sma_de_linregc2               float64
#  959  F0_sma_de_linregerrA             float64
#  960  F0_sma_de_linregerrQ             float64
#  961  F0_sma_de_stddev                 float64
#  962  F0_sma_de_skewness               float64
#  963  F0_sma_de_kurtosis               float64
#  964  F0_sma_de_quartile1              float64
#  965  F0_sma_de_quartile2              float64
#  966  F0_sma_de_quartile3              float64
#  967  F0_sma_de_iqr1-2                 float64
#  968  F0_sma_de_iqr2-3                 float64
#  969  F0_sma_de_iqr1-3                 float64
#  970  F0env_sma_de_max                 float64
#  971  F0env_sma_de_min                 float64
#  972  F0env_sma_de_range               float64
#  973  F0env_sma_de_maxPos              float64
#  974  F0env_sma_de_minPos              float64
#  975  F0env_sma_de_amean               float64
#  976  F0env_sma_de_linregc1            float64
#  977  F0env_sma_de_linregc2            float64
#  978  F0env_sma_de_linregerrA          float64
#  979  F0env_sma_de_linregerrQ          float64
#  980  F0env_sma_de_stddev              float64
#  981  F0env_sma_de_skewness            float64
#  982  F0env_sma_de_kurtosis            float64
#  983  F0env_sma_de_quartile1           float64
#  984  F0env_sma_de_quartile2           float64
#  985  F0env_sma_de_quartile3           float64
#  986  F0env_sma_de_iqr1-2              float64
#  987  F0env_sma_de_iqr2-3              float64
#  988  F0env_sma_de_iqr1-3              float64
# dtypes: float64(988), int64(1)
# memory usage: 13.2 MB

# %% [markdown]
# Join both the featureset and annotation set together

# %%
df_opensmile_emobase_whole = pd.merge(df_opensmile_emobase_features, df_annotations, how='inner', on='song_id')
df_opensmile_emobase_whole = df_opensmile_emobase_whole.drop('song_id', axis=1)
df_opensmile_emobase_whole
# Out:
#       pcm_intensity_sma_max  pcm_intensity_sma_min  pcm_intensity_sma_range  \
# 0                  0.000100           0.000000e+00                 0.000100
# 1                  0.000051           0.000000e+00                 0.000051
# 2                  0.000088           0.000000e+00                 0.000088
# 3                  0.000060           0.000000e+00                 0.000060
# 4                  0.000113           0.000000e+00                 0.000113
# ...                     ...                    ...                      ...
# 1739               0.000023           1.535268e-08                 0.000023
# 1740               0.000012           1.499340e-08                 0.000012
# 1741               0.000026           1.076092e-08                 0.000026
# 1742               0.000030           5.323769e-09                 0.000030
# 1743               0.000032           6.140887e-09                 0.000032
#
#       pcm_intensity_sma_maxPos  pcm_intensity_sma_minPos  \
# 0                       3821.0                       0.0
# 1                       2809.0                       0.0
# 2                       1800.0                       0.0
# 3                        488.0                       0.0
# 4                       1061.0                       0.0
# ...                        ...                       ...
# 1739                    2355.0                     548.0
# 1740                    3905.0                    4487.0
# 1741                    3411.0                    3137.0
# 1742                    4167.0                    1089.0
# 1743                    1713.0                     437.0
#
#       pcm_intensity_sma_amean  pcm_intensity_sma_linregc1  \
# 0                    0.000003                9.746145e-11
# 1                    0.000005                1.012040e-10
# 2                    0.000011                5.901333e-11
# 3                    0.000006               -3.841752e-10
# 4                    0.000020               -4.199130e-11
# ...                       ...                         ...
# 1739                 0.000005               -8.072022e-11
# 1740                 0.000002               -4.315512e-11
# 1741                 0.000003               -1.908036e-10
# 1742                 0.000002                9.297152e-11
# 1743                 0.000003                8.342206e-10
#
#       pcm_intensity_sma_linregc2  pcm_intensity_sma_linregerrA  \
# 0                       0.000003                      0.000002
# 1                       0.000004                      0.000004
# 2                       0.000011                      0.000008
# 3                       0.000007                      0.000005
# 4                       0.000020                      0.000011
# ...                          ...                           ...
# 1739                    0.000005                      0.000003
# 1740                    0.000002                      0.000001
# 1741                    0.000004                      0.000003
# 1742                    0.000002                      0.000002
# 1743                    0.000002                      0.000003
#
#       pcm_intensity_sma_linregerrQ  ...  F0env_sma_de_skewness  \
# 0                     2.003038e-11  ...               0.815608
# 1                     3.706416e-11  ...               1.259240
# 2                     1.247090e-10  ...               0.692436
# 3                     4.100738e-11  ...               0.625557
# 4                     1.996163e-10  ...               0.802300
# ...                            ...  ...                    ...
# 1739                  1.198487e-11  ...               7.053555
# 1740                  1.978644e-12  ...               1.890596
# 1741                  1.439331e-11  ...               0.621677
# 1742                  6.859520e-12  ...               3.872501
# 1743                  1.511511e-11  ...               0.368404
#
#       F0env_sma_de_kurtosis  F0env_sma_de_quartile1  F0env_sma_de_quartile2  \
# 0                 11.220467               -2.025291                     0.0
# 1                 29.973100                0.000000                     0.0
# 2                  9.787511               -1.309070                     0.0
# 3                  9.257450               -1.881530                     0.0
# 4                 13.485694               -1.159967                     0.0
# ...                     ...                     ...                     ...
# 1739             145.043520                0.000000                     0.0
# 1740              27.465874               -0.168976                     0.0
# 1741              18.409992                0.000000                     0.0
# 1742              60.610363                0.000000                     0.0
# 1743              11.077601                0.000000                     0.0
#
#       F0env_sma_de_quartile3  F0env_sma_de_iqr1-2  F0env_sma_de_iqr2-3  \
# 0                   1.749724             2.025291             1.749724
# 1                   0.000000             0.000000             0.000000
# 2                   1.036872             1.309070             1.036872
# 3                   1.791142             1.881530             1.791142
# 4                   1.114847             1.159967             1.114847
# ...                      ...                  ...                  ...
# 1739                0.000000             0.000000             0.000000
# 1740                0.000000             0.168976             0.000000
# 1741                0.000000             0.000000             0.000000
# 1742                0.000000             0.000000             0.000000
# 1743                0.000000             0.000000             0.000000
#
#       F0env_sma_de_iqr1-3  valence_mean_mapped  arousal_mean_mapped
# 0                3.775015               -0.475               -0.500
# 1                0.000000               -0.375               -0.425
# 2                2.345942                0.175                0.125
# 3                3.672672               -0.150                0.075
# 4                2.274814                0.200                0.350
# ...                   ...                  ...                  ...
# 1739             0.000000               -0.275                0.225
# 1740             0.168976                0.075               -0.275
# 1741             0.000000                0.350                0.300
# 1742             0.000000               -0.100                0.100
# 1743             0.000000                0.200                0.250
#
# [1744 rows x 990 columns]

# %% [markdown]
# #### Prepare dataframes for the neural network

# %% [markdown]
# Perform splitting of the dataframe into training and testing sets

# %%
features = df_opensmile_emobase_features.drop('song_id', axis=1)
features
# Out:
#       pcm_intensity_sma_max  pcm_intensity_sma_min  pcm_intensity_sma_range  \
# 0                  0.000100           0.000000e+00                 0.000100
# 1                  0.000051           0.000000e+00                 0.000051
# 2                  0.000088           0.000000e+00                 0.000088
# 3                  0.000060           0.000000e+00                 0.000060
# 4                  0.000113           0.000000e+00                 0.000113
# ...                     ...                    ...                      ...
# 1739               0.000023           1.535268e-08                 0.000023
# 1740               0.000012           1.499340e-08                 0.000012
# 1741               0.000026           1.076092e-08                 0.000026
# 1742               0.000030           5.323769e-09                 0.000030
# 1743               0.000032           6.140887e-09                 0.000032
#
#       pcm_intensity_sma_maxPos  pcm_intensity_sma_minPos  \
# 0                       3821.0                       0.0
# 1                       2809.0                       0.0
# 2                       1800.0                       0.0
# 3                        488.0                       0.0
# 4                       1061.0                       0.0
# ...                        ...                       ...
# 1739                    2355.0                     548.0
# 1740                    3905.0                    4487.0
# 1741                    3411.0                    3137.0
# 1742                    4167.0                    1089.0
# 1743                    1713.0                     437.0
#
#       pcm_intensity_sma_amean  pcm_intensity_sma_linregc1  \
# 0                    0.000003                9.746145e-11
# 1                    0.000005                1.012040e-10
# 2                    0.000011                5.901333e-11
# 3                    0.000006               -3.841752e-10
# 4                    0.000020               -4.199130e-11
# ...                       ...                         ...
# 1739                 0.000005               -8.072022e-11
# 1740                 0.000002               -4.315512e-11
# 1741                 0.000003               -1.908036e-10
# 1742                 0.000002                9.297152e-11
# 1743                 0.000003                8.342206e-10
#
#       pcm_intensity_sma_linregc2  pcm_intensity_sma_linregerrA  \
# 0                       0.000003                      0.000002
# 1                       0.000004                      0.000004
# 2                       0.000011                      0.000008
# 3                       0.000007                      0.000005
# 4                       0.000020                      0.000011
# ...                          ...                           ...
# 1739                    0.000005                      0.000003
# 1740                    0.000002                      0.000001
# 1741                    0.000004                      0.000003
# 1742                    0.000002                      0.000002
# 1743                    0.000002                      0.000003
#
#       pcm_intensity_sma_linregerrQ  ...  F0env_sma_de_linregerrQ  \
# 0                     2.003038e-11  ...                34.224740
# 1                     3.706416e-11  ...                11.536975
# 2                     1.247090e-10  ...                31.980932
# 3                     4.100738e-11  ...                33.398550
# 4                     1.996163e-10  ...                23.441298
# ...                            ...  ...                      ...
# 1739                  1.198487e-11  ...                 8.894216
# 1740                  1.978644e-12  ...                 2.125242
# 1741                  1.439331e-11  ...                11.348680
# 1742                  6.859520e-12  ...                 7.925314
# 1743                  1.511511e-11  ...                16.543354
#
#       F0env_sma_de_stddev  F0env_sma_de_skewness  F0env_sma_de_kurtosis  \
# 0                5.851549               0.815608              11.220467
# 1                3.397905               1.259240              29.973100
# 2                5.655746               0.692436               9.787511
# 3                5.780117               0.625557               9.257450
# 4                4.842434               0.802300              13.485694
# ...                   ...                    ...                    ...
# 1739             2.983331               7.053555             145.043520
# 1740             1.458878               1.890596              27.465874
# 1741             3.371960               0.621677              18.409992
# 1742             2.818051               3.872501              60.610363
# 1743             4.068033               0.368404              11.077601
#
#       F0env_sma_de_quartile1  F0env_sma_de_quartile2  F0env_sma_de_quartile3  \
# 0                  -2.025291                     0.0                1.749724
# 1                   0.000000                     0.0                0.000000
# 2                  -1.309070                     0.0                1.036872
# 3                  -1.881530                     0.0                1.791142
# 4                  -1.159967                     0.0                1.114847
# ...                      ...                     ...                     ...
# 1739                0.000000                     0.0                0.000000
# 1740               -0.168976                     0.0                0.000000
# 1741                0.000000                     0.0                0.000000
# 1742                0.000000                     0.0                0.000000
# 1743                0.000000                     0.0                0.000000
#
#       F0env_sma_de_iqr1-2  F0env_sma_de_iqr2-3  F0env_sma_de_iqr1-3
# 0                2.025291             1.749724             3.775015
# 1                0.000000             0.000000             0.000000
# 2                1.309070             1.036872             2.345942
# 3                1.881530             1.791142             3.672672
# 4                1.159967             1.114847             2.274814
# ...                   ...                  ...                  ...
# 1739             0.000000             0.000000             0.000000
# 1740             0.168976             0.000000             0.168976
# 1741             0.000000             0.000000             0.000000
# 1742             0.000000             0.000000             0.000000
# 1743             0.000000             0.000000             0.000000
#
# [1744 rows x 988 columns]

# %%
targets = df_annotations.drop('song_id', axis=1)
targets
# Out:
#       valence_mean_mapped  arousal_mean_mapped
# 0                  -0.475               -0.500
# 1                  -0.375               -0.425
# 2                   0.175                0.125
# 3                  -0.150                0.075
# 4                   0.200                0.350
# ...                   ...                  ...
# 1739               -0.275                0.225
# 1740                0.075               -0.275
# 1741                0.350                0.300
# 1742               -0.100                0.100
# 1743                0.200                0.250
#
# [1744 rows x 2 columns]

# %% [markdown]
# Perform 80-20 train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)

# %% [markdown]
# Create tensors for X_train and X_test

# %%
# get the columns containing numpy.ndarray as its values
numpy_array_columns = X_train.select_dtypes(include=['object']).columns.tolist()

print(f'Numpy ndarray columns: {numpy_array_columns}')

# tensors for columns that are numpy.ndarray
X_train_tensors_ndarray = [convert_ndarray_col_to_tensor(X_train[col]) for col in numpy_array_columns]
X_test_tensors_ndarray = [convert_ndarray_col_to_tensor(X_test[col]) for col in numpy_array_columns]

# generate a tensor for the remaining dataframe (for columns where the type is not numpy.ndarray)
X_train = X_train.drop(numpy_array_columns, axis=1)
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float64)
print(f'X_train_tensor shape: {X_train_tensor.shape}')
X_test = X_test.drop(numpy_array_columns, axis=1)
X_test_tensor = torch.tensor(X_test.values, dtype=torch.float64)
print(f'X_test_tensor shape: {X_test_tensor.shape}')
# Out:
# Numpy ndarray columns: []
# X_train_tensor shape: torch.Size([1395, 988])
# X_test_tensor shape: torch.Size([349, 988])

# %% [markdown]
# Create tensors for Y_train and Y_test

# %%
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float64)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float64)

# %% [markdown]
# Define neural network parameters and instantitate neural network

# %%
input_size = len(numpy_array_columns) + 1 # total number of tensors
hidden_size = 20 
output_size = 2  # Output size for valence and arousal
learning_rate = 0.001
criterion = nn.MSELoss()
num_epochs = 300

# %% [markdown]
# Define the neural network

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size):
        super(NeuralNetwork, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), math.ceil((input_size**0.5) * 2)),
            nn.ReLU(),
            nn.Linear(math.ceil((input_size**0.5) * 2), 2)
        )

    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# #### Training

# %% [markdown]
# Prepare input_train_data and target_train_labels

# %%
# X_train_tensors = [X_train_tensor]
# X_train_tensors.extend(X_train_tensors_ndarray)

# # Find the maximum shape among all tensors
# max_shape = max([tensor.shape for tensor in X_train_tensors])

# # Adjust tensor shapes to match the maximum shape without data loss
# X_train_tensors_adjusted = []

# for tensor in X_train_tensors:
#     padding = torch.zeros(*max_shape)
#     padding_slice = [slice(0, s) for s in tensor.shape]
#     padding[tuple(padding_slice)] = tensor
#     X_train_tensors_adjusted.append(padding)

# print(X_train_tensors_adjusted)

# %%
# input_train_data = torch.stack(tuple(X_train_tensors_adjusted), dim=0)
input_train_data = X_train_tensor.float()

# input_train_data = input_train_data.view(input_train_data.shape[1], -1)
print(input_train_data.shape)

target_train_labels = y_train_tensor
# Out:
# torch.Size([1395, 988])

# %% [markdown]
# Training loop

# %%
model = NeuralNetwork(input_size=input_train_data.shape[1])
optimiser = optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
  optimiser.zero_grad()
  
  # forward pass
  output = model(input_train_data)

  # calculate loss
  loss = torch.sqrt(criterion(output.float(), target_train_labels.float()))

  # backward pass
  loss.backward()
  # update weights
  optimiser.step()

  print(f'Epoch {epoch + 1}, Loss: {loss.item()}')

print("Training completed.")
# Out:
# Epoch 1, Loss: 0.3236202895641327
# Epoch 2, Loss: 0.31169405579566956
# Epoch 3, Loss: 0.30857226252555847
# Epoch 4, Loss: 0.3073917329311371
# Epoch 5, Loss: 0.3063937723636627
# Epoch 6, Loss: 0.3049333393573761
# Epoch 7, Loss: 0.3034643828868866
# Epoch 8, Loss: 0.30203044414520264
# Epoch 9, Loss: 0.3001430034637451
# Epoch 10, Loss: 0.29839083552360535
# Epoch 11, Loss: 0.29701390862464905
# Epoch 12, Loss: 0.29646414518356323
# Epoch 13, Loss: 0.29671287536621094
# Epoch 14, Loss: 0.2915884852409363
# Epoch 15, Loss: 0.29376715421676636
# Epoch 16, Loss: 0.2891332507133484
# Epoch 17, Loss: 0.288534551858902
# Epoch 18, Loss: 0.28554460406303406
# Epoch 19, Loss: 0.28259819746017456
# Epoch 20, Loss: 0.2841258943080902
# Epoch 21, Loss: 0.27836519479751587
# Epoch 22, Loss: 0.2762415409088135
# Epoch 23, Loss: 0.27783551812171936
# Epoch 24, Loss: 0.2738196849822998
# Epoch 25, Loss: 0.269182026386261
# Epoch 26, Loss: 0.27085521817207336
# Epoch 27, Loss: 0.28352683782577515
# Epoch 28, Loss: 0.26767995953559875
# Epoch 29, Loss: 0.269659161567688
# Epoch 30, Loss: 0.2659887671470642
# Epoch 31, Loss: 0.2654690444469452
# Epoch 32, Loss: 0.26318639516830444
# Epoch 33, Loss: 0.25696226954460144
# Epoch 34, Loss: 0.2580835521221161
# Epoch 35, Loss: 0.25657179951667786
# Epoch 36, Loss: 0.25109007954597473
# Epoch 37, Loss: 0.24716080725193024
# Epoch 38, Loss: 0.24695232510566711
# Epoch 39, Loss: 0.2519417107105255
# Epoch 40, Loss: 0.25626805424690247
# Epoch 41, Loss: 0.2511409819126129
# Epoch 42, Loss: 0.2398185431957245
# Epoch 43, Loss: 0.24738341569900513
# Epoch 44, Loss: 0.2426738440990448
# Epoch 45, Loss: 0.23645633459091187
# Epoch 46, Loss: 0.24429504573345184
# Epoch 47, Loss: 0.2405778467655182
# Epoch 48, Loss: 0.22987909615039825
# Epoch 49, Loss: 0.24193686246871948
# Epoch 50, Loss: 0.23150652647018433
# Epoch 51, Loss: 0.22808796167373657
# Epoch 52, Loss: 0.23605293035507202
# Epoch 53, Loss: 0.2226889431476593
# Epoch 54, Loss: 0.22055253386497498
# Epoch 55, Loss: 0.229183629155159
# Epoch 56, Loss: 0.21961528062820435
# Epoch 57, Loss: 0.21332447230815887
# Epoch 58, Loss: 0.22238613665103912
# Epoch 59, Loss: 0.21616412699222565
# Epoch 60, Loss: 0.20667356252670288
# Epoch 61, Loss: 0.21572193503379822
# Epoch 62, Loss: 0.21379248797893524
# Epoch 63, Loss: 0.20213685929775238
# Epoch 64, Loss: 0.20858173072338104
# Epoch 65, Loss: 0.20980092883110046
# Epoch 66, Loss: 0.19732004404067993
# Epoch 67, Loss: 0.19766703248023987
# Epoch 68, Loss: 0.20383338630199432
# Epoch 69, Loss: 0.1956491321325302
# Epoch 70, Loss: 0.18799178302288055
# Epoch 71, Loss: 0.19105146825313568
# Epoch 72, Loss: 0.19542206823825836
# Epoch 73, Loss: 0.19250935316085815
# Epoch 74, Loss: 0.18486835062503815
# Epoch 75, Loss: 0.18000878393650055
# Epoch 76, Loss: 0.18203367292881012
# Epoch 77, Loss: 0.18854691088199615
# Epoch 78, Loss: 0.19556012749671936
# Epoch 79, Loss: 0.1879909336566925
# Epoch 80, Loss: 0.17383140325546265
# Epoch 81, Loss: 0.17822904884815216
# Epoch 82, Loss: 0.17989866435527802
# Epoch 83, Loss: 0.1732320636510849
# Epoch 84, Loss: 0.1693209856748581
# Epoch 85, Loss: 0.1668139398097992
# Epoch 86, Loss: 0.1731712967157364
# Epoch 87, Loss: 0.1827498823404312
# Epoch 88, Loss: 0.18627819418907166
# Epoch 89, Loss: 0.1900329887866974
# Epoch 90, Loss: 0.16793979704380035
# Epoch 91, Loss: 0.16818411648273468
# Epoch 92, Loss: 0.17383933067321777
# Epoch 93, Loss: 0.16389289498329163
# Epoch 94, Loss: 0.16734567284584045
# Epoch 95, Loss: 0.1665302962064743
# Epoch 96, Loss: 0.16154971718788147
# Epoch 97, Loss: 0.15755775570869446
# Epoch 98, Loss: 0.15607671439647675
# Epoch 99, Loss: 0.1523153930902481
# Epoch 100, Loss: 0.15189450979232788
# Epoch 101, Loss: 0.15693399310112
# Epoch 102, Loss: 0.17414405941963196
# Epoch 103, Loss: 0.1935032457113266
# Epoch 104, Loss: 0.15236534178256989
# Epoch 105, Loss: 0.16419462859630585
# Epoch 106, Loss: 0.1746724247932434
# Epoch 107, Loss: 0.1478433609008789
# Epoch 108, Loss: 0.15734520554542542
# Epoch 109, Loss: 0.16300933063030243
# Epoch 110, Loss: 0.14499019086360931
# Epoch 111, Loss: 0.14542996883392334
# Epoch 112, Loss: 0.15884435176849365
# Epoch 113, Loss: 0.14683444797992706
# Epoch 114, Loss: 0.13955163955688477
# Epoch 115, Loss: 0.13888484239578247
# Epoch 116, Loss: 0.1447964757680893
# Epoch 117, Loss: 0.1527334451675415
# Epoch 118, Loss: 0.14279715716838837
# Epoch 119, Loss: 0.13437943160533905
# Epoch 120, Loss: 0.13495640456676483
# Epoch 121, Loss: 0.13880062103271484
# Epoch 122, Loss: 0.14039690792560577
# Epoch 123, Loss: 0.13225562870502472
# Epoch 124, Loss: 0.1276964694261551
# Epoch 125, Loss: 0.12648780643939972
# Epoch 126, Loss: 0.12889239192008972
# Epoch 127, Loss: 0.13424868881702423
# Epoch 128, Loss: 0.143556147813797
# Epoch 129, Loss: 0.14462114870548248
# Epoch 130, Loss: 0.1272546797990799
# Epoch 131, Loss: 0.12885931134223938
# Epoch 132, Loss: 0.12561368942260742
# Epoch 133, Loss: 0.1296345591545105
# Epoch 134, Loss: 0.1337185949087143
# Epoch 135, Loss: 0.12652336061000824
# Epoch 136, Loss: 0.12700216472148895
# Epoch 137, Loss: 0.12325765192508698
# Epoch 138, Loss: 0.11964276432991028
# Epoch 139, Loss: 0.12162889540195465
# Epoch 140, Loss: 0.12086670845746994
# Epoch 141, Loss: 0.11722923070192337
# Epoch 142, Loss: 0.11277087032794952
# Epoch 143, Loss: 0.11255291849374771
# Epoch 144, Loss: 0.10998056083917618
# Epoch 145, Loss: 0.10619848966598511
# Epoch 146, Loss: 0.11122854053974152
# Epoch 147, Loss: 0.1055123582482338
# Epoch 148, Loss: 0.11763002723455429
# Epoch 149, Loss: 0.14103366434574127
# Epoch 150, Loss: 0.13385874032974243
# Epoch 151, Loss: 0.12191881239414215
# Epoch 152, Loss: 0.11056436598300934
# Epoch 153, Loss: 0.11762882769107819
# Epoch 154, Loss: 0.11423551291227341
# Epoch 155, Loss: 0.12340820580720901
# Epoch 156, Loss: 0.12127303332090378
# Epoch 157, Loss: 0.11964811384677887
# Epoch 158, Loss: 0.1198076531291008
# Epoch 159, Loss: 0.11373044550418854
# Epoch 160, Loss: 0.10598356276750565
# Epoch 161, Loss: 0.11871115118265152
# Epoch 162, Loss: 0.10139776021242142
# Epoch 163, Loss: 0.10722170025110245
# Epoch 164, Loss: 0.10567079484462738
# Epoch 165, Loss: 0.10727604478597641
# Epoch 166, Loss: 0.11881031095981598
# Epoch 167, Loss: 0.11500079184770584
# Epoch 168, Loss: 0.10467628389596939
# Epoch 169, Loss: 0.1070137545466423
# Epoch 170, Loss: 0.10136048495769501
# Epoch 171, Loss: 0.10192810744047165
# Epoch 172, Loss: 0.10444102436304092
# Epoch 173, Loss: 0.10215787589550018
# Epoch 174, Loss: 0.1035110205411911
# Epoch 175, Loss: 0.10649752616882324
# Epoch 176, Loss: 0.10351961106061935
# Epoch 177, Loss: 0.10379387438297272
# Epoch 178, Loss: 0.10461047291755676
# Epoch 179, Loss: 0.1026909127831459
# Epoch 180, Loss: 0.09652150422334671
# Epoch 181, Loss: 0.10219850391149521
# Epoch 182, Loss: 0.09457292407751083
# Epoch 183, Loss: 0.11222631484270096
# Epoch 184, Loss: 0.09970592707395554
# Epoch 185, Loss: 0.10480945557355881
# Epoch 186, Loss: 0.08530578762292862
# Epoch 187, Loss: 0.0893612876534462
# Epoch 188, Loss: 0.08517205715179443
# Epoch 189, Loss: 0.09191136807203293
# Epoch 190, Loss: 0.10062116384506226
# Epoch 191, Loss: 0.10715053975582123
# Epoch 192, Loss: 0.09367401152849197
# Epoch 193, Loss: 0.09066689759492874
# Epoch 194, Loss: 0.09124664962291718
# Epoch 195, Loss: 0.08728129416704178
# Epoch 196, Loss: 0.08185697346925735
# Epoch 197, Loss: 0.09698356688022614
# Epoch 198, Loss: 0.09458644688129425
# Epoch 199, Loss: 0.08490225672721863
# Epoch 200, Loss: 0.0811101645231247
# Epoch 201, Loss: 0.08248334378004074
# Epoch 202, Loss: 0.08626400679349899
# Epoch 203, Loss: 0.08670958876609802
# Epoch 204, Loss: 0.09206382185220718
# Epoch 205, Loss: 0.09529031813144684
# Epoch 206, Loss: 0.08402225375175476
# Epoch 207, Loss: 0.07884681224822998
# Epoch 208, Loss: 0.07781452685594559
# Epoch 209, Loss: 0.08352861553430557
# Epoch 210, Loss: 0.07942264527082443
# Epoch 211, Loss: 0.07296142727136612
# Epoch 212, Loss: 0.06935151666402817
# Epoch 213, Loss: 0.07358715683221817
# Epoch 214, Loss: 0.08974488079547882
# Epoch 215, Loss: 0.10413968563079834
# Epoch 216, Loss: 0.08628800511360168
# Epoch 217, Loss: 0.07714971899986267
# Epoch 218, Loss: 0.09197085350751877
# Epoch 219, Loss: 0.07323423027992249
# Epoch 220, Loss: 0.08357103168964386
# Epoch 221, Loss: 0.09161108732223511
# Epoch 222, Loss: 0.08066066354513168
# Epoch 223, Loss: 0.08339676260948181
# Epoch 224, Loss: 0.08595822006464005
# Epoch 225, Loss: 0.07862167060375214
# Epoch 226, Loss: 0.07181498408317566
# Epoch 227, Loss: 0.08308754116296768
# Epoch 228, Loss: 0.07255222648382187
# Epoch 229, Loss: 0.07187311351299286
# Epoch 230, Loss: 0.08149921894073486
# Epoch 231, Loss: 0.08266644179821014
# Epoch 232, Loss: 0.08308522403240204
# Epoch 233, Loss: 0.08450756967067719
# Epoch 234, Loss: 0.06390314549207687
# Epoch 235, Loss: 0.06873636692762375
# Epoch 236, Loss: 0.06723813712596893
# Epoch 237, Loss: 0.0650639683008194
# Epoch 238, Loss: 0.06690947711467743
# Epoch 239, Loss: 0.07296338677406311
# Epoch 240, Loss: 0.0962323248386383
# Epoch 241, Loss: 0.07360627502202988
# Epoch 242, Loss: 0.06139928102493286
# Epoch 243, Loss: 0.06164036691188812
# Epoch 244, Loss: 0.06679727137088776
# Epoch 245, Loss: 0.06791926175355911
# Epoch 246, Loss: 0.07120659202337265
# Epoch 247, Loss: 0.08891035616397858
# Epoch 248, Loss: 0.07323512434959412
# Epoch 249, Loss: 0.05653829872608185
# Epoch 250, Loss: 0.05461372807621956
# Epoch 251, Loss: 0.06112883239984512
# Epoch 252, Loss: 0.08336178958415985
# Epoch 253, Loss: 0.07444237172603607
# Epoch 254, Loss: 0.0640164166688919
# Epoch 255, Loss: 0.06382613629102707
# Epoch 256, Loss: 0.07156829535961151
# Epoch 257, Loss: 0.05668789520859718
# Epoch 258, Loss: 0.06818067282438278
# Epoch 259, Loss: 0.07971137762069702
# Epoch 260, Loss: 0.05887451395392418
# Epoch 261, Loss: 0.054873380810022354
# Epoch 262, Loss: 0.062239743769168854
# Epoch 263, Loss: 0.07807955145835876
# Epoch 264, Loss: 0.07079487293958664
# Epoch 265, Loss: 0.058535318821668625
# Epoch 266, Loss: 0.07102249562740326
# Epoch 267, Loss: 0.06044569984078407
# Epoch 268, Loss: 0.056691404432058334
# Epoch 269, Loss: 0.05541867017745972
# Epoch 270, Loss: 0.07242034375667572
# Epoch 271, Loss: 0.06849423795938492
# Epoch 272, Loss: 0.07089903950691223
# Epoch 273, Loss: 0.0595417357981205
# Epoch 274, Loss: 0.06678718328475952
# Epoch 275, Loss: 0.057553358376026154
# Epoch 276, Loss: 0.06837241351604462
# Epoch 277, Loss: 0.07011061161756516
# Epoch 278, Loss: 0.06542758643627167
# Epoch 279, Loss: 0.051699887961149216
# Epoch 280, Loss: 0.04864389821887016
# Epoch 281, Loss: 0.055800680071115494
# Epoch 282, Loss: 0.06126822903752327
# Epoch 283, Loss: 0.07780636847019196
# Epoch 284, Loss: 0.06643005460500717
# Epoch 285, Loss: 0.05905275046825409
# Epoch 286, Loss: 0.07317744940519333
# Epoch 287, Loss: 0.050574950873851776
# Epoch 288, Loss: 0.07380485534667969
# Epoch 289, Loss: 0.06802280992269516
# Epoch 290, Loss: 0.050747379660606384
# Epoch 291, Loss: 0.054244525730609894
# Epoch 292, Loss: 0.0747673511505127
# Epoch 293, Loss: 0.06989838927984238
# Epoch 294, Loss: 0.056815482676029205
# Epoch 295, Loss: 0.05127774178981781
# Epoch 296, Loss: 0.07580547779798508
# Epoch 297, Loss: 0.061991188675165176
# Epoch 298, Loss: 0.06512381881475449
# Epoch 299, Loss: 0.06819135695695877
# Epoch 300, Loss: 0.04588530957698822
# Training completed.

# %% [markdown]
# #### Testing

# %% [markdown]
# Prepare input_test_data and target_test_labels

# %%
# X_test_tensors = [X_test_tensor]
# X_test_tensors.extend(X_test_tensors_ndarray)

# # Find the maximum shape among all tensors
# max_shape = max([tensor.shape for tensor in X_test_tensors])

# # Adjust tensor shapes to match the maximum shape without data loss
# X_test_tensors_adjusted = []

# for tensor in X_test_tensors:
#     padding = torch.zeros(*max_shape)
#     padding_slice = [slice(0, s) for s in tensor.shape]
#     padding[tuple(padding_slice)] = tensor
#     X_test_tensors_adjusted.append(padding)

# print(X_test_tensors_adjusted)

# %%
# input_test_data = torch.stack(tuple(X_test_tensors_adjusted), dim=0)

# input_test_data = input_test_data.view(input_test_data.shape[1], -1)
input_test_data = X_test_tensor.float()
print(input_test_data.shape)

target_test_labels = y_test_tensor
# Out:
# torch.Size([349, 988])

# %% [markdown]
# Generating scores

# %%
with torch.no_grad():
  test_pred = model(input_test_data)
  test_loss = criterion(test_pred.float(), target_test_labels)

print(f'Test loss: {test_loss.item()}')

metric = R2Score()
metric.update(test_pred, target_test_labels)
r2_score = metric.compute()
print(f'R2 score: {r2_score.item()}')
# Out:
# Test loss: 0.10590348757461489
# R2 score: -0.15105884023414295
